# %%
# Loading packages
import numpy as np
import pandas as pd
import os
import pprint
import yaml

# %%
EXTERNAL_PATH = os.path.join(os.pardir, 'Bluepack RH dataset')
na_values = ['N/A', 'NA', 'na', 'n/a']
table_export_raw = pd.read_excel(os.path.join(EXTERNAL_PATH, '102731377_AD.xlsx'), 
                                 sheet_name='Tab data 102731377', 
                                 header=None,
                                 na_values = na_values)[0].str.split(' = ')
table_export = pd.DataFrame({'Attribute' : table_export_raw.map(lambda x: x[0]), 
                              'Value' : table_export_raw.map(lambda x: x[1])}).set_index('Attribute')['Value'].to_dict()
table_export
# Out:
# {'ACTIVE FLOW WETTED MATERIAL - YIELD STRENGTH (KSI)': '41XX[80]',
#  'APPROXIMATE WEIGHT (LBS)': '650',
#  'CASING SIZE (IN)': '9-5/8',
#  'CASING WEIGHT RANGE (PPF)': '47-53.5',
#  'CERTIFICATION STATUS': 'ISO-V3[150-325F]',
#  'CONVEYANCE METHOD': 'TUBING',
#  'DIFFERENTIAL PRESSURE RATING (PSI)': '5000',
#  'DIFFERENTIAL RATING ISOLATED (PSI)': 'N/A',
#  'DIFFERENTIAL RATING PLUGGED (PSI)': 'N/A',
#  'DIFFERENTIAL RATING UNPLUGGED (PSI)': '5000',
#  'EXTERNAL WORKING PRESSURE (PSI) - EOEC AT SPECIFIED TEMP (F)': '5000[325]',
#  'I.D. (IN)': '2.925',
#  'I.D. - DRIFT (IN)': '2.867',
#  'I.D. - MIN. (IN)': '2.910',
#  'INTERNAL WORKING PRESSURE (PSI) - EOEC AT SPECIFIED TEMP (F)': '5000[325]',
#  'ISO QUALIFIED CASING ID': 'MAX API ID',
#  'LOWER THREAD CONNECTING - SIZE (IN), WT (PPF), TYPE, CONFIG': '3.500, 9.3, EUE, PIN',
#  'MAKE-UP LENGTH (IN)': '70',
#  'MATERIAL/ELASTOMERS': 'VITON, HNBR',
#  'MATERIAL/ELEMENTS': 'HNBR',
#  'MATERIAL/NON FLOW WETTED': '41XX, 8620',
#  'MATERIAL/O-RING(S)': 'VITON',
#  'MAX. CIRCULATION RATE PAST PACKER (BPM)': 'NA',
#  'MAX. DELTA T (F)': '175',
#  'MAX. RIH RATE (FPM)': 'NA',
#  'MAX. WORKING TEMPERATURE (DEG.F)': '325',
#  'MIN. WORKING TEMPERATURE (DEG.F)': '40',
#  'O.D. (IN)': '8.317',
#  'O.D. - MAX. (IN)': '8.319',
#  'OPERATIONS MANUAL': 'IT# 6842379',
#  'OVERALL LENGTH (IN)': '74',
#  'PACKER ENVELOPE POINTS ISOLATED - LOAD (LBS)': 'NA',
#  'PACKER ENVELOPE POINTS ISOLATED - PRESSURE (PSI)': 'NA',
#  'PACKER ENVELOPE POINTS PLUGGED - BELOW - LOAD (LBS)': 'NA',
#  'PACKER ENVELOPE POINTS PLUGGED - BELOW - PRESSURE (PSI)': 'NA',
#  'PACKER ENVELOPE POINTS UNPLUGGED - LOAD (LBS)': '72654, 72654, 50810, 0, -300000, -300000, -96280, 0',
#  'PACKER ENVELOPE POINTS UNPLUGGED - PRESSURE (PSI)': '-5000, 0, 5000, 5000, 5000, 0, -5000, -5000',
#  'QUALITY CONTROL GRADE': 'Q3',
#  'QUALITY CONTROL PLAN - QCP': 'CLG QCP-102817386',
#  'RETRIEVAL METHOD': 'STRAIGHT-PULL-RELEASE',
#  'SEAL DIAMETER (IN)': '3.500',
#  'SERVICE NACE (YES/NO)': 'YES',
#  'SETTING DIFFERENTIAL PRESSURE - RECOMMENDED (MIN)(PSI)': '3000',
#  'SETTING METHOD': 'HYDRAULIC',
#  'SETTING PRESSURE 1ST SHEAR (PSI)': '1000',
#  'SETTING PRESSURE SLIP ENGAGEMENT (PSI)': '1000',
#  'SHEAR RELEASE FORCE (LB)': '103792',
#  'TENSILE STRENGTH (LBS) - EOEC AT SPECIFIED TEMP (F)': '208000[325]',
#  'TORQUE CAPACITY - EOEC (FT-LBS)': 'N/A',
#  'UPPER THREAD CONNECTING - SIZE (IN), WT (PPF), TYPE, CONFIG': '3.500, 9.3, EUE, BOX'}

# %%
# Parsing mini attributes for IEA
independent_attributes = pd.read_excel(os.path.join(os.pardir, 'Mini attributes.xlsx'), sheet_name='Sheet1', header = 1)
independent_attributes.set_index(independent_attributes.columns[0], inplace = True)
independent_attributes.index.name = 'index'
independent_attributes['Attribute'] = independent_attributes.Attribute.str.strip()
independent_attributes['Definition'] = independent_attributes.Definition.str.strip()
independent_attributes
# Out:
#                                                Attribute  \
# index
# 1      ACTIVE FLOW WETTED MATERIAL - YIELD STRENGTH (...
# 2                                       CASING SIZE (IN)
# 3                              CASING WEIGHT RANGE (PPF)
# 4                                   CERTIFICATION STATUS
# 5                     DIFFERENTIAL PRESSURE RATING (PSI)
# 6      EXTERNAL WORKING PRESSURE (PSI) - EOEC AT SPEC...
# 7                                      I.D. - DRIFT (IN)
# 8      INTERNAL WORKING PRESSURE (PSI) - EOEC AT SPEC...
# 9      LOWER THREAD CONNECTING - SIZE (IN), WT (PPF),...
# 10                                     MATERIAL/ELEMENTS
# 11                                    MATERIAL/O-RING(S)
# 12                                      O.D. - MAX. (IN)
# 13                                 QUALITY CONTROL GRADE
# 14                            QUALITY CONTROL PLAN - QCP
# 15                                 SERVICE NACE (YES/NO)
# 16     SETTING DIFFERENTIAL PRESSURE - RECOMMENDED (M...
# 17                              SHEAR RELEASE FORCE (LB)
# 18     TENSILE STRENGTH (LBS) - EOEC AT SPECIFIED TEM...
# 19     UPPER THREAD CONNECTING - SIZE (IN), WT (PPF),...
#
#                                               Definition
# index
# 1      Component comes in direct contact with the dyn...
# 2                         Nominal completion casing size
# 3                      Nominal completion casing weights
# 4      ISO 14310 V6~V0 design validation grade for pa...
# 5      The maxium differential pressure across the el...
# 6      Max. allowable external pressure of the produc...
# 7               Drift ID using standard API tubing drift
# 8      Max. allowable internal pressure of the produc...
# 9               Thread connecion at the bottom of packer
# 10                                      Element compound
# 11                                       O-ring compound
# 12         OD of the largest metal component of a packer
# 13                3 different grade defined per API 11D1
# 14                         Customer quality control plan
# 15     If a packer type 1 components are manufactured...
# 16           Mini. differential pressure to set a packer
# 17     Nominal shear force required to activiate rele...
# 18     The Max. tension that can be pulled into a packer
# 19                 Thread connecion at the top of packer

# %%
# Parsing dataset

raw_df_data_dict = {}
files_converted = 0
files_not_converted = 0

for root, dirs, files in os.walk(EXTERNAL_PATH):
    if len(files) > 0:
        print('Converting .xlsx files from ', root)
        for file in files:
            if file[-5:] == '.xlsx':
                try:
                    print('Parsing file:', file)
                    file_name = file[:-5]                    
                    tab_name = file[:-8] 
                    table_export_raw = pd.read_excel(os.path.join(EXTERNAL_PATH, file),
                                                     sheet_name= 0, 
                                                     header=None,
                                                     na_values = na_values)[0].str.split(' = ')
                    raw_df_data_dict[file_name] = pd.DataFrame({
                        'Attribute' : table_export_raw.map(lambda x: x[0]), 
                        'Value' : table_export_raw.map(lambda x: x[1])}).set_index('Attribute')['Value'].to_dict()
                    
                    files_converted += 1
                except Exception as err:
                    print('Error with file: ', file, ' : ', err)
                    files_not_converted += 1
raw_df_data_dict
                
all_attributes_df = pd.DataFrame(data = list(raw_df_data_dict.values()), index = list(raw_df_data_dict.keys()))
all_attributes_df
# Out:
# Converting .xlsx files from  ..\Bluepack RH dataset
# Parsing file: 102041421_AB.xlsx
# Parsing file: 102043250_AF.xlsx
# Parsing file: 102055050_AC.xlsx
# Parsing file: 102055845_AC.xlsx
# Parsing file: 102103987_AG.xlsx
# Parsing file: 102684662_AF.xlsx
# Parsing file: 102689441_AD.xlsx
# Parsing file: 102689450_AE.xlsx
# Parsing file: 102727939_AC.xlsx
# Parsing file: 102731362_AD.xlsx
# Parsing file: 102731377_AD.xlsx
# Parsing file: 102740546_AB.xlsx
# Parsing file: 102743317_AD.xlsx
# Parsing file: 102743322_AD.xlsx
# Parsing file: 102749502_AG.xlsx
# Parsing file: 102750404_AB.xlsx
# Parsing file: 102779363_AD.xlsx
# Parsing file: 102792167_AE.xlsx
# Parsing file: 102825695_AC.xlsx
# Parsing file: 102825802_AC.xlsx
# Parsing file: 102832618_AD.xlsx
# Parsing file: 102832791_AD.xlsx
# Parsing file: 102849523_AC.xlsx
# Parsing file: 102850902_AD.xlsx
# Parsing file: 102869425_AC.xlsx
# Parsing file: 102878398_AD.xlsx
# Parsing file: 102883107_AC.xlsx
# Parsing file: 102888683_AD.xlsx
# Parsing file: 102891301_AD.xlsx
# Parsing file: 102894197_AE.xlsx
# Parsing file: 102894287_AD.xlsx
# Parsing file: 102908853_AC.xlsx
# Parsing file: 102908857_AC.xlsx
# Parsing file: 102932126_AD.xlsx
# Parsing file: 102939595_AC.xlsx
# Parsing file: 102947913_AC.xlsx
# Parsing file: 102961957_AB.xlsx
# Parsing file: 102966607_AA.xlsx
# Parsing file: 102991381_AH.xlsx
# Parsing file: 103000049_AA.xlsx
# Parsing file: 103007709_AB.xlsx
# Parsing file: 103015422_AB.xlsx
# Parsing file: 103062560_AG.xlsx
# Parsing file: 103068560_AB.xlsx
# Parsing file: 103096024_AB.xlsx
# Parsing file: 103120205_AB.xlsx
# Parsing file: 103129811_AB.xlsx
# Parsing file: 103144015_AA.xlsx
# Parsing file: 103171943_AB.xlsx
# Parsing file: 103180915_AB.xlsx
# Parsing file: 103183591_AD.xlsx
# Parsing file: 103183602_AC.xlsx
# Parsing file: 103197963_AB.xlsx
# Parsing file: 103202448_AB.xlsx
# Parsing file: 103207686_AB.xlsx
# Parsing file: 103209720_AB.xlsx
# Parsing file: 103210361_AA.xlsx
# Parsing file: 103211443_AC.xlsx
# Parsing file: 103231270_AA.xlsx
# Parsing file: 103231271_AC.xlsx
# Parsing file: 103231275_AA.xlsx
# Parsing file: 103231276_AB.xlsx
# Parsing file: 103232076_AA.xlsx
# Parsing file: 103232088_AA.xlsx
# Parsing file: 103232089_AA.xlsx
# Parsing file: 103232093_AA.xlsx
# Parsing file: ~$102041421_AB.xlsx
# Error with file:  ~$102041421_AB.xlsx  :  [Errno 13] Permission denied: '..\\Bluepack RH dataset\\~$102041421_AB.xlsx'
#              ACTIVE FLOW WETTED MATERIAL - YIELD STRENGTH (KSI)  \
# 102041421_AB                                            9CR[80]
# 102043250_AF                                           41XX[80]
# 102055050_AC                                           41XX[80]
# 102055845_AC                                           41XX[80]
# 102103987_AG                                           41XX[80]
# ...                                                         ...
# 103231276_AB                                           13CR[80]
# 103232076_AA                                           41XX[80]
# 103232088_AA                                           41XX[80]
# 103232089_AA                                           41XX[80]
# 103232093_AA                                           41XX[80]
#
#              APPROXIMATE WEIGHT (LBS) CASING SIZE (IN)  \
# 102041421_AB                      205                7
# 102043250_AF                      205            6-5/8
# 102055050_AC                      205                7
# 102055845_AC                      205                7
# 102103987_AG                      110            4-1/2
# ...                               ...              ...
# 103231276_AB                      550            9-5/8
# 103232076_AA                      150            5-1/2
# 103232088_AA                      110            4-1/2
# 103232089_AA                      210                7
# 103232093_AA                      200                7
#
#              CASING WEIGHT RANGE (PPF)       CERTIFICATION STATUS  \
# 102041421_AB                     23-26           ISO-V3[150-325F]
# 102043250_AF                     24-28  ISO-V3[150-325F, 40-235F]
# 102055050_AC                     26-32           ISO-V3[150-325F]
# 102055845_AC                     23-26           ISO-V3[150-325F]
# 102103987_AG                  9.5-13.5           ISO-V3[150-325F]
# ...                                ...                        ...
# 103231276_AB                     40-47           ISO-V3[150-350F]
# 103232076_AA                     17-23           ISO-V3[150-325F]
# 103232088_AA                  9.5-13.5           ISO-V3[150-325F]
# 103232089_AA                     23-29           ISO-V3[150-325F]
# 103232093_AA                     26-32           ISO-V3[150-325F]
#
#              CONVEYANCE METHOD DIFFERENTIAL PRESSURE RATING (PSI)  \
# 102041421_AB            TUBING                               5000
# 102043250_AF            TUBING                               5000
# 102055050_AC            TUBING                               5000
# 102055845_AC            TUBING                               5000
# 102103987_AG            TUBING                               5000
# ...                        ...                                ...
# 103231276_AB            TUBING                               5000
# 103232076_AA            TUBING                               5000
# 103232088_AA            TUBING                               5000
# 103232089_AA            TUBING                               5000
# 103232093_AA            TUBING                               5000
#
#              DIFFERENTIAL RATING ISOLATED (PSI)  \
# 102041421_AB                                N/A
# 102043250_AF                               5000
# 102055050_AC                                N/A
# 102055845_AC                                N/A
# 102103987_AG                                N/A
# ...                                         ...
# 103231276_AB                                N/A
# 103232076_AA                                N/A
# 103232088_AA                                 NA
# 103232089_AA                                N/A
# 103232093_AA                                N/A
#
#              DIFFERENTIAL RATING PLUGGED (PSI)  \
# 102041421_AB                               N/A
# 102043250_AF                               N/A
# 102055050_AC                               N/A
# 102055845_AC                               N/A
# 102103987_AG                               N/A
# ...                                        ...
# 103231276_AB                               N/A
# 103232076_AA                               N/A
# 103232088_AA                                NA
# 103232089_AA                               N/A
# 103232093_AA                               N/A
#
#              DIFFERENTIAL RATING UNPLUGGED (PSI)  ... SEAL DIAMETER (IN)  \
# 102041421_AB                                5000  ...                4.5
# 102043250_AF                                5000  ...              3.500
# 102055050_AC                                5000  ...              4.500
# 102055845_AC                                5000  ...              4.500
# 102103987_AG                                5000  ...              2.375
# ...                                          ...  ...                ...
# 103231276_AB                                5000  ...              4.500
# 103232076_AA                                5000  ...              2.875
# 103232088_AA                                5000  ...              2.375
# 103232089_AA                                5000  ...              2.875
# 103232093_AA                                5000  ...              3.500
#
#              SERVICE NACE (YES/NO)  \
# 102041421_AB                   YES
# 102043250_AF                   YES
# 102055050_AC                   YES
# 102055845_AC                   YES
# 102103987_AG                   YES
# ...                            ...
# 103231276_AB                   YES
# 103232076_AA                   YES
# 103232088_AA                   YES
# 103232089_AA                   YES
# 103232093_AA                   YES
#
#              SETTING DIFFERENTIAL PRESSURE - RECOMMENDED (MIN)(PSI)  \
# 102041421_AB                                               3000
# 102043250_AF                                               3000
# 102055050_AC                                               3000
# 102055845_AC                                               3000
# 102103987_AG                                               2500
# ...                                                         ...
# 103231276_AB                                               3000
# 103232076_AA                                               2500
# 103232088_AA                                               2500
# 103232089_AA                                               3000
# 103232093_AA                                               3000
#
#              SETTING METHOD SETTING PRESSURE 1ST SHEAR (PSI)  \
# 102041421_AB      HYDRAULIC                             1802
# 102043250_AF      HYDRAULIC                             1990
# 102055050_AC      HYDRAULIC                             1802
# 102055845_AC      HYDRAULIC                             1802
# 102103987_AG      HYDRAULIC                              780
# ...                     ...                              ...
# 103231276_AB      HYDRAULIC                             1465
# 103232076_AA      HYDRAULIC                             1504
# 103232088_AA      HYDRAULIC                              780
# 103232089_AA      HYDRAULIC                             1126
# 103232093_AA      HYDRAULIC                             1126
#
#              SETTING PRESSURE SLIP ENGAGEMENT (PSI) SHEAR RELEASE FORCE (LB)  \
# 102041421_AB                                   1802                   103792
# 102043250_AF                                   1990                   116766
# 102055050_AC                                   1802                   103792
# 102055845_AC                                   1802                   103792
# 102103987_AG                                   1310                    77844
# ...                                             ...                      ...
# 103231276_AB                                   1465                   116766
# 103232076_AA                                   1504                    77844
# 103232088_AA                                   1310                    77844
# 103232089_AA                                   1126                   103792
# 103232093_AA                                   1126                   103792
#
#              TENSILE STRENGTH (LBS) - EOEC AT SPECIFIED TEMP (F)  \
# 102041421_AB                                        208000[325]
# 102043250_AF                                        208000[325]
# 102055050_AC                                        208000[325]
# 102055845_AC                                        208000[325]
# 102103987_AG                                        101000[325]
# ...                                                         ...
# 103231276_AB                                        265075[350]
# 103232076_AA                                        144000[325]
# 103232088_AA                                        101000[325]
# 103232089_AA                                        144000[325]
# 103232093_AA                                        208000[325]
#
#              TORQUE CAPACITY - EOEC (FT-LBS)  \
# 102041421_AB                             N/A
# 102043250_AF                             N/A
# 102055050_AC                             N/A
# 102055845_AC                             N/A
# 102103987_AG                             N/A
# ...                                      ...
# 103231276_AB                             N/A
# 103232076_AA                             N/A
# 103232088_AA                              NA
# 103232089_AA                             N/A
# 103232093_AA                             N/A
#
#              UPPER THREAD CONNECTING - SIZE (IN), WT (PPF), TYPE, CONFIG
# 102041421_AB                          4.460, 12, STUB ACME, PIN
# 102043250_AF                               3.500, 9.3, EUE, BOX
# 102055050_AC                             4.500, 12.75, EUE, BOX
# 102055845_AC                             4.500, 12.75, EUE, BOX
# 102103987_AG                               2.375, 4.7, EUE, BOX
# ...                                                         ...
# 103231276_AB                          4.500, 12.6, VAM TOP, PIN
# 103232076_AA               2.875, 6.4, TENARIS HYDRIL BLUE, BOX
# 103232088_AA               2.375, 4.6, TENARIS HYDRIL BLUE, BOX
# 103232089_AA               2.875, 6.4, TENARIS HYDRIL BLUE, BOX
# 103232093_AA               3.500, 9.2, TENARIS HYDRIL BLUE, BOX
#
# [66 rows x 50 columns]

# %%
# Data cleaning and preparation
all_attributes_df = all_attributes_df.applymap(lambda x: np.NaN if x in ['N/A', 'NA', 'TBD', 'AMBIENT'] else x)
all_attributes_df.head()
# Out:
#              ACTIVE FLOW WETTED MATERIAL - YIELD STRENGTH (KSI)  \
# 102041421_AB                                            9CR[80]
# 102043250_AF                                           41XX[80]
# 102055050_AC                                           41XX[80]
# 102055845_AC                                           41XX[80]
# 102103987_AG                                           41XX[80]
#
#              APPROXIMATE WEIGHT (LBS) CASING SIZE (IN)  \
# 102041421_AB                      205                7
# 102043250_AF                      205            6-5/8
# 102055050_AC                      205                7
# 102055845_AC                      205                7
# 102103987_AG                      110            4-1/2
#
#              CASING WEIGHT RANGE (PPF)       CERTIFICATION STATUS  \
# 102041421_AB                     23-26           ISO-V3[150-325F]
# 102043250_AF                     24-28  ISO-V3[150-325F, 40-235F]
# 102055050_AC                     26-32           ISO-V3[150-325F]
# 102055845_AC                     23-26           ISO-V3[150-325F]
# 102103987_AG                  9.5-13.5           ISO-V3[150-325F]
#
#              CONVEYANCE METHOD DIFFERENTIAL PRESSURE RATING (PSI)  \
# 102041421_AB            TUBING                               5000
# 102043250_AF            TUBING                               5000
# 102055050_AC            TUBING                               5000
# 102055845_AC            TUBING                               5000
# 102103987_AG            TUBING                               5000
#
#              DIFFERENTIAL RATING ISOLATED (PSI)  \
# 102041421_AB                                NaN
# 102043250_AF                               5000
# 102055050_AC                                NaN
# 102055845_AC                                NaN
# 102103987_AG                                NaN
#
#               DIFFERENTIAL RATING PLUGGED (PSI)  \
# 102041421_AB                                NaN
# 102043250_AF                                NaN
# 102055050_AC                                NaN
# 102055845_AC                                NaN
# 102103987_AG                                NaN
#
#              DIFFERENTIAL RATING UNPLUGGED (PSI)  ... SEAL DIAMETER (IN)  \
# 102041421_AB                                5000  ...                4.5
# 102043250_AF                                5000  ...              3.500
# 102055050_AC                                5000  ...              4.500
# 102055845_AC                                5000  ...              4.500
# 102103987_AG                                5000  ...              2.375
#
#              SERVICE NACE (YES/NO)  \
# 102041421_AB                   YES
# 102043250_AF                   YES
# 102055050_AC                   YES
# 102055845_AC                   YES
# 102103987_AG                   YES
#
#              SETTING DIFFERENTIAL PRESSURE - RECOMMENDED (MIN)(PSI)  \
# 102041421_AB                                               3000
# 102043250_AF                                               3000
# 102055050_AC                                               3000
# 102055845_AC                                               3000
# 102103987_AG                                               2500
#
#              SETTING METHOD SETTING PRESSURE 1ST SHEAR (PSI)  \
# 102041421_AB      HYDRAULIC                             1802
# 102043250_AF      HYDRAULIC                             1990
# 102055050_AC      HYDRAULIC                             1802
# 102055845_AC      HYDRAULIC                             1802
# 102103987_AG      HYDRAULIC                              780
#
#              SETTING PRESSURE SLIP ENGAGEMENT (PSI) SHEAR RELEASE FORCE (LB)  \
# 102041421_AB                                   1802                   103792
# 102043250_AF                                   1990                   116766
# 102055050_AC                                   1802                   103792
# 102055845_AC                                   1802                   103792
# 102103987_AG                                   1310                    77844
#
#              TENSILE STRENGTH (LBS) - EOEC AT SPECIFIED TEMP (F)  \
# 102041421_AB                                        208000[325]
# 102043250_AF                                        208000[325]
# 102055050_AC                                        208000[325]
# 102055845_AC                                        208000[325]
# 102103987_AG                                        101000[325]
#
#              TORQUE CAPACITY - EOEC (FT-LBS)  \
# 102041421_AB                             NaN
# 102043250_AF                             NaN
# 102055050_AC                             NaN
# 102055845_AC                             NaN
# 102103987_AG                             NaN
#
#              UPPER THREAD CONNECTING - SIZE (IN), WT (PPF), TYPE, CONFIG
# 102041421_AB                          4.460, 12, STUB ACME, PIN
# 102043250_AF                               3.500, 9.3, EUE, BOX
# 102055050_AC                             4.500, 12.75, EUE, BOX
# 102055845_AC                             4.500, 12.75, EUE, BOX
# 102103987_AG                               2.375, 4.7, EUE, BOX
#
# [5 rows x 50 columns]

# %%
all_attributes_df_clean = all_attributes_df
all_attributes_df_clean['APPROXIMATE WEIGHT (LBS)'] = all_attributes_df['APPROXIMATE WEIGHT (LBS)'].astype(float)
all_attributes_df_clean['DIFFERENTIAL PRESSURE RATING (PSI)'] = all_attributes_df['DIFFERENTIAL PRESSURE RATING (PSI)'].astype(float)
all_attributes_df_clean['DIFFERENTIAL RATING ISOLATED (PSI)'] = all_attributes_df['DIFFERENTIAL RATING ISOLATED (PSI)'].astype(float)
all_attributes_df_clean['DIFFERENTIAL RATING PLUGGED (PSI)'] = all_attributes_df['DIFFERENTIAL RATING PLUGGED (PSI)'].astype(float)
all_attributes_df_clean['DIFFERENTIAL RATING UNPLUGGED (PSI)'] = all_attributes_df['DIFFERENTIAL RATING UNPLUGGED (PSI)'].astype(float)
all_attributes_df_clean['I.D. (IN)'] = all_attributes_df['I.D. (IN)'].astype(float)
all_attributes_df_clean['I.D. - DRIFT (IN)'] = all_attributes_df['I.D. - DRIFT (IN)'].astype(float)
all_attributes_df_clean['I.D. - MIN. (IN)'] = all_attributes_df['I.D. - MIN. (IN)'].astype(float)
all_attributes_df_clean['MAKE-UP LENGTH (IN)'] = all_attributes_df['MAKE-UP LENGTH (IN)'].astype(float)
all_attributes_df_clean['MAX. DELTA T (F)'] = all_attributes_df['MAX. DELTA T (F)'].astype(float)
all_attributes_df_clean['MAX. CIRCULATION RATE PAST PACKER (BPM)'] = all_attributes_df['MAX. CIRCULATION RATE PAST PACKER (BPM)'].astype(float)
all_attributes_df_clean['MAX. RIH RATE (FPM)'] = all_attributes_df['MAX. RIH RATE (FPM)'].astype(float)
all_attributes_df_clean['MAX. WORKING TEMPERATURE (DEG.F)'] = all_attributes_df['MAX. WORKING TEMPERATURE (DEG.F)'].astype(float)
all_attributes_df_clean['MIN. WORKING TEMPERATURE (DEG.F)'] = all_attributes_df['MIN. WORKING TEMPERATURE (DEG.F)'].astype(float)
all_attributes_df_clean['O.D. (IN)'] = all_attributes_df['O.D. (IN)'].astype(float)
all_attributes_df_clean['O.D. - MAX. (IN)'] = all_attributes_df['O.D. - MAX. (IN)'].astype(float)
all_attributes_df_clean['OVERALL LENGTH (IN)'] = all_attributes_df['OVERALL LENGTH (IN)'].astype(float)
all_attributes_df_clean['MAX. CIRCULATION RATE PAST PACKER (BPM)'] = all_attributes_df['MAX. CIRCULATION RATE PAST PACKER (BPM)'].astype(float)
all_attributes_df_clean['MAX. CIRCULATION RATE PAST PACKER (BPM)'] = all_attributes_df['MAX. CIRCULATION RATE PAST PACKER (BPM)'].astype(float)

all_attributes_df_clean['SEAL DIAMETER (IN)'] = all_attributes_df['SEAL DIAMETER (IN)'].astype(float)
all_attributes_df_clean['SETTING DIFFERENTIAL PRESSURE - RECOMMENDED (MIN)(PSI)'] = all_attributes_df['SETTING DIFFERENTIAL PRESSURE - RECOMMENDED (MIN)(PSI)'].astype(float)
all_attributes_df_clean['SETTING PRESSURE 1ST SHEAR (PSI)'] = all_attributes_df['SETTING PRESSURE 1ST SHEAR (PSI)'].astype(float)
all_attributes_df_clean['SETTING PRESSURE SLIP ENGAGEMENT (PSI)'] = all_attributes_df['SETTING PRESSURE SLIP ENGAGEMENT (PSI)'].astype(float)
all_attributes_df_clean['SHEAR RELEASE FORCE (LB)'] = all_attributes_df['SHEAR RELEASE FORCE (LB)'].str.replace(',', '').astype(float)

# %%
all_attributes_df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 66 entries, 102041421_AB to 103232093_AA
# Data columns (total 50 columns):
# ACTIVE FLOW WETTED MATERIAL - YIELD STRENGTH (KSI)              66 non-null object
# APPROXIMATE WEIGHT (LBS)                                        66 non-null float64
# CASING SIZE (IN)                                                66 non-null object
# CASING WEIGHT RANGE (PPF)                                       66 non-null object
# CERTIFICATION STATUS                                            64 non-null object
# CONVEYANCE METHOD                                               66 non-null object
# DIFFERENTIAL PRESSURE RATING (PSI)                              64 non-null float64
# DIFFERENTIAL RATING ISOLATED (PSI)                              4 non-null float64
# DIFFERENTIAL RATING PLUGGED (PSI)                               0 non-null float64
# DIFFERENTIAL RATING UNPLUGGED (PSI)                             64 non-null float64
# EXTERNAL WORKING PRESSURE (PSI) - EOEC AT SPECIFIED TEMP (F)    66 non-null object
# I.D. (IN)                                                       66 non-null float64
# I.D. - DRIFT (IN)                                               66 non-null float64
# I.D. - MIN. (IN)                                                66 non-null float64
# INTERNAL WORKING PRESSURE (PSI) - EOEC AT SPECIFIED TEMP (F)    66 non-null object
# ISO QUALIFIED CASING ID                                         64 non-null object
# LOWER THREAD CONNECTING - SIZE (IN), WT (PPF), TYPE, CONFIG     66 non-null object
# MAKE-UP LENGTH (IN)                                             65 non-null float64
# MATERIAL/ELASTOMERS                                             66 non-null object
# MATERIAL/ELEMENTS                                               64 non-null object
# MATERIAL/NON FLOW WETTED                                        66 non-null object
# MATERIAL/O-RING(S)                                              66 non-null object
# MAX. CIRCULATION RATE PAST PACKER (BPM)                         11 non-null float64
# MAX. DELTA T (F)                                                65 non-null float64
# MAX. RIH RATE (FPM)                                             11 non-null float64
# MAX. WORKING TEMPERATURE (DEG.F)                                65 non-null float64
# MIN. WORKING TEMPERATURE (DEG.F)                                65 non-null float64
# O.D. (IN)                                                       66 non-null float64
# O.D. - MAX. (IN)                                                66 non-null float64
# OPERATIONS MANUAL                                               66 non-null object
# OVERALL LENGTH (IN)                                             66 non-null float64
# PACKER ENVELOPE POINTS ISOLATED - LOAD (LBS)                    0 non-null float64
# PACKER ENVELOPE POINTS ISOLATED - PRESSURE (PSI)                0 non-null float64
# PACKER ENVELOPE POINTS PLUGGED - BELOW - LOAD (LBS)             0 non-null float64
# PACKER ENVELOPE POINTS PLUGGED - BELOW - PRESSURE (PSI)         0 non-null float64
# PACKER ENVELOPE POINTS UNPLUGGED - LOAD (LBS)                   64 non-null object
# PACKER ENVELOPE POINTS UNPLUGGED - PRESSURE (PSI)               64 non-null object
# QUALITY CONTROL GRADE                                           64 non-null object
# QUALITY CONTROL PLAN - QCP                                      66 non-null object
# RETRIEVAL METHOD                                                66 non-null object
# SEAL DIAMETER (IN)                                              64 non-null float64
# SERVICE NACE (YES/NO)                                           66 non-null object
# SETTING DIFFERENTIAL PRESSURE - RECOMMENDED (MIN)(PSI)          66 non-null float64
# SETTING METHOD                                                  66 non-null object
# SETTING PRESSURE 1ST SHEAR (PSI)                                66 non-null float64
# SETTING PRESSURE SLIP ENGAGEMENT (PSI)                          66 non-null float64
# SHEAR RELEASE FORCE (LB)                                        66 non-null float64
# TENSILE STRENGTH (LBS) - EOEC AT SPECIFIED TEMP (F)             66 non-null object
# TORQUE CAPACITY - EOEC (FT-LBS)                                 0 non-null float64
# UPPER THREAD CONNECTING - SIZE (IN), WT (PPF), TYPE, CONFIG     66 non-null object
# dtypes: float64(27), object(23)
# memory usage: 26.3+ KB

# %%
all_attributes_df_clean.to_csv('all_attributes_df_clean.csv')
all_attributes_df_clean.describe()
# Out:
#        APPROXIMATE WEIGHT (LBS)  DIFFERENTIAL PRESSURE RATING (PSI)  \
# count                 66.000000                              64.000
# mean                 369.696970                            5015.625
# std                  209.368131                             125.000
# min                  110.000000                            5000.000
# 25%                  200.000000                            5000.000
# 50%                  210.000000                            5000.000
# 75%                  640.000000                            5000.000
# max                  680.000000                            6000.000
#
#        DIFFERENTIAL RATING ISOLATED (PSI)  DIFFERENTIAL RATING PLUGGED (PSI)  \
# count                                 4.0                                0.0
# mean                               5000.0                                NaN
# std                                   0.0                                NaN
# min                                5000.0                                NaN
# 25%                                5000.0                                NaN
# 50%                                5000.0                                NaN
# 75%                                5000.0                                NaN
# max                                5000.0                                NaN
#
#        DIFFERENTIAL RATING UNPLUGGED (PSI)  I.D. (IN)  I.D. - DRIFT (IN)  \
# count                               64.000  66.000000          66.000000
# mean                              5015.625   3.158667           3.097742
# std                                125.000   0.751842           0.740321
# min                               5000.000   1.946000           1.901000
# 25%                               5000.000   2.919000           2.867000
# 50%                               5000.000   2.925000           2.867000
# 75%                               5000.000   3.890000           3.833000
# max                               6000.000   4.873000           4.767000
#
#        I.D. - MIN. (IN)  MAKE-UP LENGTH (IN)  \
# count         66.000000            65.000000
# mean           3.139773            62.784615
# std            0.752900             7.018930
# min            1.931000            49.000000
# 25%            2.881000            56.000000
# 50%            2.910000            65.000000
# 75%            3.875000            70.000000
# max            4.858000            82.000000
#
#        MAX. CIRCULATION RATE PAST PACKER (BPM)  ...  \
# count                                     11.0  ...
# mean                                       4.0  ...
# std                                        0.0  ...
# min                                        4.0  ...
# 25%                                        4.0  ...
# 50%                                        4.0  ...
# 75%                                        4.0  ...
# max                                        4.0  ...
#
#        PACKER ENVELOPE POINTS ISOLATED - LOAD (LBS)  \
# count                                           0.0
# mean                                            NaN
# std                                             NaN
# min                                             NaN
# 25%                                             NaN
# 50%                                             NaN
# 75%                                             NaN
# max                                             NaN
#
#        PACKER ENVELOPE POINTS ISOLATED - PRESSURE (PSI)  \
# count                                               0.0
# mean                                                NaN
# std                                                 NaN
# min                                                 NaN
# 25%                                                 NaN
# 50%                                                 NaN
# 75%                                                 NaN
# max                                                 NaN
#
#        PACKER ENVELOPE POINTS PLUGGED - BELOW - LOAD (LBS)  \
# count                                                0.0
# mean                                                 NaN
# std                                                  NaN
# min                                                  NaN
# 25%                                                  NaN
# 50%                                                  NaN
# 75%                                                  NaN
# max                                                  NaN
#
#        PACKER ENVELOPE POINTS PLUGGED - BELOW - PRESSURE (PSI)  \
# count                                                0.0
# mean                                                 NaN
# std                                                  NaN
# min                                                  NaN
# 25%                                                  NaN
# 50%                                                  NaN
# 75%                                                  NaN
# max                                                  NaN
#
#        SEAL DIAMETER (IN)  \
# count           64.000000
# mean             3.699219
# std              0.802315
# min              2.375000
# 25%              3.500000
# 50%              3.500000
# 75%              4.500000
# max              5.500000
#
#        SETTING DIFFERENTIAL PRESSURE - RECOMMENDED (MIN)(PSI)  \
# count                                          66.000000
# mean                                         2953.030303
# std                                           150.097094
# min                                          2400.000000
# 25%                                          3000.000000
# 50%                                          3000.000000
# 75%                                          3000.000000
# max                                          3000.000000
#
#        SETTING PRESSURE 1ST SHEAR (PSI)  \
# count                         66.000000
# mean                        1278.666667
# std                          330.533570
# min                          780.000000
# 25%                         1000.000000
# 50%                         1126.000000
# 75%                         1465.000000
# max                         1990.000000
#
#        SETTING PRESSURE SLIP ENGAGEMENT (PSI)  SHEAR RELEASE FORCE (LB)  \
# count                               66.000000                 66.000000
# mean                              1294.727273             104974.606061
# std                                318.385617               9848.136242
# min                               1000.000000              77844.000000
# 25%                               1000.000000             103792.000000
# 50%                               1126.000000             103792.000000
# 75%                               1465.000000             103792.000000
# max                               1990.000000             129740.000000
#
#        TORQUE CAPACITY - EOEC (FT-LBS)
# count                              0.0
# mean                               NaN
# std                                NaN
# min                                NaN
# 25%                                NaN
# 50%                                NaN
# 75%                                NaN
# max                                NaN
#
# [8 rows x 27 columns]

# %%
independent_attributes_df =  all_attributes_df_clean[independent_attributes.Attribute]
independent_attributes_df.head()
# Out:
#              ACTIVE FLOW WETTED MATERIAL - YIELD STRENGTH (KSI)  \
# 102041421_AB                                            9CR[80]
# 102043250_AF                                           41XX[80]
# 102055050_AC                                           41XX[80]
# 102055845_AC                                           41XX[80]
# 102103987_AG                                           41XX[80]
#
#              CASING SIZE (IN) CASING WEIGHT RANGE (PPF)  \
# 102041421_AB                7                     23-26
# 102043250_AF            6-5/8                     24-28
# 102055050_AC                7                     26-32
# 102055845_AC                7                     23-26
# 102103987_AG            4-1/2                  9.5-13.5
#
#                    CERTIFICATION STATUS  DIFFERENTIAL PRESSURE RATING (PSI)  \
# 102041421_AB           ISO-V3[150-325F]                              5000.0
# 102043250_AF  ISO-V3[150-325F, 40-235F]                              5000.0
# 102055050_AC           ISO-V3[150-325F]                              5000.0
# 102055845_AC           ISO-V3[150-325F]                              5000.0
# 102103987_AG           ISO-V3[150-325F]                              5000.0
#
#              EXTERNAL WORKING PRESSURE (PSI) - EOEC AT SPECIFIED TEMP (F)  \
# 102041421_AB                                          5000[325]
# 102043250_AF                                          5000[325]
# 102055050_AC                                          5000[325]
# 102055845_AC                                          5000[325]
# 102103987_AG                                          5000[325]
#
#               I.D. - DRIFT (IN)  \
# 102041421_AB              3.833
# 102043250_AF              2.867
# 102055050_AC              3.833
# 102055845_AC              3.833
# 102103987_AG              1.901
#
#              INTERNAL WORKING PRESSURE (PSI) - EOEC AT SPECIFIED TEMP (F)  \
# 102041421_AB                                          5000[325]
# 102043250_AF                                          5000[325]
# 102055050_AC                                          5000[325]
# 102055845_AC                                          5000[325]
# 102103987_AG                                          5000[325]
#
#              LOWER THREAD CONNECTING - SIZE (IN), WT (PPF), TYPE, CONFIG  \
# 102041421_AB                          4.460, 12, STUB ACME, PIN
# 102043250_AF                               3.500, 9.3, EUE, PIN
# 102055050_AC                             4.500, 12.75, EUE, PIN
# 102055845_AC                             4.500, 12.75, EUE, PIN
# 102103987_AG                               2.375, 4.7, EUE, PIN
#
#              MATERIAL/ELEMENTS MATERIAL/O-RING(S)  O.D. - MAX. (IN)  \
# 102041421_AB              HNBR              VITON             6.091
# 102043250_AF              HNBR              VITON             5.606
# 102055050_AC              HNBR              VITON             5.909
# 102055845_AC              HNBR              VITON             6.091
# 102103987_AG              HNBR              VITON             3.750
#
#              QUALITY CONTROL GRADE QUALITY CONTROL PLAN - QCP  \
# 102041421_AB                    Q3              QCP-101792794
# 102043250_AF                    Q3          CLG QCP-102817386
# 102055050_AC                    Q3          CLG QCP-102817386
# 102055845_AC                    Q3          CLG QCP-102817386
# 102103987_AG                    Q3          CLG QCP-102817386
#
#              SERVICE NACE (YES/NO)  \
# 102041421_AB                   YES
# 102043250_AF                   YES
# 102055050_AC                   YES
# 102055845_AC                   YES
# 102103987_AG                   YES
#
#               SETTING DIFFERENTIAL PRESSURE - RECOMMENDED (MIN)(PSI)  \
# 102041421_AB                                             3000.0
# 102043250_AF                                             3000.0
# 102055050_AC                                             3000.0
# 102055845_AC                                             3000.0
# 102103987_AG                                             2500.0
#
#               SHEAR RELEASE FORCE (LB)  \
# 102041421_AB                  103792.0
# 102043250_AF                  116766.0
# 102055050_AC                  103792.0
# 102055845_AC                  103792.0
# 102103987_AG                   77844.0
#
#              TENSILE STRENGTH (LBS) - EOEC AT SPECIFIED TEMP (F)  \
# 102041421_AB                                        208000[325]
# 102043250_AF                                        208000[325]
# 102055050_AC                                        208000[325]
# 102055845_AC                                        208000[325]
# 102103987_AG                                        101000[325]
#
#              UPPER THREAD CONNECTING - SIZE (IN), WT (PPF), TYPE, CONFIG
# 102041421_AB                          4.460, 12, STUB ACME, PIN
# 102043250_AF                               3.500, 9.3, EUE, BOX
# 102055050_AC                             4.500, 12.75, EUE, BOX
# 102055845_AC                             4.500, 12.75, EUE, BOX
# 102103987_AG                               2.375, 4.7, EUE, BOX

# %%
independent_attributes_df.info()
independent_attributes_df.to_csv('independent_attributes_df.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 66 entries, 102041421_AB to 103232093_AA
# Data columns (total 19 columns):
# ACTIVE FLOW WETTED MATERIAL - YIELD STRENGTH (KSI)              66 non-null object
# CASING SIZE (IN)                                                66 non-null object
# CASING WEIGHT RANGE (PPF)                                       66 non-null object
# CERTIFICATION STATUS                                            64 non-null object
# DIFFERENTIAL PRESSURE RATING (PSI)                              64 non-null float64
# EXTERNAL WORKING PRESSURE (PSI) - EOEC AT SPECIFIED TEMP (F)    66 non-null object
# I.D. - DRIFT (IN)                                               66 non-null float64
# INTERNAL WORKING PRESSURE (PSI) - EOEC AT SPECIFIED TEMP (F)    66 non-null object
# LOWER THREAD CONNECTING - SIZE (IN), WT (PPF), TYPE, CONFIG     66 non-null object
# MATERIAL/ELEMENTS                                               64 non-null object
# MATERIAL/O-RING(S)                                              66 non-null object
# O.D. - MAX. (IN)                                                66 non-null float64
# QUALITY CONTROL GRADE                                           64 non-null object
# QUALITY CONTROL PLAN - QCP                                      66 non-null object
# SERVICE NACE (YES/NO)                                           66 non-null object
# SETTING DIFFERENTIAL PRESSURE - RECOMMENDED (MIN)(PSI)          66 non-null float64
# SHEAR RELEASE FORCE (LB)                                        66 non-null float64
# TENSILE STRENGTH (LBS) - EOEC AT SPECIFIED TEMP (F)             66 non-null object
# UPPER THREAD CONNECTING - SIZE (IN), WT (PPF), TYPE, CONFIG     66 non-null object
# dtypes: float64(5), object(14)
# memory usage: 10.3+ KB

# %%
independent_attributes_df.describe()
# Out:
#        DIFFERENTIAL PRESSURE RATING (PSI)  I.D. - DRIFT (IN)  \
# count                              64.000          66.000000
# mean                             5015.625           3.097742
# std                               125.000           0.740321
# min                              5000.000           1.901000
# 25%                              5000.000           2.867000
# 50%                              5000.000           2.867000
# 75%                              5000.000           3.833000
# max                              6000.000           4.767000
#
#        O.D. - MAX. (IN)  \
# count         66.000000
# mean           6.885530
# std            1.453389
# min            3.750000
# 25%            5.909000
# 50%            6.091000
# 75%            8.465000
# max            9.344000
#
#        SETTING DIFFERENTIAL PRESSURE - RECOMMENDED (MIN)(PSI)  \
# count                                          66.000000
# mean                                         2953.030303
# std                                           150.097094
# min                                          2400.000000
# 25%                                          3000.000000
# 50%                                          3000.000000
# 75%                                          3000.000000
# max                                          3000.000000
#
#        SHEAR RELEASE FORCE (LB)
# count                 66.000000
# mean              104974.606061
# std                 9848.136242
# min                77844.000000
# 25%               103792.000000
# 50%               103792.000000
# 75%               103792.000000
# max               129740.000000

# %%
# Parsing complex columns
def parse_dep_params(old_ser_name, new_ser_names, df):
    old_ser = df[old_ser_name, 'value']
    new_sers = {new_ser_names[0]: old_ser.str.findall(r'.+\[').map(lambda x: x[0]).str.replace('[', '').str.replace(']', ''),
                new_ser_names[1]: old_ser.str.findall(r'\[\d+\]').map(lambda x: x[0]).str.replace('[', '').str.replace(']', '')}

    for ser_name, ser in new_sers.items():
        df[old_ser_name, ser_name] = ser
        
    df = df.sort_index(axis=1)
    return df


def parse_range_params(old_ser_name, new_ser_names, df):
    old_ser = df[old_ser_name, 'value']
    new_sers_arr = old_ser.str.split('-')
    
    new_sers = {}
    
    for i, ser_name in enumerate(new_ser_names):
        new_sers[ser_name] = new_sers_arr.map(lambda x: x[i])  
    
    for ser_name, ser in new_sers.items():
        df[old_ser_name, ser_name] = ser
        
    df = df.sort_index(axis=1)
    return df

def parse_list_params(old_ser_name, new_ser_names, df):
    old_ser = df[old_ser_name, 'value']
    new_sers_arr = old_ser.str.split(',')
    
    new_sers = {}
    
    for i, ser_name in enumerate(new_ser_names):
        new_sers[ser_name] = new_sers_arr.map(lambda x: x[i])    

    for ser_name, ser in new_sers.items():
        df[old_ser_name, ser_name] = ser
        
    df = df.sort_index(axis=1)
    return df

# %%
# Parsing complex columns
ia_df_parsed = independent_attributes_df.copy()
each_attr_cols = ['value']
old_cols = list(independent_attributes_df.columns)
new_cols = []
new_cols = pd.MultiIndex.from_product([old_cols, each_attr_cols], names=['attributes', 'values'])
ia_df_parsed.columns = new_cols

old_ser_name = 'ACTIVE FLOW WETTED MATERIAL - YIELD STRENGTH (KSI)'
new_ser_names = ['ACTIVE FLOW WETTED MATERIAL', 'YIELD STRENGTH (KSI)']
ia_df_parsed = parse_dep_params(old_ser_name, new_ser_names, ia_df_parsed)

old_ser_name = 'EXTERNAL WORKING PRESSURE (PSI) - EOEC AT SPECIFIED TEMP (F)'
new_ser_names = ['EXTERNAL WORKING PRESSURE (PSI)', 'EOEC AT SPECIFIED TEMP (F)']
ia_df_parsed.loc[ia_df_parsed[old_ser_name, 'value'] == '6000', (old_ser_name, 'value')] = '6000[0]'
ia_df_parsed = parse_dep_params(old_ser_name, new_ser_names, ia_df_parsed)

old_ser_name = 'INTERNAL WORKING PRESSURE (PSI) - EOEC AT SPECIFIED TEMP (F)'
new_ser_names = ['INTERNAL WORKING PRESSURE (PSI)', 'EOEC AT SPECIFIED TEMP (F)']
ia_df_parsed.loc[ia_df_parsed[old_ser_name, 'value'] == '7500', (old_ser_name, 'value')] = '7500[0]'
ia_df_parsed = parse_dep_params(old_ser_name, new_ser_names, ia_df_parsed)

old_ser_name = 'TENSILE STRENGTH (LBS) - EOEC AT SPECIFIED TEMP (F)'
new_ser_names = ['TENSILE STRENGTH (LBS)', 'EOEC AT SPECIFIED TEMP (F)']
ia_df_parsed.loc[ia_df_parsed[old_ser_name, 'value'] == '324,890', (old_ser_name, 'value')] = '324890[0]'
ia_df_parsed = parse_dep_params(old_ser_name, new_ser_names, ia_df_parsed)

old_ser_name = 'CASING WEIGHT RANGE (PPF)'
new_ser_names = ['MIN', 'MAX']
ia_df_parsed = parse_range_params(old_ser_name, new_ser_names, ia_df_parsed)

old_ser_name = 'UPPER THREAD CONNECTING - SIZE (IN), WT (PPF), TYPE, CONFIG'
new_ser_names = ['SIZE (IN)', 'WT (PPF)', 'TYPE', 'CONFIG']
ia_df_parsed = parse_list_params(old_ser_name, new_ser_names, ia_df_parsed)

old_ser_name = 'LOWER THREAD CONNECTING - SIZE (IN), WT (PPF), TYPE, CONFIG'
new_ser_names = ['SIZE (IN)', 'WT (PPF)', 'TYPE', 'CONFIG']
ia_df_parsed = parse_list_params(old_ser_name, new_ser_names, ia_df_parsed)

casing_inches = {'7':7, 
 '6-5/8':6.625, 
 '4-1/2':4.5, 
 '9-5/8':9.625, 
 '10-3/4':10.75, 
 '5-1/2':5.5}
ia_df_parsed['CASING SIZE (IN)', 'value'] = ia_df_parsed['CASING SIZE (IN)', 'value'].map(casing_inches)

service_nace = {'YES':True, 'NO':False}
ia_df_parsed['SERVICE NACE (YES/NO)', 'value'] = ia_df_parsed['SERVICE NACE (YES/NO)', 'value'].map(service_nace)

ia_df_parsed.head()
# Out:
# attributes   ACTIVE FLOW WETTED MATERIAL - YIELD STRENGTH (KSI)  \
# values                              ACTIVE FLOW WETTED MATERIAL
# 102041421_AB                                                9CR
# 102043250_AF                                               41XX
# 102055050_AC                                               41XX
# 102055845_AC                                               41XX
# 102103987_AG                                               41XX
#
# attributes                                  CASING SIZE (IN)  \
# values       YIELD STRENGTH (KSI)     value            value
# 102041421_AB                   80   9CR[80]            7.000
# 102043250_AF                   80  41XX[80]            6.625
# 102055050_AC                   80  41XX[80]            7.000
# 102055845_AC                   80  41XX[80]            7.000
# 102103987_AG                   80  41XX[80]            4.500
#
# attributes   CASING WEIGHT RANGE (PPF)                 \
# values                             MAX  MIN     value
# 102041421_AB                        26   23     23-26
# 102043250_AF                        28   24     24-28
# 102055050_AC                        32   26     26-32
# 102055845_AC                        26   23     23-26
# 102103987_AG                      13.5  9.5  9.5-13.5
#
# attributes         CERTIFICATION STATUS DIFFERENTIAL PRESSURE RATING (PSI)  \
# values                            value                              value
# 102041421_AB           ISO-V3[150-325F]                             5000.0
# 102043250_AF  ISO-V3[150-325F, 40-235F]                             5000.0
# 102055050_AC           ISO-V3[150-325F]                             5000.0
# 102055845_AC           ISO-V3[150-325F]                             5000.0
# 102103987_AG           ISO-V3[150-325F]                             5000.0
#
# attributes   EXTERNAL WORKING PRESSURE (PSI) - EOEC AT SPECIFIED TEMP (F)  \
# values                                         EOEC AT SPECIFIED TEMP (F)
# 102041421_AB                                                325
# 102043250_AF                                                325
# 102055050_AC                                                325
# 102055845_AC                                                325
# 102103987_AG                                                325
#
# attributes    ... SETTING DIFFERENTIAL PRESSURE - RECOMMENDED (MIN)(PSI)  \
# values        ...                                                  value
# 102041421_AB  ...                                             3000.0
# 102043250_AF  ...                                             3000.0
# 102055050_AC  ...                                             3000.0
# 102055845_AC  ...                                             3000.0
# 102103987_AG  ...                                             2500.0
#
# attributes   SHEAR RELEASE FORCE (LB)  \
# values                          value
# 102041421_AB                 103792.0
# 102043250_AF                 116766.0
# 102055050_AC                 103792.0
# 102055845_AC                 103792.0
# 102103987_AG                  77844.0
#
# attributes   TENSILE STRENGTH (LBS) - EOEC AT SPECIFIED TEMP (F)  \
# values                                EOEC AT SPECIFIED TEMP (F)
# 102041421_AB                                                325
# 102043250_AF                                                325
# 102055050_AC                                                325
# 102055845_AC                                                325
# 102103987_AG                                                325
#
# attributes                                        \
# values       TENSILE STRENGTH (LBS)        value
# 102041421_AB                 208000  208000[325]
# 102043250_AF                 208000  208000[325]
# 102055050_AC                 208000  208000[325]
# 102055845_AC                 208000  208000[325]
# 102103987_AG                 101000  101000[325]
#
# attributes   UPPER THREAD CONNECTING - SIZE (IN), WT (PPF), TYPE, CONFIG  \
# values                                                            CONFIG
# 102041421_AB                                                PIN
# 102043250_AF                                                BOX
# 102055050_AC                                                BOX
# 102055845_AC                                                BOX
# 102103987_AG                                                BOX
#
# attributes
# values       SIZE (IN)        TYPE WT (PPF)                      value
# 102041421_AB     4.460   STUB ACME       12  4.460, 12, STUB ACME, PIN
# 102043250_AF     3.500         EUE      9.3       3.500, 9.3, EUE, BOX
# 102055050_AC     4.500         EUE    12.75     4.500, 12.75, EUE, BOX
# 102055845_AC     4.500         EUE    12.75     4.500, 12.75, EUE, BOX
# 102103987_AG     2.375         EUE      4.7       2.375, 4.7, EUE, BOX
#
# [5 rows x 37 columns]

# %%
ia_df_parsed.describe()
# Out:
# attributes CASING SIZE (IN) DIFFERENTIAL PRESSURE RATING (PSI)  \
# values                value                              value
# count             66.000000                             64.000
# mean               7.964015                           5015.625
# std                1.561983                            125.000
# min                4.500000                           5000.000
# 25%                7.000000                           5000.000
# 50%                7.000000                           5000.000
# 75%                9.625000                           5000.000
# max               10.750000                           6000.000
#
# attributes I.D. - DRIFT (IN) O.D. - MAX. (IN)  \
# values                 value            value
# count              66.000000        66.000000
# mean                3.097742         6.885530
# std                 0.740321         1.453389
# min                 1.901000         3.750000
# 25%                 2.867000         5.909000
# 50%                 2.867000         6.091000
# 75%                 3.833000         8.465000
# max                 4.767000         9.344000
#
# attributes SETTING DIFFERENTIAL PRESSURE - RECOMMENDED (MIN)(PSI)  \
# values                                                      value
# count                                               66.000000
# mean                                              2953.030303
# std                                                150.097094
# min                                               2400.000000
# 25%                                               3000.000000
# 50%                                               3000.000000
# 75%                                               3000.000000
# max                                               3000.000000
#
# attributes SHEAR RELEASE FORCE (LB)
# values                        value
# count                     66.000000
# mean                  104974.606061
# std                     9848.136242
# min                    77844.000000
# 25%                   103792.000000
# 50%                   103792.000000
# 75%                   103792.000000
# max                   129740.000000

# %%
# Filter sample
high_level = ['A','B', 'C', 'D']
low_level = ['value', 'w2', 'w3']

rng = np.random.RandomState(42)

df_new = pd.DataFrame(data = rng.rand(1000,12), columns = pd.MultiIndex.from_product([high_level, low_level]))

sample_dict = {0:'s1', 1:'s2', 2:'s3'}

df_new[('D','value')] = [sample_dict[rng.randint(0, 3)] for i in range(1000)]
df_new[('D','w2')] = [sample_dict[rng.randint(0, 3)] for i in range(1000)]
df_new[('D','w3')] = [sample_dict[rng.randint(0, 3)] for i in range(1000)]                  
df_new
# Out:
#             A                             B                             C  \
#         value        w2        w3     value        w2        w3     value
# 0    0.374540  0.950714  0.731994  0.598658  0.156019  0.155995  0.058084
# 1    0.832443  0.212339  0.181825  0.183405  0.304242  0.524756  0.431945
# 2    0.456070  0.785176  0.199674  0.514234  0.592415  0.046450  0.607545
# 3    0.304614  0.097672  0.684233  0.440152  0.122038  0.495177  0.034389
# 4    0.546710  0.184854  0.969585  0.775133  0.939499  0.894827  0.597900
# ..        ...       ...       ...       ...       ...       ...       ...
# 995  0.090838  0.128937  0.239610  0.859528  0.924613  0.826258  0.334077
# 996  0.049292  0.694356  0.832226  0.846349  0.678464  0.954016  0.511005
# 997  0.548120  0.453015  0.877758  0.100032  0.257740  0.751799  0.094987
# 998  0.447542  0.917022  0.467870  0.275040  0.141829  0.003745  0.532157
# 999  0.774722  0.946791  0.100440  0.155590  0.960013  0.037784  0.977632
#
#                             D
#            w2        w3 value  w2  w3
# 0    0.866176  0.601115    s2  s3  s1
# 1    0.291229  0.611853    s3  s3  s1
# 2    0.170524  0.065052    s3  s1  s1
# 3    0.909320  0.258780    s1  s1  s2
# 4    0.921874  0.088493    s1  s3  s2
# ..        ...       ...   ...  ..  ..
# 995  0.272446  0.549156    s3  s1  s1
# 996  0.913815  0.967812    s1  s3  s3
# 997  0.320764  0.387155    s1  s2  s2
# 998  0.107157  0.391728    s3  s1  s2
# 999  0.004644  0.873669    s2  s1  s2
#
# [1000 rows x 12 columns]

# %%
# Filter result
df_filter_result = pd.DataFrame().reindex_like(df_new)

# Rules for filtering
rules = {('A', 'value'):'df_new.A.value < x', 
         ('B', 'w2') :'df_new.B.w2 > x',
         ('C', 'w3'):'df_new.C.w3*10 <= x', 
         ('D', 'w3'):'df_new.D.w3 == x'}

# Values for filtering
user_record = {('A', 'value') : 0.9,
                ('B', 'w2') : 0.5,
                ('C', 'w3') : 0.3,
                ('D', 'w3') : 's1'}

for key, rule in rules.items():
    if key in user_record:
        x = user_record[key]
        df_filter_result[key] = pd.eval(rule)

df_filter_result
# Out:
#         A             B                C                D
#     value  w2  w3 value     w2  w3 value  w2     w3 value  w2     w3
# 0    True NaN NaN   NaN  False NaN   NaN NaN  False   NaN NaN   True
# 1    True NaN NaN   NaN  False NaN   NaN NaN  False   NaN NaN   True
# 2    True NaN NaN   NaN   True NaN   NaN NaN  False   NaN NaN   True
# 3    True NaN NaN   NaN  False NaN   NaN NaN  False   NaN NaN  False
# 4    True NaN NaN   NaN   True NaN   NaN NaN  False   NaN NaN  False
# ..    ...  ..  ..   ...    ...  ..   ...  ..    ...   ...  ..    ...
# 995  True NaN NaN   NaN   True NaN   NaN NaN  False   NaN NaN   True
# 996  True NaN NaN   NaN   True NaN   NaN NaN  False   NaN NaN  False
# 997  True NaN NaN   NaN  False NaN   NaN NaN  False   NaN NaN  False
# 998  True NaN NaN   NaN  False NaN   NaN NaN  False   NaN NaN  False
# 999  True NaN NaN   NaN   True NaN   NaN NaN  False   NaN NaN  False
#
# [1000 rows x 12 columns]

# %%
criteries = set(list(user_record.keys()) + list(rules.keys()))
s_filter_result_sum = df_filter_result[criteries].sum(axis = 1)

# Full match
df_new[s_filter_result_sum == len(criteries)]
# Out:
#             A                             B                             C  \
#         value        w2        w3     value        w2        w3     value
# 305  0.509854  0.501276  0.050243  0.034912  0.551160  0.438179  0.839180
# 687  0.332950  0.669412  0.216136  0.590872  0.913206  0.797802  0.921458
# 738  0.214272  0.064491  0.574294  0.622029  0.505742  0.817102  0.861009
# 748  0.328746  0.720434  0.643771  0.332818  0.754873  0.648695  0.637445
# 769  0.383949  0.736817  0.475942  0.122583  0.927934  0.454097  0.734487
# 781  0.050065  0.873634  0.075554  0.246688  0.695319  0.409448  0.876314
# 811  0.469654  0.782934  0.746255  0.604613  0.686367  0.018356  0.311778
# 863  0.786183  0.376950  0.100367  0.633779  0.880131  0.887754  0.957663
# 986  0.771668  0.919531  0.533201  0.100065  0.588689  0.778396  0.093328
#
#                             D
#            w2        w3 value  w2  w3
# 305  0.160680  0.024972    s1  s1  s1
# 687  0.978506  0.010670    s2  s3  s1
# 738  0.615624  0.012756    s2  s1  s1
# 748  0.553428  0.011390    s3  s2  s1
# 769  0.367174  0.018881    s3  s3  s1
# 781  0.297980  0.011871    s2  s1  s1
# 811  0.637822  0.009345    s1  s2  s1
# 863  0.867705  0.002141    s1  s2  s1
# 986  0.172657  0.012291    s1  s2  s1

# %%
# Other records ordered by number of matched columns
df_new.loc[s_filter_result_sum[s_filter_result_sum < len(criteries)].sort_values(ascending = False).index]
# Out:
#             A                             B                             C  \
#         value        w2        w3     value        w2        w3     value
# 869  0.103577  0.837729  0.152750  0.082927  0.641775  0.471937  0.907891
# 146  0.012121  0.241201  0.975874  0.801537  0.959577  0.487854  0.109736
# 280  0.796241  0.271946  0.692359  0.264062  0.939068  0.636374  0.324512
# 885  0.357641  0.290744  0.614771  0.902776  0.962292  0.653603  0.838159
# 779  0.651198  0.856285  0.112383  0.347738  0.876421  0.201655  0.078242
# ..        ...       ...       ...       ...       ...       ...       ...
# 905  0.949537  0.339529  0.108146  0.506501  0.085811  0.969527  0.038685
# 854  0.984165  0.019901  0.699027  0.252912  0.040488  0.402890  0.935218
# 754  0.953125  0.516736  0.819107  0.547128  0.040785  0.315008  0.575550
# 132  0.987786  0.136440  0.695145  0.404319  0.428200  0.717598  0.692436
# 611  0.942185  0.518493  0.352309  0.234058  0.049781  0.268500  0.654236
#
#                             D
#            w2        w3 value  w2  w3
# 869  0.363189  0.287152    s2  s2  s1
# 146  0.547959  0.454377    s1  s3  s1
# 280  0.269512  0.190927    s2  s1  s1
# 885  0.525202  0.208327    s2  s1  s1
# 779  0.788119  0.835486    s3  s2  s1
# ..        ...       ...   ...  ..  ..
# 905  0.753504  0.525102    s3  s3  s2
# 854  0.011765  0.587886    s3  s1  s3
# 754  0.950594  0.859130    s1  s3  s2
# 132  0.991256  0.128394    s3  s2  s2
# 611  0.533617  0.944041    s1  s3  s3
#
# [991 rows x 12 columns]

# %%
# Readable column names
rename_columns = {'ACTIVE FLOW WETTED MATERIAL - YIELD STRENGTH (KSI)':'WETTED_MATERIAL',
'CASING SIZE (IN)':'CASING_SIZE',
'CASING WEIGHT RANGE (PPF)':'WEIGHT_RANGE',
'CERTIFICATION STATUS':'CERTIFICATION',
'DIFFERENTIAL PRESSURE RATING (PSI)':'PRESSURE_RATING',
'EXTERNAL WORKING PRESSURE (PSI) - EOEC AT SPECIFIED TEMP (F)':'EXTERNAL_PRESSURE',
'I.D. - DRIFT (IN)':'ID_DRIFT',
'INTERNAL WORKING PRESSURE (PSI) - EOEC AT SPECIFIED TEMP (F)':'INTERNAL_PRESSURE',
'LOWER THREAD CONNECTING - SIZE (IN), WT (PPF), TYPE, CONFIG':'LOWER_THREAD',
'MATERIAL/ELEMENTS':'MATERIAL_ELEMENTS',
'MATERIAL/O-RING(S)':'MATERIAL_O_RING',
'O.D. - MAX. (IN)':'OD_MAX',
'QUALITY CONTROL GRADE':'QCG',
'QUALITY CONTROL PLAN - QCP':'QCP',
'SERVICE NACE (YES/NO)':'SERVICE_NACE',
'SETTING DIFFERENTIAL PRESSURE - RECOMMENDED (MIN)(PSI)':'SETTING_PRESSURE',
'SHEAR RELEASE FORCE (LB)':'RELEASE_FORCE',
'TENSILE STRENGTH (LBS) - EOEC AT SPECIFIED TEMP (F)':'TENSILE_STRENGTH',
'UPPER THREAD CONNECTING - SIZE (IN), WT (PPF), TYPE, CONFIG':'UPPER_THREAD',
'ACTIVE FLOW WETTED MATERIAL':'MATERIAL',
'CONFIG':'CONFIG',
'EOEC AT SPECIFIED TEMP (F)':'TEMP',
'EXTERNAL WORKING PRESSURE (PSI)':'PRESSURE',
'INTERNAL WORKING PRESSURE (PSI)':'PRESSURE',
'MAX':'MAX',
'MIN':'MIN',
'SIZE (IN)':'SIZE',
'TENSILE STRENGTH (LBS)':'STRENGTH',
'TYPE':'TYPE',
'WT (PPF)':'WT',
'YIELD STRENGTH (KSI)':'STRENGTH',
'value':'value'}

reverse_rename = {'WETTED_MATERIAL':'ACTIVE FLOW WETTED MATERIAL - YIELD STRENGTH (KSI)',
'CASING_SIZE':'CASING SIZE (IN)',
'WEIGHT_RANGE':'CASING WEIGHT RANGE (PPF)',
'CERTIFICATION':'CERTIFICATION STATUS',
'PRESSURE_RATING':'DIFFERENTIAL PRESSURE RATING (PSI)',
'EXTERNAL_PRESSURE':'EXTERNAL WORKING PRESSURE (PSI) - EOEC AT SPECIFIED TEMP (F)',
'ID_DRIFT':'I.D. - DRIFT (IN)',
'INTERNAL_PRESSURE':'INTERNAL WORKING PRESSURE (PSI) - EOEC AT SPECIFIED TEMP (F)',
'LOWER_THREAD':'LOWER THREAD CONNECTING - SIZE (IN), WT (PPF), TYPE, CONFIG',
'MATERIAL_ELEMENTS':'MATERIAL/ELEMENTS',
'MATERIAL_O_RING':'MATERIAL/O-RING(S)',
'OD_MAX':'O.D. - MAX. (IN)',
'QCG':'QUALITY CONTROL GRADE',
'QCP':'QUALITY CONTROL PLAN - QCP',
'SERVICE_NACE':'SERVICE NACE (YES/NO)',
'SETTING_PRESSURE':'SETTING DIFFERENTIAL PRESSURE - RECOMMENDED (MIN)(PSI)',
'RELEASE_FORCE':'SHEAR RELEASE FORCE (LB)',
'TENSILE_STRENGTH':'TENSILE STRENGTH (LBS) - EOEC AT SPECIFIED TEMP (F)',
'UPPER_THREAD':'UPPER THREAD CONNECTING - SIZE (IN), WT (PPF), TYPE, CONFIG'}

ia_df = ia_df_parsed.copy()
ia_df.rename(columns = rename_columns, inplace = True)

ia_df[('WETTED_MATERIAL', 'STRENGTH')] = ia_df[('WETTED_MATERIAL', 'STRENGTH')].astype(float)
ia_df[('WEIGHT_RANGE', 'MAX')] = ia_df[('WEIGHT_RANGE', 'MAX')].astype(float)
ia_df[('WEIGHT_RANGE', 'MIN')] = ia_df[('WEIGHT_RANGE', 'MIN')].astype(float)
ia_df[('EXTERNAL_PRESSURE', 'TEMP')]     = ia_df[('EXTERNAL_PRESSURE', 'TEMP')].astype(float)
ia_df[('EXTERNAL_PRESSURE', 'PRESSURE')] = ia_df[('EXTERNAL_PRESSURE', 'PRESSURE')].astype(float)
ia_df[('INTERNAL_PRESSURE', 'TEMP')]     = ia_df[('INTERNAL_PRESSURE', 'TEMP')].astype(float)
ia_df[('INTERNAL_PRESSURE', 'PRESSURE')] = ia_df[('INTERNAL_PRESSURE', 'PRESSURE')].astype(float)
ia_df[('LOWER_THREAD', 'SIZE')] = ia_df[('LOWER_THREAD', 'SIZE')].astype(float)
ia_df[('LOWER_THREAD', 'WT')]   = ia_df[('LOWER_THREAD', 'WT')].astype(float)
ia_df[('UPPER_THREAD', 'SIZE')] = ia_df[('UPPER_THREAD', 'SIZE')].astype(float)
ia_df[('UPPER_THREAD', 'WT')]   = ia_df[('UPPER_THREAD', 'WT')].astype(float)
ia_df[('TENSILE_STRENGTH', 'TEMP')]     = ia_df[('TENSILE_STRENGTH', 'TEMP')].astype(float)
ia_df[('TENSILE_STRENGTH', 'STRENGTH')] = ia_df[('TENSILE_STRENGTH', 'STRENGTH')].astype(float)
ia_df[('CERTIFICATION', 'value')] = ia_df['CERTIFICATION']['value'].str.strip()
ia_df[('LOWER_THREAD' , 'TYPE')]   = ia_df.LOWER_THREAD.TYPE.str.strip()
ia_df[('LOWER_THREAD' , 'CONFIG')] = ia_df.LOWER_THREAD.CONFIG.str.strip()
ia_df[('UPPER_THREAD' , 'TYPE')]   = ia_df.UPPER_THREAD.TYPE.str.strip()
ia_df[('UPPER_THREAD' , 'CONFIG')] = ia_df.UPPER_THREAD.CONFIG.str.strip()
ia_df[('QCP' , 'value')] = ia_df.QCP.value.str.replace('.', '')

ia_df_basic_cols = ia_df.drop([('WETTED_MATERIAL',  'value'),
                               ('WEIGHT_RANGE',     'value'),
                               ('EXTERNAL_PRESSURE','value'),
                               ('INTERNAL_PRESSURE','value'),
                               ('LOWER_THREAD',     'value'),
                               ('TENSILE_STRENGTH', 'value'),
                               ('UPPER_THREAD',     'value')], axis = 1)

ia_df_basic_cols.head()
# Out:
# attributes   WETTED_MATERIAL          CASING_SIZE WEIGHT_RANGE        \
# values              MATERIAL STRENGTH       value          MAX   MIN
# 102041421_AB             9CR     80.0       7.000         26.0  23.0
# 102043250_AF            41XX     80.0       6.625         28.0  24.0
# 102055050_AC            41XX     80.0       7.000         32.0  26.0
# 102055845_AC            41XX     80.0       7.000         26.0  23.0
# 102103987_AG            41XX     80.0       4.500         13.5   9.5
#
# attributes                CERTIFICATION PRESSURE_RATING EXTERNAL_PRESSURE  \
# values                            value           value              TEMP
# 102041421_AB           ISO-V3[150-325F]          5000.0             325.0
# 102043250_AF  ISO-V3[150-325F, 40-235F]          5000.0             325.0
# 102055050_AC           ISO-V3[150-325F]          5000.0             325.0
# 102055845_AC           ISO-V3[150-325F]          5000.0             325.0
# 102103987_AG           ISO-V3[150-325F]          5000.0             325.0
#
# attributes            ID_DRIFT  ...                QCP SERVICE_NACE  \
# values       PRESSURE    value  ...              value        value
# 102041421_AB   5000.0    3.833  ...      QCP-101792794         True
# 102043250_AF   5000.0    2.867  ...  CLG QCP-102817386         True
# 102055050_AC   5000.0    3.833  ...  CLG QCP-102817386         True
# 102055845_AC   5000.0    3.833  ...  CLG QCP-102817386         True
# 102103987_AG   5000.0    1.901  ...  CLG QCP-102817386         True
#
# attributes   SETTING_PRESSURE RELEASE_FORCE TENSILE_STRENGTH            \
# values                  value         value             TEMP  STRENGTH
# 102041421_AB           3000.0      103792.0            325.0  208000.0
# 102043250_AF           3000.0      116766.0            325.0  208000.0
# 102055050_AC           3000.0      103792.0            325.0  208000.0
# 102055845_AC           3000.0      103792.0            325.0  208000.0
# 102103987_AG           2500.0       77844.0            325.0  101000.0
#
# attributes   UPPER_THREAD
# values             CONFIG   SIZE       TYPE     WT
# 102041421_AB          PIN  4.460  STUB ACME  12.00
# 102043250_AF          BOX  3.500        EUE   9.30
# 102055050_AC          BOX  4.500        EUE  12.75
# 102055845_AC          BOX  4.500        EUE  12.75
# 102103987_AG          BOX  2.375        EUE   4.70
#
# [5 rows x 30 columns]

# %%
# Run filter on data
# Filter results
ia_df_filter_result = pd.DataFrame().reindex_like(ia_df_basic_cols)

# EXAMPLE Rules
ia_rules = {('WETTED_MATERIAL', 'MATERIAL'):'ia_df.WETTED_MATERIAL.MATERIAL == x', 
            ('CASING_SIZE', 'value') :'ia_df.CASING_SIZE.value <= x',
            ('WEIGHT_RANGE', 'MAX'):'ia_df.WEIGHT_RANGE.MAX >= x', 
            ('WEIGHT_RANGE', 'MIN'):'ia_df.WEIGHT_RANGE.MIN <= x'}

# EXAMPLE User Data
ia_user_record = {('WETTED_MATERIAL', 'MATERIAL') : '41XX', 
                  ('CASING_SIZE', 'value')        : 7.0,
                  ('WEIGHT_RANGE', 'MAX')         : 25, 
                  ('WEIGHT_RANGE', 'MIN')         : 24}

for key, rule in ia_rules.items():
    if key in ia_user_record:
        x = ia_user_record[key]
        ia_df_filter_result[key] = pd.eval(rule)

ia_criteries = set(list(ia_user_record.keys()) + list(ia_rules.keys()))
s_filter_result_sum = ia_df_filter_result[ia_criteries].sum(axis = 1)

# Rules for filtering for each basic column
ia_rules = {
(  'WETTED_MATERIAL', 'MATERIAL'):"ia_df.WETTED_MATERIAL.MATERIAL==x", 
(  'WETTED_MATERIAL', 'STRENGTH'):"ia_df.WETTED_MATERIAL.STRENGTH>=x",
(      'CASING_SIZE',    'value'):"ia_df.CASING_SIZE.value<=x",
(     'WEIGHT_RANGE',      'MAX'):"ia_df.WEIGHT_RANGE.MAX<=x",
(     'WEIGHT_RANGE',      'MIN'):"ia_df.WEIGHT_RANGE.MIN>=x",
(    'CERTIFICATION',    'value'):"ia_df.CERTIFICATION.value==x",
(  'PRESSURE_RATING',    'value'):"ia_df.PRESSURE_RATING.value>=x",
('EXTERNAL_PRESSURE',     'TEMP'):"ia_df.EXTERNAL_PRESSURE.TEMP>=x",
('EXTERNAL_PRESSURE', 'PRESSURE'):"ia_df.EXTERNAL_PRESSURE.PRESSURE>=x",
(         'ID_DRIFT',    'value'):"ia_df.ID_DRIFT.value<=x",
('INTERNAL_PRESSURE',     'TEMP'):"ia_df.INTERNAL_PRESSURE.TEMP>=x",
('INTERNAL_PRESSURE', 'PRESSURE'):"ia_df.INTERNAL_PRESSURE.PRESSURE>=x",
(     'LOWER_THREAD',   'CONFIG'):"ia_df.LOWER_THREAD.CONFIG==x",
(     'LOWER_THREAD',     'SIZE'):"ia_df.LOWER_THREAD.SIZE<=x",
(     'LOWER_THREAD',     'TYPE'):"ia_df.LOWER_THREAD.TYPE==x",
(     'LOWER_THREAD',       'WT'):"ia_df.LOWER_THREAD.WT<=x",
('MATERIAL_ELEMENTS',    'value'):"ia_df.MATERIAL_ELEMENTS.value==x",
(  'MATERIAL_O_RING',    'value'):"ia_df.MATERIAL_O_RING.value==x",
(           'OD_MAX',    'value'):"ia_df.OD_MAX.value<=x",
(              'QCG',    'value'):"ia_df.QCG.value==x",
(              'QCP',    'value'):"ia_df.QCP.value==x",
(     'SERVICE_NACE',    'value'):"ia_df.SERVICE_NACE.value==x",
( 'SETTING_PRESSURE',    'value'):"ia_df.SETTING_PRESSURE.value>=x",
(    'RELEASE_FORCE',    'value'):"ia_df.RELEASE_FORCE.value<=x",
( 'TENSILE_STRENGTH',     'TEMP'):"ia_df.TENSILE_STRENGTH.TEMP>=x",
( 'TENSILE_STRENGTH', 'STRENGTH'):"ia_df.TENSILE_STRENGTH.STRENGTH>=x",
(     'UPPER_THREAD',   'CONFIG'):"ia_df.UPPER_THREAD.CONFIG==x",
(     'UPPER_THREAD',     'SIZE'):"ia_df.UPPER_THREAD.SIZE<=x",
(     'UPPER_THREAD',     'TYPE'):"ia_df.UPPER_THREAD.TYPE==x",
(     'UPPER_THREAD',       'WT'):"ia_df.UPPER_THREAD.WT<=x"}

# %%
# Full match records
ia_df_basic_cols[s_filter_result_sum == len(ia_criteries)].head()
# Out:
# attributes   WETTED_MATERIAL          CASING_SIZE WEIGHT_RANGE        \
# values              MATERIAL STRENGTH       value          MAX   MIN
# 102043250_AF            41XX     80.0       6.625         28.0  24.0
# 102055845_AC            41XX     80.0       7.000         26.0  23.0
# 102689441_AD            41XX     80.0       7.000         29.0  23.0
# 102743317_AD            41XX     80.0       7.000         26.0  20.0
# 102749502_AG            41XX     80.0       7.000         29.0  23.0
#
# attributes                CERTIFICATION PRESSURE_RATING EXTERNAL_PRESSURE  \
# values                            value           value              TEMP
# 102043250_AF  ISO-V3[150-325F, 40-235F]          5000.0             325.0
# 102055845_AC           ISO-V3[150-325F]          5000.0             325.0
# 102689441_AD           ISO-V3[150-325F]          5000.0             325.0
# 102743317_AD           ISO-V3[150-325F]          5000.0             325.0
# 102749502_AG           ISO-V3[150-325F]          5000.0             325.0
#
# attributes            ID_DRIFT  ...                QCP SERVICE_NACE  \
# values       PRESSURE    value  ...              value        value
# 102043250_AF   5000.0    2.867  ...  CLG QCP-102817386         True
# 102055845_AC   5000.0    3.833  ...  CLG QCP-102817386         True
# 102689441_AD   5000.0    1.904  ...  CLG QCP-102817386         True
# 102743317_AD   5000.0    2.867  ...  CLG QCP-102817386         True
# 102749502_AG   5000.0    2.867  ...  CLG QCP-102817386         True
#
# attributes   SETTING_PRESSURE RELEASE_FORCE TENSILE_STRENGTH            \
# values                  value         value             TEMP  STRENGTH
# 102043250_AF           3000.0      116766.0            325.0  208000.0
# 102055845_AC           3000.0      103792.0            325.0  208000.0
# 102689441_AD           3000.0      103792.0            325.0  104000.0
# 102743317_AD           3000.0      103792.0            325.0  208000.0
# 102749502_AG           3000.0      103792.0            325.0  208000.0
#
# attributes   UPPER_THREAD
# values             CONFIG   SIZE TYPE     WT
# 102043250_AF          BOX  3.500  EUE   9.30
# 102055845_AC          BOX  4.500  EUE  12.75
# 102689441_AD          BOX  2.375  EUE   4.70
# 102743317_AD          BOX  3.500  EUE   9.30
# 102749502_AG          BOX  3.500  EUE   9.30
#
# [5 rows x 30 columns]

# %%
# Other records ordered by number of matched columns
ia_df_basic_cols.loc[s_filter_result_sum[s_filter_result_sum < len(ia_criteries)].sort_values(ascending = False).index].head()
# Out:
# attributes   WETTED_MATERIAL          CASING_SIZE WEIGHT_RANGE        \
# values              MATERIAL STRENGTH       value          MAX   MIN
# 103232093_AA            41XX     80.0         7.0         32.0  26.0
# 103000049_AA             9CR     80.0         7.0         26.0  23.0
# 102055050_AC            41XX     80.0         7.0         32.0  26.0
# 102103987_AG            41XX     80.0         4.5         13.5   9.5
# 102727939_AC            41XX    110.0         7.0         32.0  26.0
#
# attributes       CERTIFICATION PRESSURE_RATING EXTERNAL_PRESSURE           \
# values                   value           value              TEMP PRESSURE
# 103232093_AA  ISO-V3[150-325F]          5000.0             325.0   5000.0
# 103000049_AA  ISO-V3[150-325F]          5000.0             325.0   5000.0
# 102055050_AC  ISO-V3[150-325F]          5000.0             325.0   5000.0
# 102103987_AG  ISO-V3[150-325F]          5000.0             325.0   5000.0
# 102727939_AC   ISO-V6[AMBIENT]          6000.0               0.0   6000.0
#
# attributes   ID_DRIFT  ...                QCP SERVICE_NACE SETTING_PRESSURE  \
# values          value  ...              value        value            value
# 103232093_AA    2.867  ...  CLG QCP-102817386         True           3000.0
# 103000049_AA    3.833  ...  CLG QCP-102817386         True           3000.0
# 102055050_AC    3.833  ...  CLG QCP-102817386         True           3000.0
# 102103987_AG    1.901  ...  CLG QCP-102817386         True           2500.0
# 102727939_AC    3.833  ...  CLG QCP-102817386        False           3000.0
#
# attributes   RELEASE_FORCE TENSILE_STRENGTH           UPPER_THREAD         \
# values               value             TEMP  STRENGTH       CONFIG   SIZE
# 103232093_AA      103792.0            325.0  208000.0          BOX  3.500
# 103000049_AA      103792.0            325.0  208000.0          PIN  4.460
# 102055050_AC      103792.0            325.0  208000.0          BOX  4.500
# 102103987_AG       77844.0            325.0  101000.0          BOX  2.375
# 102727939_AC      129740.0              0.0  324890.0          PIN  4.460
#
# attributes
# values                       TYPE     WT
# 103232093_AA  TENARIS HYDRIL BLUE   9.20
# 103000049_AA            STUB ACME  12.00
# 102055050_AC                  EUE  12.75
# 102103987_AG                  EUE   4.70
# 102727939_AC            STUB ACME  12.00
#
# [5 rows x 30 columns]

# %%
# Dict for json for full match

ia_df_pm = ia_df_basic_cols[s_filter_result_sum == len(ia_criteries)]
dict_df_pm = ia_df_pm.to_dict('index')
{rec_id:{str(col_id):dict_df_pm[rec_id][col_id] for col_id in dict_df_pm[rec_id]} for rec_id in dict_df_pm.keys()}
# Out:
# {'102043250_AF': {"('WETTED_MATERIAL', 'MATERIAL')": '41XX',
#   "('WETTED_MATERIAL', 'STRENGTH')": 80.0,
#   "('CASING_SIZE', 'value')": 6.625,
#   "('WEIGHT_RANGE', 'MAX')": 28.0,
#   "('WEIGHT_RANGE', 'MIN')": 24.0,
#   "('CERTIFICATION', 'value')": 'ISO-V3[150-325F, 40-235F]',
#   "('PRESSURE_RATING', 'value')": 5000.0,
#   "('EXTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('EXTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('ID_DRIFT', 'value')": 2.867,
#   "('INTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('INTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('LOWER_THREAD', 'CONFIG')": 'PIN',
#   "('LOWER_THREAD', 'SIZE')": 3.5,
#   "('LOWER_THREAD', 'TYPE')": 'EUE',
#   "('LOWER_THREAD', 'WT')": 9.3,
#   "('MATERIAL_ELEMENTS', 'value')": 'HNBR',
#   "('MATERIAL_O_RING', 'value')": 'VITON',
#   "('OD_MAX', 'value')": 5.606,
#   "('QCG', 'value')": 'Q3',
#   "('QCP', 'value')": 'CLG QCP-102817386',
#   "('SERVICE_NACE', 'value')": True,
#   "('SETTING_PRESSURE', 'value')": 3000.0,
#   "('RELEASE_FORCE', 'value')": 116766.0,
#   "('TENSILE_STRENGTH', 'TEMP')": 325.0,
#   "('TENSILE_STRENGTH', 'STRENGTH')": 208000.0,
#   "('UPPER_THREAD', 'CONFIG')": 'BOX',
#   "('UPPER_THREAD', 'SIZE')": 3.5,
#   "('UPPER_THREAD', 'TYPE')": 'EUE',
#   "('UPPER_THREAD', 'WT')": 9.3},
#  '102055845_AC': {"('WETTED_MATERIAL', 'MATERIAL')": '41XX',
#   "('WETTED_MATERIAL', 'STRENGTH')": 80.0,
#   "('CASING_SIZE', 'value')": 7.0,
#   "('WEIGHT_RANGE', 'MAX')": 26.0,
#   "('WEIGHT_RANGE', 'MIN')": 23.0,
#   "('CERTIFICATION', 'value')": 'ISO-V3[150-325F]',
#   "('PRESSURE_RATING', 'value')": 5000.0,
#   "('EXTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('EXTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('ID_DRIFT', 'value')": 3.833,
#   "('INTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('INTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('LOWER_THREAD', 'CONFIG')": 'PIN',
#   "('LOWER_THREAD', 'SIZE')": 4.5,
#   "('LOWER_THREAD', 'TYPE')": 'EUE',
#   "('LOWER_THREAD', 'WT')": 12.75,
#   "('MATERIAL_ELEMENTS', 'value')": 'HNBR',
#   "('MATERIAL_O_RING', 'value')": 'VITON',
#   "('OD_MAX', 'value')": 6.091,
#   "('QCG', 'value')": 'Q3',
#   "('QCP', 'value')": 'CLG QCP-102817386',
#   "('SERVICE_NACE', 'value')": True,
#   "('SETTING_PRESSURE', 'value')": 3000.0,
#   "('RELEASE_FORCE', 'value')": 103792.0,
#   "('TENSILE_STRENGTH', 'TEMP')": 325.0,
#   "('TENSILE_STRENGTH', 'STRENGTH')": 208000.0,
#   "('UPPER_THREAD', 'CONFIG')": 'BOX',
#   "('UPPER_THREAD', 'SIZE')": 4.5,
#   "('UPPER_THREAD', 'TYPE')": 'EUE',
#   "('UPPER_THREAD', 'WT')": 12.75},
#  '102689441_AD': {"('WETTED_MATERIAL', 'MATERIAL')": '41XX',
#   "('WETTED_MATERIAL', 'STRENGTH')": 80.0,
#   "('CASING_SIZE', 'value')": 7.0,
#   "('WEIGHT_RANGE', 'MAX')": 29.0,
#   "('WEIGHT_RANGE', 'MIN')": 23.0,
#   "('CERTIFICATION', 'value')": 'ISO-V3[150-325F]',
#   "('PRESSURE_RATING', 'value')": 5000.0,
#   "('EXTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('EXTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('ID_DRIFT', 'value')": 1.904,
#   "('INTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('INTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('LOWER_THREAD', 'CONFIG')": 'PIN',
#   "('LOWER_THREAD', 'SIZE')": 2.375,
#   "('LOWER_THREAD', 'TYPE')": 'EUE',
#   "('LOWER_THREAD', 'WT')": 4.7,
#   "('MATERIAL_ELEMENTS', 'value')": 'HNBR',
#   "('MATERIAL_O_RING', 'value')": 'VITON',
#   "('OD_MAX', 'value')": 5.999,
#   "('QCG', 'value')": 'Q3',
#   "('QCP', 'value')": 'CLG QCP-102817386',
#   "('SERVICE_NACE', 'value')": True,
#   "('SETTING_PRESSURE', 'value')": 3000.0,
#   "('RELEASE_FORCE', 'value')": 103792.0,
#   "('TENSILE_STRENGTH', 'TEMP')": 325.0,
#   "('TENSILE_STRENGTH', 'STRENGTH')": 104000.0,
#   "('UPPER_THREAD', 'CONFIG')": 'BOX',
#   "('UPPER_THREAD', 'SIZE')": 2.375,
#   "('UPPER_THREAD', 'TYPE')": 'EUE',
#   "('UPPER_THREAD', 'WT')": 4.7},
#  '102743317_AD': {"('WETTED_MATERIAL', 'MATERIAL')": '41XX',
#   "('WETTED_MATERIAL', 'STRENGTH')": 80.0,
#   "('CASING_SIZE', 'value')": 7.0,
#   "('WEIGHT_RANGE', 'MAX')": 26.0,
#   "('WEIGHT_RANGE', 'MIN')": 20.0,
#   "('CERTIFICATION', 'value')": 'ISO-V3[150-325F]',
#   "('PRESSURE_RATING', 'value')": 5000.0,
#   "('EXTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('EXTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('ID_DRIFT', 'value')": 2.867,
#   "('INTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('INTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('LOWER_THREAD', 'CONFIG')": 'PIN',
#   "('LOWER_THREAD', 'SIZE')": 3.5,
#   "('LOWER_THREAD', 'TYPE')": 'EUE',
#   "('LOWER_THREAD', 'WT')": 9.3,
#   "('MATERIAL_ELEMENTS', 'value')": 'HNBR',
#   "('MATERIAL_O_RING', 'value')": 'VITON',
#   "('OD_MAX', 'value')": 6.091,
#   "('QCG', 'value')": 'Q3',
#   "('QCP', 'value')": 'CLG QCP-102817386',
#   "('SERVICE_NACE', 'value')": True,
#   "('SETTING_PRESSURE', 'value')": 3000.0,
#   "('RELEASE_FORCE', 'value')": 103792.0,
#   "('TENSILE_STRENGTH', 'TEMP')": 325.0,
#   "('TENSILE_STRENGTH', 'STRENGTH')": 208000.0,
#   "('UPPER_THREAD', 'CONFIG')": 'BOX',
#   "('UPPER_THREAD', 'SIZE')": 3.5,
#   "('UPPER_THREAD', 'TYPE')": 'EUE',
#   "('UPPER_THREAD', 'WT')": 9.3},
#  '102749502_AG': {"('WETTED_MATERIAL', 'MATERIAL')": '41XX',
#   "('WETTED_MATERIAL', 'STRENGTH')": 80.0,
#   "('CASING_SIZE', 'value')": 7.0,
#   "('WEIGHT_RANGE', 'MAX')": 29.0,
#   "('WEIGHT_RANGE', 'MIN')": 23.0,
#   "('CERTIFICATION', 'value')": 'ISO-V3[150-325F]',
#   "('PRESSURE_RATING', 'value')": 5000.0,
#   "('EXTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('EXTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('ID_DRIFT', 'value')": 2.867,
#   "('INTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('INTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('LOWER_THREAD', 'CONFIG')": 'PIN',
#   "('LOWER_THREAD', 'SIZE')": 3.5,
#   "('LOWER_THREAD', 'TYPE')": 'EUE',
#   "('LOWER_THREAD', 'WT')": 9.3,
#   "('MATERIAL_ELEMENTS', 'value')": 'HNBR',
#   "('MATERIAL_O_RING', 'value')": 'VITON',
#   "('OD_MAX', 'value')": 5.999,
#   "('QCG', 'value')": 'Q3',
#   "('QCP', 'value')": 'CLG QCP-102817386',
#   "('SERVICE_NACE', 'value')": True,
#   "('SETTING_PRESSURE', 'value')": 3000.0,
#   "('RELEASE_FORCE', 'value')": 103792.0,
#   "('TENSILE_STRENGTH', 'TEMP')": 325.0,
#   "('TENSILE_STRENGTH', 'STRENGTH')": 208000.0,
#   "('UPPER_THREAD', 'CONFIG')": 'BOX',
#   "('UPPER_THREAD', 'SIZE')": 3.5,
#   "('UPPER_THREAD', 'TYPE')": 'EUE',
#   "('UPPER_THREAD', 'WT')": 9.3},
#  '102779363_AD': {"('WETTED_MATERIAL', 'MATERIAL')": '41XX',
#   "('WETTED_MATERIAL', 'STRENGTH')": 80.0,
#   "('CASING_SIZE', 'value')": 7.0,
#   "('WEIGHT_RANGE', 'MAX')": 29.0,
#   "('WEIGHT_RANGE', 'MIN')": 23.0,
#   "('CERTIFICATION', 'value')": 'ISO-V3[150-325F]',
#   "('PRESSURE_RATING', 'value')": 5000.0,
#   "('EXTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('EXTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('ID_DRIFT', 'value')": 2.347,
#   "('INTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('INTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('LOWER_THREAD', 'CONFIG')": 'PIN',
#   "('LOWER_THREAD', 'SIZE')": 2.875,
#   "('LOWER_THREAD', 'TYPE')": 'EUE',
#   "('LOWER_THREAD', 'WT')": 6.5,
#   "('MATERIAL_ELEMENTS', 'value')": 'HNBR',
#   "('MATERIAL_O_RING', 'value')": 'VITON',
#   "('OD_MAX', 'value')": 5.999,
#   "('QCG', 'value')": 'Q3',
#   "('QCP', 'value')": 'CLG QCP-102817386',
#   "('SERVICE_NACE', 'value')": True,
#   "('SETTING_PRESSURE', 'value')": 3000.0,
#   "('RELEASE_FORCE', 'value')": 103792.0,
#   "('TENSILE_STRENGTH', 'TEMP')": 325.0,
#   "('TENSILE_STRENGTH', 'STRENGTH')": 144000.0,
#   "('UPPER_THREAD', 'CONFIG')": 'BOX',
#   "('UPPER_THREAD', 'SIZE')": 2.875,
#   "('UPPER_THREAD', 'TYPE')": 'EUE',
#   "('UPPER_THREAD', 'WT')": 6.5},
#  '102825802_AC': {"('WETTED_MATERIAL', 'MATERIAL')": '41XX',
#   "('WETTED_MATERIAL', 'STRENGTH')": 80.0,
#   "('CASING_SIZE', 'value')": 6.625,
#   "('WEIGHT_RANGE', 'MAX')": 28.0,
#   "('WEIGHT_RANGE', 'MIN')": 24.0,
#   "('CERTIFICATION', 'value')": 'ISO-V3[150-325F, 40-235F]',
#   "('PRESSURE_RATING', 'value')": 5000.0,
#   "('EXTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('EXTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('ID_DRIFT', 'value')": 2.867,
#   "('INTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('INTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('LOWER_THREAD', 'CONFIG')": 'PIN',
#   "('LOWER_THREAD', 'SIZE')": 3.5,
#   "('LOWER_THREAD', 'TYPE')": 'VAM TOP',
#   "('LOWER_THREAD', 'WT')": 9.2,
#   "('MATERIAL_ELEMENTS', 'value')": 'HNBR',
#   "('MATERIAL_O_RING', 'value')": 'VITON',
#   "('OD_MAX', 'value')": 5.606,
#   "('QCG', 'value')": 'Q3',
#   "('QCP', 'value')": 'CLG QCP-102817386',
#   "('SERVICE_NACE', 'value')": True,
#   "('SETTING_PRESSURE', 'value')": 3000.0,
#   "('RELEASE_FORCE', 'value')": 116766.0,
#   "('TENSILE_STRENGTH', 'TEMP')": 325.0,
#   "('TENSILE_STRENGTH', 'STRENGTH')": 208000.0,
#   "('UPPER_THREAD', 'CONFIG')": 'BOX',
#   "('UPPER_THREAD', 'SIZE')": 3.5,
#   "('UPPER_THREAD', 'TYPE')": 'VAM TOP',
#   "('UPPER_THREAD', 'WT')": 9.2},
#  '102849523_AC': {"('WETTED_MATERIAL', 'MATERIAL')": '41XX',
#   "('WETTED_MATERIAL', 'STRENGTH')": 80.0,
#   "('CASING_SIZE', 'value')": 7.0,
#   "('WEIGHT_RANGE', 'MAX')": 29.0,
#   "('WEIGHT_RANGE', 'MIN')": 23.0,
#   "('CERTIFICATION', 'value')": 'ISO-V3[150-325F]',
#   "('PRESSURE_RATING', 'value')": 5000.0,
#   "('EXTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('EXTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('ID_DRIFT', 'value')": 2.867,
#   "('INTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('INTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('LOWER_THREAD', 'CONFIG')": 'PIN',
#   "('LOWER_THREAD', 'SIZE')": 3.5,
#   "('LOWER_THREAD', 'TYPE')": 'EUE',
#   "('LOWER_THREAD', 'WT')": 9.3,
#   "('MATERIAL_ELEMENTS', 'value')": 'HNBR',
#   "('MATERIAL_O_RING', 'value')": 'VITON',
#   "('OD_MAX', 'value')": 5.999,
#   "('QCG', 'value')": 'Q3',
#   "('QCP', 'value')": 'CLG QCP-102817386',
#   "('SERVICE_NACE', 'value')": True,
#   "('SETTING_PRESSURE', 'value')": 3000.0,
#   "('RELEASE_FORCE', 'value')": 104000.0,
#   "('TENSILE_STRENGTH', 'TEMP')": 325.0,
#   "('TENSILE_STRENGTH', 'STRENGTH')": 208000.0,
#   "('UPPER_THREAD', 'CONFIG')": 'BOX',
#   "('UPPER_THREAD', 'SIZE')": 3.5,
#   "('UPPER_THREAD', 'TYPE')": 'MODIFIED EUE',
#   "('UPPER_THREAD', 'WT')": 9.3},
#  '102932126_AD': {"('WETTED_MATERIAL', 'MATERIAL')": '41XX',
#   "('WETTED_MATERIAL', 'STRENGTH')": 80.0,
#   "('CASING_SIZE', 'value')": 7.0,
#   "('WEIGHT_RANGE', 'MAX')": 26.0,
#   "('WEIGHT_RANGE', 'MIN')": 20.0,
#   "('CERTIFICATION', 'value')": 'ISO-V3[150-350F]',
#   "('PRESSURE_RATING', 'value')": 5000.0,
#   "('EXTERNAL_PRESSURE', 'TEMP')": 350.0,
#   "('EXTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('ID_DRIFT', 'value')": 2.867,
#   "('INTERNAL_PRESSURE', 'TEMP')": 350.0,
#   "('INTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('LOWER_THREAD', 'CONFIG')": 'PIN',
#   "('LOWER_THREAD', 'SIZE')": 3.5,
#   "('LOWER_THREAD', 'TYPE')": 'EUE',
#   "('LOWER_THREAD', 'WT')": 9.3,
#   "('MATERIAL_ELEMENTS', 'value')": 'AFLAS',
#   "('MATERIAL_O_RING', 'value')": 'VITON',
#   "('OD_MAX', 'value')": 6.091,
#   "('QCG', 'value')": 'Q3',
#   "('QCP', 'value')": 'CLG QCP-102817386',
#   "('SERVICE_NACE', 'value')": True,
#   "('SETTING_PRESSURE', 'value')": 3000.0,
#   "('RELEASE_FORCE', 'value')": 103792.0,
#   "('TENSILE_STRENGTH', 'TEMP')": 350.0,
#   "('TENSILE_STRENGTH', 'STRENGTH')": 208000.0,
#   "('UPPER_THREAD', 'CONFIG')": 'BOX',
#   "('UPPER_THREAD', 'SIZE')": 3.5,
#   "('UPPER_THREAD', 'TYPE')": 'EUE',
#   "('UPPER_THREAD', 'WT')": 9.3},
#  '102939595_AC': {"('WETTED_MATERIAL', 'MATERIAL')": '41XX',
#   "('WETTED_MATERIAL', 'STRENGTH')": 80.0,
#   "('CASING_SIZE', 'value')": 7.0,
#   "('WEIGHT_RANGE', 'MAX')": 26.0,
#   "('WEIGHT_RANGE', 'MIN')": 23.0,
#   "('CERTIFICATION', 'value')": 'ISO-V3[150-350F]',
#   "('PRESSURE_RATING', 'value')": 5000.0,
#   "('EXTERNAL_PRESSURE', 'TEMP')": 350.0,
#   "('EXTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('ID_DRIFT', 'value')": 3.833,
#   "('INTERNAL_PRESSURE', 'TEMP')": 350.0,
#   "('INTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('LOWER_THREAD', 'CONFIG')": 'PIN',
#   "('LOWER_THREAD', 'SIZE')": 4.5,
#   "('LOWER_THREAD', 'TYPE')": 'NEW VAM',
#   "('LOWER_THREAD', 'WT')": 12.6,
#   "('MATERIAL_ELEMENTS', 'value')": 'AFLAS',
#   "('MATERIAL_O_RING', 'value')": 'VITON',
#   "('OD_MAX', 'value')": 6.091,
#   "('QCG', 'value')": 'Q3',
#   "('QCP', 'value')": 'CLG QCP-102817386',
#   "('SERVICE_NACE', 'value')": True,
#   "('SETTING_PRESSURE', 'value')": 2400.0,
#   "('RELEASE_FORCE', 'value')": 103792.0,
#   "('TENSILE_STRENGTH', 'TEMP')": 350.0,
#   "('TENSILE_STRENGTH', 'STRENGTH')": 208000.0,
#   "('UPPER_THREAD', 'CONFIG')": 'BOX',
#   "('UPPER_THREAD', 'SIZE')": 4.5,
#   "('UPPER_THREAD', 'TYPE')": 'NEW VAM',
#   "('UPPER_THREAD', 'WT')": 12.6},
#  '103068560_AB': {"('WETTED_MATERIAL', 'MATERIAL')": '41XX',
#   "('WETTED_MATERIAL', 'STRENGTH')": 80.0,
#   "('CASING_SIZE', 'value')": 7.0,
#   "('WEIGHT_RANGE', 'MAX')": 29.0,
#   "('WEIGHT_RANGE', 'MIN')": 23.0,
#   "('CERTIFICATION', 'value')": 'ISO-V3[150-325F]',
#   "('PRESSURE_RATING', 'value')": 5000.0,
#   "('EXTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('EXTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('ID_DRIFT', 'value')": 2.867,
#   "('INTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('INTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('LOWER_THREAD', 'CONFIG')": 'PIN',
#   "('LOWER_THREAD', 'SIZE')": 3.5,
#   "('LOWER_THREAD', 'TYPE')": 'VAM TOP',
#   "('LOWER_THREAD', 'WT')": 9.2,
#   "('MATERIAL_ELEMENTS', 'value')": 'HNBR',
#   "('MATERIAL_O_RING', 'value')": 'VITON',
#   "('OD_MAX', 'value')": 5.999,
#   "('QCG', 'value')": 'Q3',
#   "('QCP', 'value')": 'CLG QCP-102817386',
#   "('SERVICE_NACE', 'value')": True,
#   "('SETTING_PRESSURE', 'value')": 3000.0,
#   "('RELEASE_FORCE', 'value')": 103792.0,
#   "('TENSILE_STRENGTH', 'TEMP')": 325.0,
#   "('TENSILE_STRENGTH', 'STRENGTH')": 208000.0,
#   "('UPPER_THREAD', 'CONFIG')": 'BOX',
#   "('UPPER_THREAD', 'SIZE')": 3.5,
#   "('UPPER_THREAD', 'TYPE')": 'VAM TOP',
#   "('UPPER_THREAD', 'WT')": 9.2},
#  '103096024_AB': {"('WETTED_MATERIAL', 'MATERIAL')": '41XX',
#   "('WETTED_MATERIAL', 'STRENGTH')": 80.0,
#   "('CASING_SIZE', 'value')": 7.0,
#   "('WEIGHT_RANGE', 'MAX')": 29.0,
#   "('WEIGHT_RANGE', 'MIN')": 23.0,
#   "('CERTIFICATION', 'value')": 'ISO-V3[150-325F]',
#   "('PRESSURE_RATING', 'value')": 5000.0,
#   "('EXTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('EXTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('ID_DRIFT', 'value')": 2.347,
#   "('INTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('INTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('LOWER_THREAD', 'CONFIG')": 'PIN',
#   "('LOWER_THREAD', 'SIZE')": 2.875,
#   "('LOWER_THREAD', 'TYPE')": 'VAM TOP',
#   "('LOWER_THREAD', 'WT')": 6.4,
#   "('MATERIAL_ELEMENTS', 'value')": 'HNBR',
#   "('MATERIAL_O_RING', 'value')": 'VITON',
#   "('OD_MAX', 'value')": 5.999,
#   "('QCG', 'value')": 'Q3',
#   "('QCP', 'value')": 'CLG QCP-102817386',
#   "('SERVICE_NACE', 'value')": True,
#   "('SETTING_PRESSURE', 'value')": 3000.0,
#   "('RELEASE_FORCE', 'value')": 103792.0,
#   "('TENSILE_STRENGTH', 'TEMP')": 325.0,
#   "('TENSILE_STRENGTH', 'STRENGTH')": 144000.0,
#   "('UPPER_THREAD', 'CONFIG')": 'BOX',
#   "('UPPER_THREAD', 'SIZE')": 2.875,
#   "('UPPER_THREAD', 'TYPE')": 'VAM TOP',
#   "('UPPER_THREAD', 'WT')": 6.4},
#  '103202448_AB': {"('WETTED_MATERIAL', 'MATERIAL')": '41XX',
#   "('WETTED_MATERIAL', 'STRENGTH')": 80.0,
#   "('CASING_SIZE', 'value')": 7.0,
#   "('WEIGHT_RANGE', 'MAX')": 29.0,
#   "('WEIGHT_RANGE', 'MIN')": 23.0,
#   "('CERTIFICATION', 'value')": 'ISO-V3[150-325F]',
#   "('PRESSURE_RATING', 'value')": 5000.0,
#   "('EXTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('EXTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('ID_DRIFT', 'value')": 2.347,
#   "('INTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('INTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('LOWER_THREAD', 'CONFIG')": 'PIN',
#   "('LOWER_THREAD', 'SIZE')": 2.875,
#   "('LOWER_THREAD', 'TYPE')": 'FOX',
#   "('LOWER_THREAD', 'WT')": 6.4,
#   "('MATERIAL_ELEMENTS', 'value')": 'HNBR',
#   "('MATERIAL_O_RING', 'value')": 'VITON',
#   "('OD_MAX', 'value')": 5.999,
#   "('QCG', 'value')": 'Q3',
#   "('QCP', 'value')": 'CLG QCP-102817386',
#   "('SERVICE_NACE', 'value')": True,
#   "('SETTING_PRESSURE', 'value')": 3000.0,
#   "('RELEASE_FORCE', 'value')": 103792.0,
#   "('TENSILE_STRENGTH', 'TEMP')": 325.0,
#   "('TENSILE_STRENGTH', 'STRENGTH')": 144000.0,
#   "('UPPER_THREAD', 'CONFIG')": 'BOX',
#   "('UPPER_THREAD', 'SIZE')": 2.875,
#   "('UPPER_THREAD', 'TYPE')": 'FOX',
#   "('UPPER_THREAD', 'WT')": 6.4},
#  '103207686_AB': {"('WETTED_MATERIAL', 'MATERIAL')": '41XX',
#   "('WETTED_MATERIAL', 'STRENGTH')": 80.0,
#   "('CASING_SIZE', 'value')": 7.0,
#   "('WEIGHT_RANGE', 'MAX')": 29.0,
#   "('WEIGHT_RANGE', 'MIN')": 23.0,
#   "('CERTIFICATION', 'value')": 'ISO-V3[150-325F]',
#   "('PRESSURE_RATING', 'value')": 5000.0,
#   "('EXTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('EXTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('ID_DRIFT', 'value')": 2.347,
#   "('INTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('INTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('LOWER_THREAD', 'CONFIG')": 'PIN',
#   "('LOWER_THREAD', 'SIZE')": 2.875,
#   "('LOWER_THREAD', 'TYPE')": 'JFE BEAR',
#   "('LOWER_THREAD', 'WT')": 6.4,
#   "('MATERIAL_ELEMENTS', 'value')": 'HNBR',
#   "('MATERIAL_O_RING', 'value')": 'VITON',
#   "('OD_MAX', 'value')": 5.999,
#   "('QCG', 'value')": 'Q3',
#   "('QCP', 'value')": 'CLG QCP-102817386',
#   "('SERVICE_NACE', 'value')": True,
#   "('SETTING_PRESSURE', 'value')": 3000.0,
#   "('RELEASE_FORCE', 'value')": 103792.0,
#   "('TENSILE_STRENGTH', 'TEMP')": 325.0,
#   "('TENSILE_STRENGTH', 'STRENGTH')": 144000.0,
#   "('UPPER_THREAD', 'CONFIG')": 'BOX',
#   "('UPPER_THREAD', 'SIZE')": 2.875,
#   "('UPPER_THREAD', 'TYPE')": 'JFE BEAR',
#   "('UPPER_THREAD', 'WT')": 6.4},
#  '103210361_AA': {"('WETTED_MATERIAL', 'MATERIAL')": '41XX',
#   "('WETTED_MATERIAL', 'STRENGTH')": 80.0,
#   "('CASING_SIZE', 'value')": 7.0,
#   "('WEIGHT_RANGE', 'MAX')": 29.0,
#   "('WEIGHT_RANGE', 'MIN')": 23.0,
#   "('CERTIFICATION', 'value')": 'ISO-V3[150-325F]',
#   "('PRESSURE_RATING', 'value')": 5000.0,
#   "('EXTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('EXTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('ID_DRIFT', 'value')": 2.867,
#   "('INTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('INTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('LOWER_THREAD', 'CONFIG')": 'PIN',
#   "('LOWER_THREAD', 'SIZE')": 3.5,
#   "('LOWER_THREAD', 'TYPE')": 'JFE BEAR',
#   "('LOWER_THREAD', 'WT')": 9.2,
#   "('MATERIAL_ELEMENTS', 'value')": 'HNBR',
#   "('MATERIAL_O_RING', 'value')": 'VITON',
#   "('OD_MAX', 'value')": 5.999,
#   "('QCG', 'value')": 'Q3',
#   "('QCP', 'value')": 'CLG QCP-102817386',
#   "('SERVICE_NACE', 'value')": True,
#   "('SETTING_PRESSURE', 'value')": 3000.0,
#   "('RELEASE_FORCE', 'value')": 103792.0,
#   "('TENSILE_STRENGTH', 'TEMP')": 325.0,
#   "('TENSILE_STRENGTH', 'STRENGTH')": 208000.0,
#   "('UPPER_THREAD', 'CONFIG')": 'BOX',
#   "('UPPER_THREAD', 'SIZE')": 3.5,
#   "('UPPER_THREAD', 'TYPE')": 'JFE BEAR',
#   "('UPPER_THREAD', 'WT')": 9.2},
#  '103232089_AA': {"('WETTED_MATERIAL', 'MATERIAL')": '41XX',
#   "('WETTED_MATERIAL', 'STRENGTH')": 80.0,
#   "('CASING_SIZE', 'value')": 7.0,
#   "('WEIGHT_RANGE', 'MAX')": 29.0,
#   "('WEIGHT_RANGE', 'MIN')": 23.0,
#   "('CERTIFICATION', 'value')": 'ISO-V3[150-325F]',
#   "('PRESSURE_RATING', 'value')": 5000.0,
#   "('EXTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('EXTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('ID_DRIFT', 'value')": 2.347,
#   "('INTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('INTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('LOWER_THREAD', 'CONFIG')": 'PIN',
#   "('LOWER_THREAD', 'SIZE')": 2.875,
#   "('LOWER_THREAD', 'TYPE')": 'TENARIS HYDRIL BLUE',
#   "('LOWER_THREAD', 'WT')": 6.4,
#   "('MATERIAL_ELEMENTS', 'value')": 'HNBR',
#   "('MATERIAL_O_RING', 'value')": 'VITON',
#   "('OD_MAX', 'value')": 5.999,
#   "('QCG', 'value')": 'Q3',
#   "('QCP', 'value')": 'CLG QCP-102817386',
#   "('SERVICE_NACE', 'value')": True,
#   "('SETTING_PRESSURE', 'value')": 3000.0,
#   "('RELEASE_FORCE', 'value')": 103792.0,
#   "('TENSILE_STRENGTH', 'TEMP')": 325.0,
#   "('TENSILE_STRENGTH', 'STRENGTH')": 144000.0,
#   "('UPPER_THREAD', 'CONFIG')": 'BOX',
#   "('UPPER_THREAD', 'SIZE')": 2.875,
#   "('UPPER_THREAD', 'TYPE')": 'TENARIS HYDRIL BLUE',
#   "('UPPER_THREAD', 'WT')": 6.4}}

# %%
#  Dict for json for other match

ia_df_om = ia_df_basic_cols.loc[s_filter_result_sum[s_filter_result_sum < len(ia_criteries)].sort_values(ascending = False).index]
dict_df_om = ia_df_om.to_dict('index')
{rec_id:{str(col_id):dict_df_om[rec_id][col_id] for col_id in dict_df_om[rec_id]} for rec_id in dict_df_om.keys()}
# Out:
# {'103232093_AA': {"('WETTED_MATERIAL', 'MATERIAL')": '41XX',
#   "('WETTED_MATERIAL', 'STRENGTH')": 80.0,
#   "('CASING_SIZE', 'value')": 7.0,
#   "('WEIGHT_RANGE', 'MAX')": 32.0,
#   "('WEIGHT_RANGE', 'MIN')": 26.0,
#   "('CERTIFICATION', 'value')": 'ISO-V3[150-325F]',
#   "('PRESSURE_RATING', 'value')": 5000.0,
#   "('EXTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('EXTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('ID_DRIFT', 'value')": 2.867,
#   "('INTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('INTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('LOWER_THREAD', 'CONFIG')": 'PIN',
#   "('LOWER_THREAD', 'SIZE')": 3.5,
#   "('LOWER_THREAD', 'TYPE')": 'TENARIS HYDRIL BLUE',
#   "('LOWER_THREAD', 'WT')": 9.2,
#   "('MATERIAL_ELEMENTS', 'value')": 'HNBR',
#   "('MATERIAL_O_RING', 'value')": 'VITON',
#   "('OD_MAX', 'value')": 5.909,
#   "('QCG', 'value')": 'Q3',
#   "('QCP', 'value')": 'CLG QCP-102817386',
#   "('SERVICE_NACE', 'value')": True,
#   "('SETTING_PRESSURE', 'value')": 3000.0,
#   "('RELEASE_FORCE', 'value')": 103792.0,
#   "('TENSILE_STRENGTH', 'TEMP')": 325.0,
#   "('TENSILE_STRENGTH', 'STRENGTH')": 208000.0,
#   "('UPPER_THREAD', 'CONFIG')": 'BOX',
#   "('UPPER_THREAD', 'SIZE')": 3.5,
#   "('UPPER_THREAD', 'TYPE')": 'TENARIS HYDRIL BLUE',
#   "('UPPER_THREAD', 'WT')": 9.2},
#  '103000049_AA': {"('WETTED_MATERIAL', 'MATERIAL')": '9CR',
#   "('WETTED_MATERIAL', 'STRENGTH')": 80.0,
#   "('CASING_SIZE', 'value')": 7.0,
#   "('WEIGHT_RANGE', 'MAX')": 26.0,
#   "('WEIGHT_RANGE', 'MIN')": 23.0,
#   "('CERTIFICATION', 'value')": 'ISO-V3[150-325F]',
#   "('PRESSURE_RATING', 'value')": 5000.0,
#   "('EXTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('EXTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('ID_DRIFT', 'value')": 3.833,
#   "('INTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('INTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('LOWER_THREAD', 'CONFIG')": 'PIN',
#   "('LOWER_THREAD', 'SIZE')": 4.46,
#   "('LOWER_THREAD', 'TYPE')": 'STUB ACME',
#   "('LOWER_THREAD', 'WT')": 12.0,
#   "('MATERIAL_ELEMENTS', 'value')": 'HNBR',
#   "('MATERIAL_O_RING', 'value')": 'VITON',
#   "('OD_MAX', 'value')": 6.091,
#   "('QCG', 'value')": 'Q3',
#   "('QCP', 'value')": 'CLG QCP-102817386',
#   "('SERVICE_NACE', 'value')": True,
#   "('SETTING_PRESSURE', 'value')": 3000.0,
#   "('RELEASE_FORCE', 'value')": 103792.0,
#   "('TENSILE_STRENGTH', 'TEMP')": 325.0,
#   "('TENSILE_STRENGTH', 'STRENGTH')": 208000.0,
#   "('UPPER_THREAD', 'CONFIG')": 'PIN',
#   "('UPPER_THREAD', 'SIZE')": 4.46,
#   "('UPPER_THREAD', 'TYPE')": 'STUB ACME',
#   "('UPPER_THREAD', 'WT')": 12.0},
#  '102055050_AC': {"('WETTED_MATERIAL', 'MATERIAL')": '41XX',
#   "('WETTED_MATERIAL', 'STRENGTH')": 80.0,
#   "('CASING_SIZE', 'value')": 7.0,
#   "('WEIGHT_RANGE', 'MAX')": 32.0,
#   "('WEIGHT_RANGE', 'MIN')": 26.0,
#   "('CERTIFICATION', 'value')": 'ISO-V3[150-325F]',
#   "('PRESSURE_RATING', 'value')": 5000.0,
#   "('EXTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('EXTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('ID_DRIFT', 'value')": 3.833,
#   "('INTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('INTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('LOWER_THREAD', 'CONFIG')": 'PIN',
#   "('LOWER_THREAD', 'SIZE')": 4.5,
#   "('LOWER_THREAD', 'TYPE')": 'EUE',
#   "('LOWER_THREAD', 'WT')": 12.75,
#   "('MATERIAL_ELEMENTS', 'value')": 'HNBR',
#   "('MATERIAL_O_RING', 'value')": 'VITON',
#   "('OD_MAX', 'value')": 5.909,
#   "('QCG', 'value')": 'Q3',
#   "('QCP', 'value')": 'CLG QCP-102817386',
#   "('SERVICE_NACE', 'value')": True,
#   "('SETTING_PRESSURE', 'value')": 3000.0,
#   "('RELEASE_FORCE', 'value')": 103792.0,
#   "('TENSILE_STRENGTH', 'TEMP')": 325.0,
#   "('TENSILE_STRENGTH', 'STRENGTH')": 208000.0,
#   "('UPPER_THREAD', 'CONFIG')": 'BOX',
#   "('UPPER_THREAD', 'SIZE')": 4.5,
#   "('UPPER_THREAD', 'TYPE')": 'EUE',
#   "('UPPER_THREAD', 'WT')": 12.75},
#  '102103987_AG': {"('WETTED_MATERIAL', 'MATERIAL')": '41XX',
#   "('WETTED_MATERIAL', 'STRENGTH')": 80.0,
#   "('CASING_SIZE', 'value')": 4.5,
#   "('WEIGHT_RANGE', 'MAX')": 13.5,
#   "('WEIGHT_RANGE', 'MIN')": 9.5,
#   "('CERTIFICATION', 'value')": 'ISO-V3[150-325F]',
#   "('PRESSURE_RATING', 'value')": 5000.0,
#   "('EXTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('EXTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('ID_DRIFT', 'value')": 1.901,
#   "('INTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('INTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('LOWER_THREAD', 'CONFIG')": 'PIN',
#   "('LOWER_THREAD', 'SIZE')": 2.375,
#   "('LOWER_THREAD', 'TYPE')": 'EUE',
#   "('LOWER_THREAD', 'WT')": 4.7,
#   "('MATERIAL_ELEMENTS', 'value')": 'HNBR',
#   "('MATERIAL_O_RING', 'value')": 'VITON',
#   "('OD_MAX', 'value')": 3.75,
#   "('QCG', 'value')": 'Q3',
#   "('QCP', 'value')": 'CLG QCP-102817386',
#   "('SERVICE_NACE', 'value')": True,
#   "('SETTING_PRESSURE', 'value')": 2500.0,
#   "('RELEASE_FORCE', 'value')": 77844.0,
#   "('TENSILE_STRENGTH', 'TEMP')": 325.0,
#   "('TENSILE_STRENGTH', 'STRENGTH')": 101000.0,
#   "('UPPER_THREAD', 'CONFIG')": 'BOX',
#   "('UPPER_THREAD', 'SIZE')": 2.375,
#   "('UPPER_THREAD', 'TYPE')": 'EUE',
#   "('UPPER_THREAD', 'WT')": 4.7},
#  '102727939_AC': {"('WETTED_MATERIAL', 'MATERIAL')": '41XX',
#   "('WETTED_MATERIAL', 'STRENGTH')": 110.0,
#   "('CASING_SIZE', 'value')": 7.0,
#   "('WEIGHT_RANGE', 'MAX')": 32.0,
#   "('WEIGHT_RANGE', 'MIN')": 26.0,
#   "('CERTIFICATION', 'value')": 'ISO-V6[AMBIENT]',
#   "('PRESSURE_RATING', 'value')": 6000.0,
#   "('EXTERNAL_PRESSURE', 'TEMP')": 0.0,
#   "('EXTERNAL_PRESSURE', 'PRESSURE')": 6000.0,
#   "('ID_DRIFT', 'value')": 3.833,
#   "('INTERNAL_PRESSURE', 'TEMP')": 0.0,
#   "('INTERNAL_PRESSURE', 'PRESSURE')": 7500.0,
#   "('LOWER_THREAD', 'CONFIG')": 'PIN',
#   "('LOWER_THREAD', 'SIZE')": 4.46,
#   "('LOWER_THREAD', 'TYPE')": 'STUB ACME',
#   "('LOWER_THREAD', 'WT')": 12.0,
#   "('MATERIAL_ELEMENTS', 'value')": 'HNBR',
#   "('MATERIAL_O_RING', 'value')": 'VITON',
#   "('OD_MAX', 'value')": 5.909,
#   "('QCG', 'value')": 'Q3',
#   "('QCP', 'value')": 'CLG QCP-102817386',
#   "('SERVICE_NACE', 'value')": False,
#   "('SETTING_PRESSURE', 'value')": 3000.0,
#   "('RELEASE_FORCE', 'value')": 129740.0,
#   "('TENSILE_STRENGTH', 'TEMP')": 0.0,
#   "('TENSILE_STRENGTH', 'STRENGTH')": 324890.0,
#   "('UPPER_THREAD', 'CONFIG')": 'PIN',
#   "('UPPER_THREAD', 'SIZE')": 4.46,
#   "('UPPER_THREAD', 'TYPE')": 'STUB ACME',
#   "('UPPER_THREAD', 'WT')": 12.0},
#  '102740546_AB': {"('WETTED_MATERIAL', 'MATERIAL')": '9CR',
#   "('WETTED_MATERIAL', 'STRENGTH')": 80.0,
#   "('CASING_SIZE', 'value')": 6.625,
#   "('WEIGHT_RANGE', 'MAX')": 28.0,
#   "('WEIGHT_RANGE', 'MIN')": 24.0,
#   "('CERTIFICATION', 'value')": 'ISO-V1[150-325F]',
#   "('PRESSURE_RATING', 'value')": 5000.0,
#   "('EXTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('EXTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('ID_DRIFT', 'value')": 2.867,
#   "('INTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('INTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('LOWER_THREAD', 'CONFIG')": 'PIN',
#   "('LOWER_THREAD', 'SIZE')": 3.5,
#   "('LOWER_THREAD', 'TYPE')": 'VAM TOP',
#   "('LOWER_THREAD', 'WT')": 9.2,
#   "('MATERIAL_ELEMENTS', 'value')": 'HNBR',
#   "('MATERIAL_O_RING', 'value')": 'VITON',
#   "('OD_MAX', 'value')": 5.606,
#   "('QCG', 'value')": 'Q3',
#   "('QCP', 'value')": 'CLG QCP-102817386',
#   "('SERVICE_NACE', 'value')": True,
#   "('SETTING_PRESSURE', 'value')": 3000.0,
#   "('RELEASE_FORCE', 'value')": 116766.0,
#   "('TENSILE_STRENGTH', 'TEMP')": 325.0,
#   "('TENSILE_STRENGTH', 'STRENGTH')": 208000.0,
#   "('UPPER_THREAD', 'CONFIG')": 'BOX',
#   "('UPPER_THREAD', 'SIZE')": 3.5,
#   "('UPPER_THREAD', 'TYPE')": 'VAM TOP',
#   "('UPPER_THREAD', 'WT')": 9.2},
#  '102743322_AD': {"('WETTED_MATERIAL', 'MATERIAL')": '41XX',
#   "('WETTED_MATERIAL', 'STRENGTH')": 80.0,
#   "('CASING_SIZE', 'value')": 7.0,
#   "('WEIGHT_RANGE', 'MAX')": 32.0,
#   "('WEIGHT_RANGE', 'MIN')": 26.0,
#   "('CERTIFICATION', 'value')": 'ISO-V3[150-325F]',
#   "('PRESSURE_RATING', 'value')": 5000.0,
#   "('EXTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('EXTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('ID_DRIFT', 'value')": 2.867,
#   "('INTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('INTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('LOWER_THREAD', 'CONFIG')": 'PIN',
#   "('LOWER_THREAD', 'SIZE')": 3.5,
#   "('LOWER_THREAD', 'TYPE')": 'EUE',
#   "('LOWER_THREAD', 'WT')": 9.3,
#   "('MATERIAL_ELEMENTS', 'value')": 'HNBR',
#   "('MATERIAL_O_RING', 'value')": 'VITON',
#   "('OD_MAX', 'value')": 5.909,
#   "('QCG', 'value')": 'Q3',
#   "('QCP', 'value')": 'CLG QCP-102817386',
#   "('SERVICE_NACE', 'value')": True,
#   "('SETTING_PRESSURE', 'value')": 3000.0,
#   "('RELEASE_FORCE', 'value')": 103792.0,
#   "('TENSILE_STRENGTH', 'TEMP')": 325.0,
#   "('TENSILE_STRENGTH', 'STRENGTH')": 208000.0,
#   "('UPPER_THREAD', 'CONFIG')": 'BOX',
#   "('UPPER_THREAD', 'SIZE')": 3.5,
#   "('UPPER_THREAD', 'TYPE')": 'EUE',
#   "('UPPER_THREAD', 'WT')": 9.3},
#  '102750404_AB': {"('WETTED_MATERIAL', 'MATERIAL')": '41XX',
#   "('WETTED_MATERIAL', 'STRENGTH')": 80.0,
#   "('CASING_SIZE', 'value')": 7.0,
#   "('WEIGHT_RANGE', 'MAX')": 32.0,
#   "('WEIGHT_RANGE', 'MIN')": 26.0,
#   "('CERTIFICATION', 'value')": 'ISO-V3[150-325F]',
#   "('PRESSURE_RATING', 'value')": 5000.0,
#   "('EXTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('EXTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('ID_DRIFT', 'value')": 3.833,
#   "('INTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('INTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('LOWER_THREAD', 'CONFIG')": 'PIN',
#   "('LOWER_THREAD', 'SIZE')": 4.5,
#   "('LOWER_THREAD', 'TYPE')": 'VAM TOP',
#   "('LOWER_THREAD', 'WT')": 12.6,
#   "('MATERIAL_ELEMENTS', 'value')": 'HNBR',
#   "('MATERIAL_O_RING', 'value')": 'VITON',
#   "('OD_MAX', 'value')": 5.909,
#   "('QCG', 'value')": 'Q3',
#   "('QCP', 'value')": 'CLG QCP-102817386',
#   "('SERVICE_NACE', 'value')": True,
#   "('SETTING_PRESSURE', 'value')": 3000.0,
#   "('RELEASE_FORCE', 'value')": 103792.0,
#   "('TENSILE_STRENGTH', 'TEMP')": 325.0,
#   "('TENSILE_STRENGTH', 'STRENGTH')": 208000.0,
#   "('UPPER_THREAD', 'CONFIG')": 'BOX',
#   "('UPPER_THREAD', 'SIZE')": 4.5,
#   "('UPPER_THREAD', 'TYPE')": 'VAM TOP',
#   "('UPPER_THREAD', 'WT')": 12.6},
#  '102825695_AC': {"('WETTED_MATERIAL', 'MATERIAL')": '13CR',
#   "('WETTED_MATERIAL', 'STRENGTH')": 80.0,
#   "('CASING_SIZE', 'value')": 6.625,
#   "('WEIGHT_RANGE', 'MAX')": 28.0,
#   "('WEIGHT_RANGE', 'MIN')": 24.0,
#   "('CERTIFICATION', 'value')": 'ISO-V3[150-325F, 40-235F]',
#   "('PRESSURE_RATING', 'value')": 5000.0,
#   "('EXTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('EXTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('ID_DRIFT', 'value')": 2.867,
#   "('INTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('INTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('LOWER_THREAD', 'CONFIG')": 'PIN',
#   "('LOWER_THREAD', 'SIZE')": 3.5,
#   "('LOWER_THREAD', 'TYPE')": 'VAM TOP',
#   "('LOWER_THREAD', 'WT')": 9.2,
#   "('MATERIAL_ELEMENTS', 'value')": 'HNBR',
#   "('MATERIAL_O_RING', 'value')": 'VITON',
#   "('OD_MAX', 'value')": 5.606,
#   "('QCG', 'value')": 'Q3',
#   "('QCP', 'value')": 'CLG QCP-102817386',
#   "('SERVICE_NACE', 'value')": True,
#   "('SETTING_PRESSURE', 'value')": 3000.0,
#   "('RELEASE_FORCE', 'value')": 116766.0,
#   "('TENSILE_STRENGTH', 'TEMP')": 325.0,
#   "('TENSILE_STRENGTH', 'STRENGTH')": 208000.0,
#   "('UPPER_THREAD', 'CONFIG')": 'BOX',
#   "('UPPER_THREAD', 'SIZE')": 3.5,
#   "('UPPER_THREAD', 'TYPE')": 'VAM TOP',
#   "('UPPER_THREAD', 'WT')": 9.2},
#  '102832618_AD': {"('WETTED_MATERIAL', 'MATERIAL')": '13CR',
#   "('WETTED_MATERIAL', 'STRENGTH')": 80.0,
#   "('CASING_SIZE', 'value')": 7.0,
#   "('WEIGHT_RANGE', 'MAX')": 29.0,
#   "('WEIGHT_RANGE', 'MIN')": 23.0,
#   "('CERTIFICATION', 'value')": 'ISO-V3[150-325F]',
#   "('PRESSURE_RATING', 'value')": 5000.0,
#   "('EXTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('EXTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('ID_DRIFT', 'value')": 2.867,
#   "('INTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('INTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('LOWER_THREAD', 'CONFIG')": 'PIN',
#   "('LOWER_THREAD', 'SIZE')": 3.5,
#   "('LOWER_THREAD', 'TYPE')": 'VAM TOP',
#   "('LOWER_THREAD', 'WT')": 9.2,
#   "('MATERIAL_ELEMENTS', 'value')": 'HNBR',
#   "('MATERIAL_O_RING', 'value')": 'VITON',
#   "('OD_MAX', 'value')": 5.999,
#   "('QCG', 'value')": 'Q3',
#   "('QCP', 'value')": 'CLG QCP-102817386',
#   "('SERVICE_NACE', 'value')": True,
#   "('SETTING_PRESSURE', 'value')": 3000.0,
#   "('RELEASE_FORCE', 'value')": 103792.0,
#   "('TENSILE_STRENGTH', 'TEMP')": 325.0,
#   "('TENSILE_STRENGTH', 'STRENGTH')": 208000.0,
#   "('UPPER_THREAD', 'CONFIG')": 'BOX',
#   "('UPPER_THREAD', 'SIZE')": 3.5,
#   "('UPPER_THREAD', 'TYPE')": 'VAM TOP',
#   "('UPPER_THREAD', 'WT')": 9.2},
#  '102869425_AC': {"('WETTED_MATERIAL', 'MATERIAL')": '9CR-1MO',
#   "('WETTED_MATERIAL', 'STRENGTH')": 80.0,
#   "('CASING_SIZE', 'value')": 7.0,
#   "('WEIGHT_RANGE', 'MAX')": 29.0,
#   "('WEIGHT_RANGE', 'MIN')": 23.0,
#   "('CERTIFICATION', 'value')": 'ISO-V3[150-325F]',
#   "('PRESSURE_RATING', 'value')": 5000.0,
#   "('EXTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('EXTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('ID_DRIFT', 'value')": 2.867,
#   "('INTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('INTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('LOWER_THREAD', 'CONFIG')": 'PIN',
#   "('LOWER_THREAD', 'SIZE')": 3.5,
#   "('LOWER_THREAD', 'TYPE')": 'EUE',
#   "('LOWER_THREAD', 'WT')": 9.3,
#   "('MATERIAL_ELEMENTS', 'value')": 'HNBR',
#   "('MATERIAL_O_RING', 'value')": 'VITON',
#   "('OD_MAX', 'value')": 5.999,
#   "('QCG', 'value')": 'Q3',
#   "('QCP', 'value')": 'CLG QCP-102817386',
#   "('SERVICE_NACE', 'value')": True,
#   "('SETTING_PRESSURE', 'value')": 3000.0,
#   "('RELEASE_FORCE', 'value')": 103792.0,
#   "('TENSILE_STRENGTH', 'TEMP')": 325.0,
#   "('TENSILE_STRENGTH', 'STRENGTH')": 208000.0,
#   "('UPPER_THREAD', 'CONFIG')": 'BOX',
#   "('UPPER_THREAD', 'SIZE')": 3.5,
#   "('UPPER_THREAD', 'TYPE')": 'EUE',
#   "('UPPER_THREAD', 'WT')": 9.3},
#  '102883107_AC': {"('WETTED_MATERIAL', 'MATERIAL')": '9CR-1MO',
#   "('WETTED_MATERIAL', 'STRENGTH')": 80.0,
#   "('CASING_SIZE', 'value')": 7.0,
#   "('WEIGHT_RANGE', 'MAX')": 29.0,
#   "('WEIGHT_RANGE', 'MIN')": 23.0,
#   "('CERTIFICATION', 'value')": 'ISO-V3[150-325F]',
#   "('PRESSURE_RATING', 'value')": 5000.0,
#   "('EXTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('EXTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('ID_DRIFT', 'value')": 2.867,
#   "('INTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('INTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('LOWER_THREAD', 'CONFIG')": 'PIN',
#   "('LOWER_THREAD', 'SIZE')": 3.5,
#   "('LOWER_THREAD', 'TYPE')": 'EUE',
#   "('LOWER_THREAD', 'WT')": 9.3,
#   "('MATERIAL_ELEMENTS', 'value')": 'HNBR',
#   "('MATERIAL_O_RING', 'value')": 'VITON',
#   "('OD_MAX', 'value')": 5.999,
#   "('QCG', 'value')": 'Q3',
#   "('QCP', 'value')": 'CLG QCP-102817386',
#   "('SERVICE_NACE', 'value')": True,
#   "('SETTING_PRESSURE', 'value')": 3000.0,
#   "('RELEASE_FORCE', 'value')": 103792.0,
#   "('TENSILE_STRENGTH', 'TEMP')": 325.0,
#   "('TENSILE_STRENGTH', 'STRENGTH')": 208000.0,
#   "('UPPER_THREAD', 'CONFIG')": 'PIN',
#   "('UPPER_THREAD', 'SIZE')": 3.5,
#   "('UPPER_THREAD', 'TYPE')": 'EUE',
#   "('UPPER_THREAD', 'WT')": 9.3},
#  '103232088_AA': {"('WETTED_MATERIAL', 'MATERIAL')": '41XX',
#   "('WETTED_MATERIAL', 'STRENGTH')": 80.0,
#   "('CASING_SIZE', 'value')": 4.5,
#   "('WEIGHT_RANGE', 'MAX')": 13.5,
#   "('WEIGHT_RANGE', 'MIN')": 9.5,
#   "('CERTIFICATION', 'value')": 'ISO-V3[150-325F]',
#   "('PRESSURE_RATING', 'value')": 5000.0,
#   "('EXTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('EXTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('ID_DRIFT', 'value')": 1.901,
#   "('INTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('INTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('LOWER_THREAD', 'CONFIG')": 'PIN',
#   "('LOWER_THREAD', 'SIZE')": 2.375,
#   "('LOWER_THREAD', 'TYPE')": 'TENARIS HYDRIL BLUE',
#   "('LOWER_THREAD', 'WT')": 4.6,
#   "('MATERIAL_ELEMENTS', 'value')": 'HNBR',
#   "('MATERIAL_O_RING', 'value')": 'VITON',
#   "('OD_MAX', 'value')": 3.75,
#   "('QCG', 'value')": 'Q3',
#   "('QCP', 'value')": 'CLG QCP-102817386',
#   "('SERVICE_NACE', 'value')": True,
#   "('SETTING_PRESSURE', 'value')": 2500.0,
#   "('RELEASE_FORCE', 'value')": 77844.0,
#   "('TENSILE_STRENGTH', 'TEMP')": 325.0,
#   "('TENSILE_STRENGTH', 'STRENGTH')": 101000.0,
#   "('UPPER_THREAD', 'CONFIG')": 'BOX',
#   "('UPPER_THREAD', 'SIZE')": 2.375,
#   "('UPPER_THREAD', 'TYPE')": 'TENARIS HYDRIL BLUE',
#   "('UPPER_THREAD', 'WT')": 4.6},
#  '102947913_AC': {"('WETTED_MATERIAL', 'MATERIAL')": '41XX',
#   "('WETTED_MATERIAL', 'STRENGTH')": 80.0,
#   "('CASING_SIZE', 'value')": 5.5,
#   "('WEIGHT_RANGE', 'MAX')": 23.0,
#   "('WEIGHT_RANGE', 'MIN')": 17.0,
#   "('CERTIFICATION', 'value')": 'ISO-V3[150-325F]',
#   "('PRESSURE_RATING', 'value')": 5000.0,
#   "('EXTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('EXTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('ID_DRIFT', 'value')": 2.347,
#   "('INTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('INTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('LOWER_THREAD', 'CONFIG')": 'PIN',
#   "('LOWER_THREAD', 'SIZE')": 2.875,
#   "('LOWER_THREAD', 'TYPE')": 'EUE',
#   "('LOWER_THREAD', 'WT')": 6.5,
#   "('MATERIAL_ELEMENTS', 'value')": 'HNBR',
#   "('MATERIAL_O_RING', 'value')": 'VITON',
#   "('OD_MAX', 'value')": 4.5,
#   "('QCG', 'value')": 'Q3',
#   "('QCP', 'value')": 'CLG QCP-102817386',
#   "('SERVICE_NACE', 'value')": True,
#   "('SETTING_PRESSURE', 'value')": 2500.0,
#   "('RELEASE_FORCE', 'value')": 77844.0,
#   "('TENSILE_STRENGTH', 'TEMP')": 325.0,
#   "('TENSILE_STRENGTH', 'STRENGTH')": 144000.0,
#   "('UPPER_THREAD', 'CONFIG')": 'BOX',
#   "('UPPER_THREAD', 'SIZE')": 2.875,
#   "('UPPER_THREAD', 'TYPE')": 'EUE',
#   "('UPPER_THREAD', 'WT')": 6.5},
#  '102961957_AB': {"('WETTED_MATERIAL', 'MATERIAL')": '41XX',
#   "('WETTED_MATERIAL', 'STRENGTH')": 80.0,
#   "('CASING_SIZE', 'value')": 5.5,
#   "('WEIGHT_RANGE', 'MAX')": 17.0,
#   "('WEIGHT_RANGE', 'MIN')": 13.0,
#   "('CERTIFICATION', 'value')": 'ISO-V3[150-325F]',
#   "('PRESSURE_RATING', 'value')": 5000.0,
#   "('EXTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('EXTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('ID_DRIFT', 'value')": 2.347,
#   "('INTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('INTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('LOWER_THREAD', 'CONFIG')": 'PIN',
#   "('LOWER_THREAD', 'SIZE')": 2.875,
#   "('LOWER_THREAD', 'TYPE')": 'EUE',
#   "('LOWER_THREAD', 'WT')": 6.5,
#   "('MATERIAL_ELEMENTS', 'value')": 'HNBR',
#   "('MATERIAL_O_RING', 'value')": 'VITON',
#   "('OD_MAX', 'value')": 4.705,
#   "('QCG', 'value')": 'Q3',
#   "('QCP', 'value')": 'CLG QCP-102817386',
#   "('SERVICE_NACE', 'value')": True,
#   "('SETTING_PRESSURE', 'value')": 2500.0,
#   "('RELEASE_FORCE', 'value')": 77844.0,
#   "('TENSILE_STRENGTH', 'TEMP')": 325.0,
#   "('TENSILE_STRENGTH', 'STRENGTH')": 144000.0,
#   "('UPPER_THREAD', 'CONFIG')": 'BOX',
#   "('UPPER_THREAD', 'SIZE')": 2.875,
#   "('UPPER_THREAD', 'TYPE')": 'EUE',
#   "('UPPER_THREAD', 'WT')": 6.5},
#  '102041421_AB': {"('WETTED_MATERIAL', 'MATERIAL')": '9CR',
#   "('WETTED_MATERIAL', 'STRENGTH')": 80.0,
#   "('CASING_SIZE', 'value')": 7.0,
#   "('WEIGHT_RANGE', 'MAX')": 26.0,
#   "('WEIGHT_RANGE', 'MIN')": 23.0,
#   "('CERTIFICATION', 'value')": 'ISO-V3[150-325F]',
#   "('PRESSURE_RATING', 'value')": 5000.0,
#   "('EXTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('EXTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('ID_DRIFT', 'value')": 3.833,
#   "('INTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('INTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('LOWER_THREAD', 'CONFIG')": 'PIN',
#   "('LOWER_THREAD', 'SIZE')": 4.46,
#   "('LOWER_THREAD', 'TYPE')": 'STUB ACME',
#   "('LOWER_THREAD', 'WT')": 12.0,
#   "('MATERIAL_ELEMENTS', 'value')": 'HNBR',
#   "('MATERIAL_O_RING', 'value')": 'VITON',
#   "('OD_MAX', 'value')": 6.091,
#   "('QCG', 'value')": 'Q3',
#   "('QCP', 'value')": 'QCP-101792794',
#   "('SERVICE_NACE', 'value')": True,
#   "('SETTING_PRESSURE', 'value')": 3000.0,
#   "('RELEASE_FORCE', 'value')": 103792.0,
#   "('TENSILE_STRENGTH', 'TEMP')": 325.0,
#   "('TENSILE_STRENGTH', 'STRENGTH')": 208000.0,
#   "('UPPER_THREAD', 'CONFIG')": 'PIN',
#   "('UPPER_THREAD', 'SIZE')": 4.46,
#   "('UPPER_THREAD', 'TYPE')": 'STUB ACME',
#   "('UPPER_THREAD', 'WT')": 12.0},
#  '103232076_AA': {"('WETTED_MATERIAL', 'MATERIAL')": '41XX',
#   "('WETTED_MATERIAL', 'STRENGTH')": 80.0,
#   "('CASING_SIZE', 'value')": 5.5,
#   "('WEIGHT_RANGE', 'MAX')": 23.0,
#   "('WEIGHT_RANGE', 'MIN')": 17.0,
#   "('CERTIFICATION', 'value')": 'ISO-V3[150-325F]',
#   "('PRESSURE_RATING', 'value')": 5000.0,
#   "('EXTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('EXTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('ID_DRIFT', 'value')": 2.347,
#   "('INTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('INTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('LOWER_THREAD', 'CONFIG')": 'PIN',
#   "('LOWER_THREAD', 'SIZE')": 2.875,
#   "('LOWER_THREAD', 'TYPE')": 'TENARIS HYDRIL BLUE',
#   "('LOWER_THREAD', 'WT')": 6.4,
#   "('MATERIAL_ELEMENTS', 'value')": 'HNBR',
#   "('MATERIAL_O_RING', 'value')": 'VITON',
#   "('OD_MAX', 'value')": 4.5,
#   "('QCG', 'value')": 'Q3',
#   "('QCP', 'value')": 'CLG QCP-102817386',
#   "('SERVICE_NACE', 'value')": True,
#   "('SETTING_PRESSURE', 'value')": 2500.0,
#   "('RELEASE_FORCE', 'value')": 77844.0,
#   "('TENSILE_STRENGTH', 'TEMP')": 325.0,
#   "('TENSILE_STRENGTH', 'STRENGTH')": 144000.0,
#   "('UPPER_THREAD', 'CONFIG')": 'BOX',
#   "('UPPER_THREAD', 'SIZE')": 2.875,
#   "('UPPER_THREAD', 'TYPE')": 'TENARIS HYDRIL BLUE',
#   "('UPPER_THREAD', 'WT')": 6.4},
#  '103144015_AA': {"('WETTED_MATERIAL', 'MATERIAL')": '41XX',
#   "('WETTED_MATERIAL', 'STRENGTH')": 80.0,
#   "('CASING_SIZE', 'value')": 7.0,
#   "('WEIGHT_RANGE', 'MAX')": 32.0,
#   "('WEIGHT_RANGE', 'MIN')": 26.0,
#   "('CERTIFICATION', 'value')": nan,
#   "('PRESSURE_RATING', 'value')": nan,
#   "('EXTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('EXTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('ID_DRIFT', 'value')": 3.833,
#   "('INTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('INTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('LOWER_THREAD', 'CONFIG')": 'PIN',
#   "('LOWER_THREAD', 'SIZE')": 4.5,
#   "('LOWER_THREAD', 'TYPE')": 'VAM TOP',
#   "('LOWER_THREAD', 'WT')": 12.6,
#   "('MATERIAL_ELEMENTS', 'value')": nan,
#   "('MATERIAL_O_RING', 'value')": 'VITON',
#   "('OD_MAX', 'value')": 5.909,
#   "('QCG', 'value')": nan,
#   "('QCP', 'value')": 'CLG QCP-102817386',
#   "('SERVICE_NACE', 'value')": True,
#   "('SETTING_PRESSURE', 'value')": 3000.0,
#   "('RELEASE_FORCE', 'value')": 103792.0,
#   "('TENSILE_STRENGTH', 'TEMP')": 325.0,
#   "('TENSILE_STRENGTH', 'STRENGTH')": 208000.0,
#   "('UPPER_THREAD', 'CONFIG')": 'BOX',
#   "('UPPER_THREAD', 'SIZE')": 4.5,
#   "('UPPER_THREAD', 'TYPE')": 'VAM TOP',
#   "('UPPER_THREAD', 'WT')": 12.6},
#  '103183602_AC': {"('WETTED_MATERIAL', 'MATERIAL')": '41XX',
#   "('WETTED_MATERIAL', 'STRENGTH')": 80.0,
#   "('CASING_SIZE', 'value')": 9.625,
#   "('WEIGHT_RANGE', 'MAX')": 53.5,
#   "('WEIGHT_RANGE', 'MIN')": 47.0,
#   "('CERTIFICATION', 'value')": 'ISO-V3[150-325F]',
#   "('PRESSURE_RATING', 'value')": 5000.0,
#   "('EXTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('EXTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('ID_DRIFT', 'value')": 3.833,
#   "('INTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('INTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('LOWER_THREAD', 'CONFIG')": 'PIN',
#   "('LOWER_THREAD', 'SIZE')": 4.5,
#   "('LOWER_THREAD', 'TYPE')": 'EUE',
#   "('LOWER_THREAD', 'WT')": 12.75,
#   "('MATERIAL_ELEMENTS', 'value')": 'HNBR',
#   "('MATERIAL_O_RING', 'value')": 'VITON',
#   "('OD_MAX', 'value')": 8.319,
#   "('QCG', 'value')": 'Q3',
#   "('QCP', 'value')": 'CLG QCP-102817386',
#   "('SERVICE_NACE', 'value')": True,
#   "('SETTING_PRESSURE', 'value')": 3000.0,
#   "('RELEASE_FORCE', 'value')": 116766.0,
#   "('TENSILE_STRENGTH', 'TEMP')": 325.0,
#   "('TENSILE_STRENGTH', 'STRENGTH')": 265075.0,
#   "('UPPER_THREAD', 'CONFIG')": 'BOX',
#   "('UPPER_THREAD', 'SIZE')": 4.5,
#   "('UPPER_THREAD', 'TYPE')": 'EUE',
#   "('UPPER_THREAD', 'WT')": 12.75},
#  '103062560_AG': {"('WETTED_MATERIAL', 'MATERIAL')": '41XX',
#   "('WETTED_MATERIAL', 'STRENGTH')": 80.0,
#   "('CASING_SIZE', 'value')": 9.625,
#   "('WEIGHT_RANGE', 'MAX')": 47.0,
#   "('WEIGHT_RANGE', 'MIN')": 40.0,
#   "('CERTIFICATION', 'value')": 'ISO-V3[150-325F]',
#   "('PRESSURE_RATING', 'value')": 5000.0,
#   "('EXTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('EXTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('ID_DRIFT', 'value')": 4.767,
#   "('INTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('INTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('LOWER_THREAD', 'CONFIG')": 'PIN',
#   "('LOWER_THREAD', 'SIZE')": 5.5,
#   "('LOWER_THREAD', 'TYPE')": 'LTC',
#   "('LOWER_THREAD', 'WT')": 17.0,
#   "('MATERIAL_ELEMENTS', 'value')": 'HNBR',
#   "('MATERIAL_O_RING', 'value')": 'VITON',
#   "('OD_MAX', 'value')": 8.465,
#   "('QCG', 'value')": 'Q3',
#   "('QCP', 'value')": 'CLG QCP-102817386',
#   "('SERVICE_NACE', 'value')": True,
#   "('SETTING_PRESSURE', 'value')": 3000.0,
#   "('RELEASE_FORCE', 'value')": 116766.0,
#   "('TENSILE_STRENGTH', 'TEMP')": 325.0,
#   "('TENSILE_STRENGTH', 'STRENGTH')": 217387.0,
#   "('UPPER_THREAD', 'CONFIG')": 'BOX',
#   "('UPPER_THREAD', 'SIZE')": 5.5,
#   "('UPPER_THREAD', 'TYPE')": 'LTC',
#   "('UPPER_THREAD', 'WT')": 17.0},
#  '102684662_AF': {"('WETTED_MATERIAL', 'MATERIAL')": '41XX',
#   "('WETTED_MATERIAL', 'STRENGTH')": 80.0,
#   "('CASING_SIZE', 'value')": 9.625,
#   "('WEIGHT_RANGE', 'MAX')": 47.0,
#   "('WEIGHT_RANGE', 'MIN')": 40.0,
#   "('CERTIFICATION', 'value')": 'ISO-V3[40-235F, 150-325F]',
#   "('PRESSURE_RATING', 'value')": 5000.0,
#   "('EXTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('EXTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('ID_DRIFT', 'value')": 2.867,
#   "('INTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('INTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('LOWER_THREAD', 'CONFIG')": 'PIN',
#   "('LOWER_THREAD', 'SIZE')": 3.5,
#   "('LOWER_THREAD', 'TYPE')": 'EUE',
#   "('LOWER_THREAD', 'WT')": 9.3,
#   "('MATERIAL_ELEMENTS', 'value')": 'HNBR',
#   "('MATERIAL_O_RING', 'value')": 'VITON',
#   "('OD_MAX', 'value')": 8.465,
#   "('QCG', 'value')": 'Q3',
#   "('QCP', 'value')": 'CLG QCP-102817386',
#   "('SERVICE_NACE', 'value')": True,
#   "('SETTING_PRESSURE', 'value')": 3000.0,
#   "('RELEASE_FORCE', 'value')": 103792.0,
#   "('TENSILE_STRENGTH', 'TEMP')": 325.0,
#   "('TENSILE_STRENGTH', 'STRENGTH')": 208000.0,
#   "('UPPER_THREAD', 'CONFIG')": 'BOX',
#   "('UPPER_THREAD', 'SIZE')": 3.5,
#   "('UPPER_THREAD', 'TYPE')": 'EUE',
#   "('UPPER_THREAD', 'WT')": 9.3},
#  '102689450_AE': {"('WETTED_MATERIAL', 'MATERIAL')": '41XX',
#   "('WETTED_MATERIAL', 'STRENGTH')": 80.0,
#   "('CASING_SIZE', 'value')": 10.75,
#   "('WEIGHT_RANGE', 'MAX')": 65.7,
#   "('WEIGHT_RANGE', 'MIN')": 45.5,
#   "('CERTIFICATION', 'value')": 'ISO-V3[150-325F]',
#   "('PRESSURE_RATING', 'value')": 5000.0,
#   "('EXTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('EXTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('ID_DRIFT', 'value')": 4.767,
#   "('INTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('INTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('LOWER_THREAD', 'CONFIG')": 'PIN',
#   "('LOWER_THREAD', 'SIZE')": 5.5,
#   "('LOWER_THREAD', 'TYPE')": 'LTC',
#   "('LOWER_THREAD', 'WT')": 17.0,
#   "('MATERIAL_ELEMENTS', 'value')": 'HNBR',
#   "('MATERIAL_O_RING', 'value')": 'VITON',
#   "('OD_MAX', 'value')": 9.344,
#   "('QCG', 'value')": 'Q3',
#   "('QCP', 'value')": 'CLQ QCP-102817386',
#   "('SERVICE_NACE', 'value')": True,
#   "('SETTING_PRESSURE', 'value')": 3000.0,
#   "('RELEASE_FORCE', 'value')": 116766.0,
#   "('TENSILE_STRENGTH', 'TEMP')": 325.0,
#   "('TENSILE_STRENGTH', 'STRENGTH')": 408300.0,
#   "('UPPER_THREAD', 'CONFIG')": 'BOX',
#   "('UPPER_THREAD', 'SIZE')": 5.5,
#   "('UPPER_THREAD', 'TYPE')": 'LTC',
#   "('UPPER_THREAD', 'WT')": 17.0},
#  '103231275_AA': {"('WETTED_MATERIAL', 'MATERIAL')": '13CR',
#   "('WETTED_MATERIAL', 'STRENGTH')": 80.0,
#   "('CASING_SIZE', 'value')": 7.0,
#   "('WEIGHT_RANGE', 'MAX')": 32.0,
#   "('WEIGHT_RANGE', 'MIN')": 26.0,
#   "('CERTIFICATION', 'value')": 'ISO-V3[150-350F]',
#   "('PRESSURE_RATING', 'value')": 5000.0,
#   "('EXTERNAL_PRESSURE', 'TEMP')": 350.0,
#   "('EXTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('ID_DRIFT', 'value')": 2.347,
#   "('INTERNAL_PRESSURE', 'TEMP')": 350.0,
#   "('INTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('LOWER_THREAD', 'CONFIG')": 'PIN',
#   "('LOWER_THREAD', 'SIZE')": 2.875,
#   "('LOWER_THREAD', 'TYPE')": 'VAM TOP',
#   "('LOWER_THREAD', 'WT')": 6.4,
#   "('MATERIAL_ELEMENTS', 'value')": 'AFLAS',
#   "('MATERIAL_O_RING', 'value')": 'VITON',
#   "('OD_MAX', 'value')": 5.909,
#   "('QCG', 'value')": 'Q3',
#   "('QCP', 'value')": 'CLG QCP-102817386',
#   "('SERVICE_NACE', 'value')": True,
#   "('SETTING_PRESSURE', 'value')": 3000.0,
#   "('RELEASE_FORCE', 'value')": 103792.0,
#   "('TENSILE_STRENGTH', 'TEMP')": 350.0,
#   "('TENSILE_STRENGTH', 'STRENGTH')": 144000.0,
#   "('UPPER_THREAD', 'CONFIG')": 'PIN',
#   "('UPPER_THREAD', 'SIZE')": 2.875,
#   "('UPPER_THREAD', 'TYPE')": 'VAM TOP',
#   "('UPPER_THREAD', 'WT')": 6.4},
#  '102731362_AD': {"('WETTED_MATERIAL', 'MATERIAL')": '41XX',
#   "('WETTED_MATERIAL', 'STRENGTH')": 80.0,
#   "('CASING_SIZE', 'value')": 9.625,
#   "('WEIGHT_RANGE', 'MAX')": 40.0,
#   "('WEIGHT_RANGE', 'MIN')": 36.0,
#   "('CERTIFICATION', 'value')": 'ISO-V3[150-325F]',
#   "('PRESSURE_RATING', 'value')": 5000.0,
#   "('EXTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('EXTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('ID_DRIFT', 'value')": 2.867,
#   "('INTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('INTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('LOWER_THREAD', 'CONFIG')": 'PIN',
#   "('LOWER_THREAD', 'SIZE')": 3.5,
#   "('LOWER_THREAD', 'TYPE')": 'EUE',
#   "('LOWER_THREAD', 'WT')": 9.3,
#   "('MATERIAL_ELEMENTS', 'value')": 'HNBR',
#   "('MATERIAL_O_RING', 'value')": 'VITON',
#   "('OD_MAX', 'value')": 8.619,
#   "('QCG', 'value')": 'Q3',
#   "('QCP', 'value')": 'CLG QCP-102817386',
#   "('SERVICE_NACE', 'value')": True,
#   "('SETTING_PRESSURE', 'value')": 3000.0,
#   "('RELEASE_FORCE', 'value')": 103792.0,
#   "('TENSILE_STRENGTH', 'TEMP')": 325.0,
#   "('TENSILE_STRENGTH', 'STRENGTH')": 208000.0,
#   "('UPPER_THREAD', 'CONFIG')": 'BOX',
#   "('UPPER_THREAD', 'SIZE')": 3.5,
#   "('UPPER_THREAD', 'TYPE')": 'MODIFIED EUE',
#   "('UPPER_THREAD', 'WT')": 9.3},
#  '102731377_AD': {"('WETTED_MATERIAL', 'MATERIAL')": '41XX',
#   "('WETTED_MATERIAL', 'STRENGTH')": 80.0,
#   "('CASING_SIZE', 'value')": 9.625,
#   "('WEIGHT_RANGE', 'MAX')": 53.5,
#   "('WEIGHT_RANGE', 'MIN')": 47.0,
#   "('CERTIFICATION', 'value')": 'ISO-V3[150-325F]',
#   "('PRESSURE_RATING', 'value')": 5000.0,
#   "('EXTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('EXTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('ID_DRIFT', 'value')": 2.867,
#   "('INTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('INTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('LOWER_THREAD', 'CONFIG')": 'PIN',
#   "('LOWER_THREAD', 'SIZE')": 3.5,
#   "('LOWER_THREAD', 'TYPE')": 'EUE',
#   "('LOWER_THREAD', 'WT')": 9.3,
#   "('MATERIAL_ELEMENTS', 'value')": 'HNBR',
#   "('MATERIAL_O_RING', 'value')": 'VITON',
#   "('OD_MAX', 'value')": 8.319,
#   "('QCG', 'value')": 'Q3',
#   "('QCP', 'value')": 'CLG QCP-102817386',
#   "('SERVICE_NACE', 'value')": True,
#   "('SETTING_PRESSURE', 'value')": 3000.0,
#   "('RELEASE_FORCE', 'value')": 103792.0,
#   "('TENSILE_STRENGTH', 'TEMP')": 325.0,
#   "('TENSILE_STRENGTH', 'STRENGTH')": 208000.0,
#   "('UPPER_THREAD', 'CONFIG')": 'BOX',
#   "('UPPER_THREAD', 'SIZE')": 3.5,
#   "('UPPER_THREAD', 'TYPE')": 'EUE',
#   "('UPPER_THREAD', 'WT')": 9.3},
#  '103231270_AA': {"('WETTED_MATERIAL', 'MATERIAL')": '13CR',
#   "('WETTED_MATERIAL', 'STRENGTH')": 80.0,
#   "('CASING_SIZE', 'value')": 7.0,
#   "('WEIGHT_RANGE', 'MAX')": 32.0,
#   "('WEIGHT_RANGE', 'MIN')": 26.0,
#   "('CERTIFICATION', 'value')": 'ISO-V3[150-350F]',
#   "('PRESSURE_RATING', 'value')": 5000.0,
#   "('EXTERNAL_PRESSURE', 'TEMP')": 350.0,
#   "('EXTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('ID_DRIFT', 'value')": 2.867,
#   "('INTERNAL_PRESSURE', 'TEMP')": 350.0,
#   "('INTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('LOWER_THREAD', 'CONFIG')": 'PIN',
#   "('LOWER_THREAD', 'SIZE')": 3.5,
#   "('LOWER_THREAD', 'TYPE')": 'VAM TOP',
#   "('LOWER_THREAD', 'WT')": 9.2,
#   "('MATERIAL_ELEMENTS', 'value')": 'AFLAS',
#   "('MATERIAL_O_RING', 'value')": 'VITON',
#   "('OD_MAX', 'value')": 5.909,
#   "('QCG', 'value')": 'Q3',
#   "('QCP', 'value')": 'CLG QCP-102817386',
#   "('SERVICE_NACE', 'value')": True,
#   "('SETTING_PRESSURE', 'value')": 3000.0,
#   "('RELEASE_FORCE', 'value')": 103792.0,
#   "('TENSILE_STRENGTH', 'TEMP')": 350.0,
#   "('TENSILE_STRENGTH', 'STRENGTH')": 208000.0,
#   "('UPPER_THREAD', 'CONFIG')": 'PIN',
#   "('UPPER_THREAD', 'SIZE')": 3.5,
#   "('UPPER_THREAD', 'TYPE')": 'VAM TOP',
#   "('UPPER_THREAD', 'WT')": 9.2},
#  '103211443_AC': {"('WETTED_MATERIAL', 'MATERIAL')": '41XX',
#   "('WETTED_MATERIAL', 'STRENGTH')": 80.0,
#   "('CASING_SIZE', 'value')": 9.625,
#   "('WEIGHT_RANGE', 'MAX')": 53.5,
#   "('WEIGHT_RANGE', 'MIN')": 47.0,
#   "('CERTIFICATION', 'value')": 'ISO-V3[150-350F]',
#   "('PRESSURE_RATING', 'value')": 5000.0,
#   "('EXTERNAL_PRESSURE', 'TEMP')": 350.0,
#   "('EXTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('ID_DRIFT', 'value')": 4.767,
#   "('INTERNAL_PRESSURE', 'TEMP')": 350.0,
#   "('INTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('LOWER_THREAD', 'CONFIG')": 'PIN',
#   "('LOWER_THREAD', 'SIZE')": 5.5,
#   "('LOWER_THREAD', 'TYPE')": 'LTC',
#   "('LOWER_THREAD', 'WT')": 17.0,
#   "('MATERIAL_ELEMENTS', 'value')": 'AFLAS',
#   "('MATERIAL_O_RING', 'value')": 'VITON',
#   "('OD_MAX', 'value')": 8.319,
#   "('QCG', 'value')": 'Q3',
#   "('QCP', 'value')": 'CLG QCP-102817386',
#   "('SERVICE_NACE', 'value')": True,
#   "('SETTING_PRESSURE', 'value')": 3000.0,
#   "('RELEASE_FORCE', 'value')": 116766.0,
#   "('TENSILE_STRENGTH', 'TEMP')": 350.0,
#   "('TENSILE_STRENGTH', 'STRENGTH')": 217387.0,
#   "('UPPER_THREAD', 'CONFIG')": 'BOX',
#   "('UPPER_THREAD', 'SIZE')": 5.5,
#   "('UPPER_THREAD', 'TYPE')": 'LTC',
#   "('UPPER_THREAD', 'WT')": 17.0},
#  '102792167_AE': {"('WETTED_MATERIAL', 'MATERIAL')": '41XX',
#   "('WETTED_MATERIAL', 'STRENGTH')": 80.0,
#   "('CASING_SIZE', 'value')": 9.625,
#   "('WEIGHT_RANGE', 'MAX')": 47.0,
#   "('WEIGHT_RANGE', 'MIN')": 40.0,
#   "('CERTIFICATION', 'value')": 'ISO-V3[40-235F, 150-325F]',
#   "('PRESSURE_RATING', 'value')": 5000.0,
#   "('EXTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('EXTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('ID_DRIFT', 'value')": 2.347,
#   "('INTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('INTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('LOWER_THREAD', 'CONFIG')": 'PIN',
#   "('LOWER_THREAD', 'SIZE')": 2.875,
#   "('LOWER_THREAD', 'TYPE')": 'VAM TOP',
#   "('LOWER_THREAD', 'WT')": 6.4,
#   "('MATERIAL_ELEMENTS', 'value')": 'HNBR',
#   "('MATERIAL_O_RING', 'value')": 'VITON',
#   "('OD_MAX', 'value')": 8.465,
#   "('QCG', 'value')": 'Q3',
#   "('QCP', 'value')": 'CLG QCP-102817386',
#   "('SERVICE_NACE', 'value')": True,
#   "('SETTING_PRESSURE', 'value')": 3000.0,
#   "('RELEASE_FORCE', 'value')": 103792.0,
#   "('TENSILE_STRENGTH', 'TEMP')": 325.0,
#   "('TENSILE_STRENGTH', 'STRENGTH')": 144000.0,
#   "('UPPER_THREAD', 'CONFIG')": 'BOX',
#   "('UPPER_THREAD', 'SIZE')": 2.875,
#   "('UPPER_THREAD', 'TYPE')": 'VAM TOP',
#   "('UPPER_THREAD', 'WT')": 6.4},
#  '103209720_AB': {"('WETTED_MATERIAL', 'MATERIAL')": '41XX',
#   "('WETTED_MATERIAL', 'STRENGTH')": 80.0,
#   "('CASING_SIZE', 'value')": 9.625,
#   "('WEIGHT_RANGE', 'MAX')": 47.0,
#   "('WEIGHT_RANGE', 'MIN')": 40.0,
#   "('CERTIFICATION', 'value')": 'ISO-V3[40-235F, 150-325F]',
#   "('PRESSURE_RATING', 'value')": 5000.0,
#   "('EXTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('EXTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('ID_DRIFT', 'value')": 2.867,
#   "('INTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('INTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('LOWER_THREAD', 'CONFIG')": 'PIN',
#   "('LOWER_THREAD', 'SIZE')": 3.5,
#   "('LOWER_THREAD', 'TYPE')": 'JFE BEAR',
#   "('LOWER_THREAD', 'WT')": 9.2,
#   "('MATERIAL_ELEMENTS', 'value')": 'HNBR',
#   "('MATERIAL_O_RING', 'value')": 'VITON',
#   "('OD_MAX', 'value')": 8.465,
#   "('QCG', 'value')": 'Q3',
#   "('QCP', 'value')": 'CLG QCP-102817386',
#   "('SERVICE_NACE', 'value')": True,
#   "('SETTING_PRESSURE', 'value')": 3000.0,
#   "('RELEASE_FORCE', 'value')": 103792.0,
#   "('TENSILE_STRENGTH', 'TEMP')": 325.0,
#   "('TENSILE_STRENGTH', 'STRENGTH')": 208000.0,
#   "('UPPER_THREAD', 'CONFIG')": 'BOX',
#   "('UPPER_THREAD', 'SIZE')": 3.5,
#   "('UPPER_THREAD', 'TYPE')": 'JFE BEAR',
#   "('UPPER_THREAD', 'WT')": 9.2},
#  '103197963_AB': {"('WETTED_MATERIAL', 'MATERIAL')": '41XX',
#   "('WETTED_MATERIAL', 'STRENGTH')": 80.0,
#   "('CASING_SIZE', 'value')": 9.625,
#   "('WEIGHT_RANGE', 'MAX')": 47.0,
#   "('WEIGHT_RANGE', 'MIN')": 40.0,
#   "('CERTIFICATION', 'value')": 'ISO-V3[150-325F]',
#   "('PRESSURE_RATING', 'value')": 5000.0,
#   "('EXTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('EXTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('ID_DRIFT', 'value')": 3.833,
#   "('INTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('INTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('LOWER_THREAD', 'CONFIG')": 'PIN',
#   "('LOWER_THREAD', 'SIZE')": 4.5,
#   "('LOWER_THREAD', 'TYPE')": 'VAM TOP',
#   "('LOWER_THREAD', 'WT')": 12.6,
#   "('MATERIAL_ELEMENTS', 'value')": 'HNBR',
#   "('MATERIAL_O_RING', 'value')": 'VITON',
#   "('OD_MAX', 'value')": 8.465,
#   "('QCG', 'value')": 'Q3',
#   "('QCP', 'value')": 'CLG QCP-102817386',
#   "('SERVICE_NACE', 'value')": True,
#   "('SETTING_PRESSURE', 'value')": 3000.0,
#   "('RELEASE_FORCE', 'value')": 116766.0,
#   "('TENSILE_STRENGTH', 'TEMP')": 325.0,
#   "('TENSILE_STRENGTH', 'STRENGTH')": 265075.0,
#   "('UPPER_THREAD', 'CONFIG')": 'BOX',
#   "('UPPER_THREAD', 'SIZE')": 4.5,
#   "('UPPER_THREAD', 'TYPE')": 'VAM TOP',
#   "('UPPER_THREAD', 'WT')": 12.6},
#  '102850902_AD': {"('WETTED_MATERIAL', 'MATERIAL')": '41XX',
#   "('WETTED_MATERIAL', 'STRENGTH')": 80.0,
#   "('CASING_SIZE', 'value')": 9.625,
#   "('WEIGHT_RANGE', 'MAX')": 47.0,
#   "('WEIGHT_RANGE', 'MIN')": 40.0,
#   "('CERTIFICATION', 'value')": 'ISO-V3[40-235F, 150-325F]',
#   "('PRESSURE_RATING', 'value')": 5000.0,
#   "('EXTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('EXTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('ID_DRIFT', 'value')": 2.867,
#   "('INTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('INTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('LOWER_THREAD', 'CONFIG')": 'PIN',
#   "('LOWER_THREAD', 'SIZE')": 3.5,
#   "('LOWER_THREAD', 'TYPE')": 'EUE',
#   "('LOWER_THREAD', 'WT')": 9.3,
#   "('MATERIAL_ELEMENTS', 'value')": 'HNBR',
#   "('MATERIAL_O_RING', 'value')": 'VITON',
#   "('OD_MAX', 'value')": 8.465,
#   "('QCG', 'value')": 'Q3',
#   "('QCP', 'value')": 'CLG QCP-102817386',
#   "('SERVICE_NACE', 'value')": True,
#   "('SETTING_PRESSURE', 'value')": 3000.0,
#   "('RELEASE_FORCE', 'value')": 103792.0,
#   "('TENSILE_STRENGTH', 'TEMP')": 325.0,
#   "('TENSILE_STRENGTH', 'STRENGTH')": 208000.0,
#   "('UPPER_THREAD', 'CONFIG')": 'BOX',
#   "('UPPER_THREAD', 'SIZE')": 3.5,
#   "('UPPER_THREAD', 'TYPE')": 'MODIFIED EUE',
#   "('UPPER_THREAD', 'WT')": 9.3},
#  '102908857_AC': {"('WETTED_MATERIAL', 'MATERIAL')": '41XX',
#   "('WETTED_MATERIAL', 'STRENGTH')": 80.0,
#   "('CASING_SIZE', 'value')": 9.625,
#   "('WEIGHT_RANGE', 'MAX')": 40.0,
#   "('WEIGHT_RANGE', 'MIN')": 36.0,
#   "('CERTIFICATION', 'value')": 'ISO-V3[150-350F]',
#   "('PRESSURE_RATING', 'value')": 5000.0,
#   "('EXTERNAL_PRESSURE', 'TEMP')": 350.0,
#   "('EXTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('ID_DRIFT', 'value')": 2.867,
#   "('INTERNAL_PRESSURE', 'TEMP')": 350.0,
#   "('INTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('LOWER_THREAD', 'CONFIG')": 'PIN',
#   "('LOWER_THREAD', 'SIZE')": 3.5,
#   "('LOWER_THREAD', 'TYPE')": 'EUE',
#   "('LOWER_THREAD', 'WT')": 9.3,
#   "('MATERIAL_ELEMENTS', 'value')": 'AFLAS',
#   "('MATERIAL_O_RING', 'value')": 'VITON',
#   "('OD_MAX', 'value')": 8.619,
#   "('QCG', 'value')": 'Q3',
#   "('QCP', 'value')": 'CLG QCP-102817386',
#   "('SERVICE_NACE', 'value')": True,
#   "('SETTING_PRESSURE', 'value')": 3000.0,
#   "('RELEASE_FORCE', 'value')": 103792.0,
#   "('TENSILE_STRENGTH', 'TEMP')": 350.0,
#   "('TENSILE_STRENGTH', 'STRENGTH')": 208000.0,
#   "('UPPER_THREAD', 'CONFIG')": 'BOX',
#   "('UPPER_THREAD', 'SIZE')": 3.5,
#   "('UPPER_THREAD', 'TYPE')": 'EUE',
#   "('UPPER_THREAD', 'WT')": 9.3},
#  '102991381_AH': {"('WETTED_MATERIAL', 'MATERIAL')": '41XX',
#   "('WETTED_MATERIAL', 'STRENGTH')": 80.0,
#   "('CASING_SIZE', 'value')": 9.625,
#   "('WEIGHT_RANGE', 'MAX')": 47.0,
#   "('WEIGHT_RANGE', 'MIN')": 40.0,
#   "('CERTIFICATION', 'value')": 'ISO-V3[150-350F]',
#   "('PRESSURE_RATING', 'value')": 5000.0,
#   "('EXTERNAL_PRESSURE', 'TEMP')": 350.0,
#   "('EXTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('ID_DRIFT', 'value')": 4.767,
#   "('INTERNAL_PRESSURE', 'TEMP')": 350.0,
#   "('INTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('LOWER_THREAD', 'CONFIG')": 'PIN',
#   "('LOWER_THREAD', 'SIZE')": 5.5,
#   "('LOWER_THREAD', 'TYPE')": 'VAM TOP',
#   "('LOWER_THREAD', 'WT')": 17.0,
#   "('MATERIAL_ELEMENTS', 'value')": 'AFLAS',
#   "('MATERIAL_O_RING', 'value')": 'VITON',
#   "('OD_MAX', 'value')": 8.465,
#   "('QCG', 'value')": 'Q3',
#   "('QCP', 'value')": 'CLG QCP-102817386',
#   "('SERVICE_NACE', 'value')": True,
#   "('SETTING_PRESSURE', 'value')": 3000.0,
#   "('RELEASE_FORCE', 'value')": 116766.0,
#   "('TENSILE_STRENGTH', 'TEMP')": 350.0,
#   "('TENSILE_STRENGTH', 'STRENGTH')": 217387.0,
#   "('UPPER_THREAD', 'CONFIG')": 'BOX',
#   "('UPPER_THREAD', 'SIZE')": 5.5,
#   "('UPPER_THREAD', 'TYPE')": 'VAM TOP',
#   "('UPPER_THREAD', 'WT')": 17.0},
#  '102894197_AE': {"('WETTED_MATERIAL', 'MATERIAL')": '13CR',
#   "('WETTED_MATERIAL', 'STRENGTH')": 80.0,
#   "('CASING_SIZE', 'value')": 7.0,
#   "('WEIGHT_RANGE', 'MAX')": 32.0,
#   "('WEIGHT_RANGE', 'MIN')": 26.0,
#   "('CERTIFICATION', 'value')": 'ISO-V3[150-350F]',
#   "('PRESSURE_RATING', 'value')": 5000.0,
#   "('EXTERNAL_PRESSURE', 'TEMP')": 350.0,
#   "('EXTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('ID_DRIFT', 'value')": 2.867,
#   "('INTERNAL_PRESSURE', 'TEMP')": 350.0,
#   "('INTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('LOWER_THREAD', 'CONFIG')": 'PIN',
#   "('LOWER_THREAD', 'SIZE')": 3.5,
#   "('LOWER_THREAD', 'TYPE')": 'FOX',
#   "('LOWER_THREAD', 'WT')": 9.2,
#   "('MATERIAL_ELEMENTS', 'value')": 'AFLAS',
#   "('MATERIAL_O_RING', 'value')": 'VITON',
#   "('OD_MAX', 'value')": 5.909,
#   "('QCG', 'value')": 'Q3',
#   "('QCP', 'value')": 'CLG QCP-102817386',
#   "('SERVICE_NACE', 'value')": True,
#   "('SETTING_PRESSURE', 'value')": 3000.0,
#   "('RELEASE_FORCE', 'value')": 103792.0,
#   "('TENSILE_STRENGTH', 'TEMP')": 350.0,
#   "('TENSILE_STRENGTH', 'STRENGTH')": 208000.0,
#   "('UPPER_THREAD', 'CONFIG')": 'PIN',
#   "('UPPER_THREAD', 'SIZE')": 3.5,
#   "('UPPER_THREAD', 'TYPE')": 'FOX',
#   "('UPPER_THREAD', 'WT')": 9.2},
#  '102908853_AC': {"('WETTED_MATERIAL', 'MATERIAL')": '41XX',
#   "('WETTED_MATERIAL', 'STRENGTH')": 80.0,
#   "('CASING_SIZE', 'value')": 9.625,
#   "('WEIGHT_RANGE', 'MAX')": 53.5,
#   "('WEIGHT_RANGE', 'MIN')": 47.0,
#   "('CERTIFICATION', 'value')": 'ISO-V3[150-350F]',
#   "('PRESSURE_RATING', 'value')": 5000.0,
#   "('EXTERNAL_PRESSURE', 'TEMP')": 350.0,
#   "('EXTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('ID_DRIFT', 'value')": 2.867,
#   "('INTERNAL_PRESSURE', 'TEMP')": 350.0,
#   "('INTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('LOWER_THREAD', 'CONFIG')": 'PIN',
#   "('LOWER_THREAD', 'SIZE')": 3.5,
#   "('LOWER_THREAD', 'TYPE')": 'EUE',
#   "('LOWER_THREAD', 'WT')": 9.3,
#   "('MATERIAL_ELEMENTS', 'value')": 'AFLAS',
#   "('MATERIAL_O_RING', 'value')": 'VITON',
#   "('OD_MAX', 'value')": 8.319,
#   "('QCG', 'value')": 'Q3',
#   "('QCP', 'value')": 'CLG QCP-102817386',
#   "('SERVICE_NACE', 'value')": True,
#   "('SETTING_PRESSURE', 'value')": 3000.0,
#   "('RELEASE_FORCE', 'value')": 103792.0,
#   "('TENSILE_STRENGTH', 'TEMP')": 350.0,
#   "('TENSILE_STRENGTH', 'STRENGTH')": 208000.0,
#   "('UPPER_THREAD', 'CONFIG')": 'BOX',
#   "('UPPER_THREAD', 'SIZE')": 3.5,
#   "('UPPER_THREAD', 'TYPE')": 'EUE',
#   "('UPPER_THREAD', 'WT')": 9.3},
#  '103180915_AB': {"('WETTED_MATERIAL', 'MATERIAL')": '41XX',
#   "('WETTED_MATERIAL', 'STRENGTH')": 80.0,
#   "('CASING_SIZE', 'value')": 9.625,
#   "('WEIGHT_RANGE', 'MAX')": 47.0,
#   "('WEIGHT_RANGE', 'MIN')": 40.0,
#   "('CERTIFICATION', 'value')": 'ISO-V3[150-325F]',
#   "('PRESSURE_RATING', 'value')": 5000.0,
#   "('EXTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('EXTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('ID_DRIFT', 'value')": 3.833,
#   "('INTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('INTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('LOWER_THREAD', 'CONFIG')": 'PIN',
#   "('LOWER_THREAD', 'SIZE')": 4.5,
#   "('LOWER_THREAD', 'TYPE')": 'EUE',
#   "('LOWER_THREAD', 'WT')": 12.75,
#   "('MATERIAL_ELEMENTS', 'value')": 'HNBR',
#   "('MATERIAL_O_RING', 'value')": 'VITON',
#   "('OD_MAX', 'value')": 8.465,
#   "('QCG', 'value')": 'Q3',
#   "('QCP', 'value')": 'CLG QCP-102817386',
#   "('SERVICE_NACE', 'value')": True,
#   "('SETTING_PRESSURE', 'value')": 3000.0,
#   "('RELEASE_FORCE', 'value')": 116766.0,
#   "('TENSILE_STRENGTH', 'TEMP')": 325.0,
#   "('TENSILE_STRENGTH', 'STRENGTH')": 265075.0,
#   "('UPPER_THREAD', 'CONFIG')": 'BOX',
#   "('UPPER_THREAD', 'SIZE')": 4.5,
#   "('UPPER_THREAD', 'TYPE')": 'EUE',
#   "('UPPER_THREAD', 'WT')": 12.75},
#  '103183591_AD': {"('WETTED_MATERIAL', 'MATERIAL')": '41XX',
#   "('WETTED_MATERIAL', 'STRENGTH')": 80.0,
#   "('CASING_SIZE', 'value')": 9.625,
#   "('WEIGHT_RANGE', 'MAX')": 53.5,
#   "('WEIGHT_RANGE', 'MIN')": 47.0,
#   "('CERTIFICATION', 'value')": 'ISO-V3[150-325F]',
#   "('PRESSURE_RATING', 'value')": 5000.0,
#   "('EXTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('EXTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('ID_DRIFT', 'value')": 4.767,
#   "('INTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('INTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('LOWER_THREAD', 'CONFIG')": 'PIN',
#   "('LOWER_THREAD', 'SIZE')": 5.5,
#   "('LOWER_THREAD', 'TYPE')": 'LTC',
#   "('LOWER_THREAD', 'WT')": 17.0,
#   "('MATERIAL_ELEMENTS', 'value')": 'HNBR',
#   "('MATERIAL_O_RING', 'value')": 'VITON',
#   "('OD_MAX', 'value')": 8.319,
#   "('QCG', 'value')": 'Q3',
#   "('QCP', 'value')": 'CLG QCP-102817386',
#   "('SERVICE_NACE', 'value')": True,
#   "('SETTING_PRESSURE', 'value')": 3000.0,
#   "('RELEASE_FORCE', 'value')": 116766.0,
#   "('TENSILE_STRENGTH', 'TEMP')": 325.0,
#   "('TENSILE_STRENGTH', 'STRENGTH')": 217387.0,
#   "('UPPER_THREAD', 'CONFIG')": 'BOX',
#   "('UPPER_THREAD', 'SIZE')": 5.5,
#   "('UPPER_THREAD', 'TYPE')": 'LTC',
#   "('UPPER_THREAD', 'WT')": 17.0},
#  '103171943_AB': {"('WETTED_MATERIAL', 'MATERIAL')": '41XX',
#   "('WETTED_MATERIAL', 'STRENGTH')": 80.0,
#   "('CASING_SIZE', 'value')": 9.625,
#   "('WEIGHT_RANGE', 'MAX')": 53.5,
#   "('WEIGHT_RANGE', 'MIN')": 47.0,
#   "('CERTIFICATION', 'value')": 'ISO-V3[150-325F]',
#   "('PRESSURE_RATING', 'value')": 5000.0,
#   "('EXTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('EXTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('ID_DRIFT', 'value')": 2.867,
#   "('INTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('INTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('LOWER_THREAD', 'CONFIG')": 'PIN',
#   "('LOWER_THREAD', 'SIZE')": 3.5,
#   "('LOWER_THREAD', 'TYPE')": 'VAM TOP',
#   "('LOWER_THREAD', 'WT')": 9.2,
#   "('MATERIAL_ELEMENTS', 'value')": 'HNBR',
#   "('MATERIAL_O_RING', 'value')": 'VITON',
#   "('OD_MAX', 'value')": 8.319,
#   "('QCG', 'value')": 'Q3',
#   "('QCP', 'value')": 'CLG QCP-102817386',
#   "('SERVICE_NACE', 'value')": True,
#   "('SETTING_PRESSURE', 'value')": 3000.0,
#   "('RELEASE_FORCE', 'value')": 103792.0,
#   "('TENSILE_STRENGTH', 'TEMP')": 325.0,
#   "('TENSILE_STRENGTH', 'STRENGTH')": 208000.0,
#   "('UPPER_THREAD', 'CONFIG')": 'BOX',
#   "('UPPER_THREAD', 'SIZE')": 3.5,
#   "('UPPER_THREAD', 'TYPE')": 'VAM TOP',
#   "('UPPER_THREAD', 'WT')": 9.2},
#  '102966607_AA': {"('WETTED_MATERIAL', 'MATERIAL')": '13CR',
#   "('WETTED_MATERIAL', 'STRENGTH')": 80.0,
#   "('CASING_SIZE', 'value')": 7.0,
#   "('WEIGHT_RANGE', 'MAX')": 32.0,
#   "('WEIGHT_RANGE', 'MIN')": 26.0,
#   "('CERTIFICATION', 'value')": nan,
#   "('PRESSURE_RATING', 'value')": nan,
#   "('EXTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('EXTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('ID_DRIFT', 'value')": 3.833,
#   "('INTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('INTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('LOWER_THREAD', 'CONFIG')": 'PIN',
#   "('LOWER_THREAD', 'SIZE')": 4.5,
#   "('LOWER_THREAD', 'TYPE')": 'JFE BEAR',
#   "('LOWER_THREAD', 'WT')": 12.6,
#   "('MATERIAL_ELEMENTS', 'value')": nan,
#   "('MATERIAL_O_RING', 'value')": 'VITON',
#   "('OD_MAX', 'value')": 5.909,
#   "('QCG', 'value')": nan,
#   "('QCP', 'value')": 'CLG QCP-102817386',
#   "('SERVICE_NACE', 'value')": True,
#   "('SETTING_PRESSURE', 'value')": 3000.0,
#   "('RELEASE_FORCE', 'value')": 103792.0,
#   "('TENSILE_STRENGTH', 'TEMP')": 325.0,
#   "('TENSILE_STRENGTH', 'STRENGTH')": 208000.0,
#   "('UPPER_THREAD', 'CONFIG')": 'BOX',
#   "('UPPER_THREAD', 'SIZE')": 4.5,
#   "('UPPER_THREAD', 'TYPE')": 'JFE BEAR',
#   "('UPPER_THREAD', 'WT')": 12.6},
#  '102878398_AD': {"('WETTED_MATERIAL', 'MATERIAL')": '25CR',
#   "('WETTED_MATERIAL', 'STRENGTH')": 80.0,
#   "('CASING_SIZE', 'value')": 9.625,
#   "('WEIGHT_RANGE', 'MAX')": 47.0,
#   "('WEIGHT_RANGE', 'MIN')": 40.0,
#   "('CERTIFICATION', 'value')": 'ISO-V3[40-195F]',
#   "('PRESSURE_RATING', 'value')": 5000.0,
#   "('EXTERNAL_PRESSURE', 'TEMP')": 195.0,
#   "('EXTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('ID_DRIFT', 'value')": 2.867,
#   "('INTERNAL_PRESSURE', 'TEMP')": 195.0,
#   "('INTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('LOWER_THREAD', 'CONFIG')": 'PIN',
#   "('LOWER_THREAD', 'SIZE')": 3.5,
#   "('LOWER_THREAD', 'TYPE')": 'VAM TOP',
#   "('LOWER_THREAD', 'WT')": 9.2,
#   "('MATERIAL_ELEMENTS', 'value')": 'HNBR',
#   "('MATERIAL_O_RING', 'value')": 'VITON',
#   "('OD_MAX', 'value')": 8.465,
#   "('QCG', 'value')": 'Q3',
#   "('QCP', 'value')": 'CLG QCP-102817386',
#   "('SERVICE_NACE', 'value')": True,
#   "('SETTING_PRESSURE', 'value')": 3000.0,
#   "('RELEASE_FORCE', 'value')": 103792.0,
#   "('TENSILE_STRENGTH', 'TEMP')": 195.0,
#   "('TENSILE_STRENGTH', 'STRENGTH')": 207000.0,
#   "('UPPER_THREAD', 'CONFIG')": 'BOX',
#   "('UPPER_THREAD', 'SIZE')": 3.5,
#   "('UPPER_THREAD', 'TYPE')": 'VAM TOP',
#   "('UPPER_THREAD', 'WT')": 9.2},
#  '103015422_AB': {"('WETTED_MATERIAL', 'MATERIAL')": '13CR',
#   "('WETTED_MATERIAL', 'STRENGTH')": 80.0,
#   "('CASING_SIZE', 'value')": 9.625,
#   "('WEIGHT_RANGE', 'MAX')": 53.5,
#   "('WEIGHT_RANGE', 'MIN')": 47.0,
#   "('CERTIFICATION', 'value')": 'ISO-V3[150-350F]',
#   "('PRESSURE_RATING', 'value')": 5000.0,
#   "('EXTERNAL_PRESSURE', 'TEMP')": 350.0,
#   "('EXTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('ID_DRIFT', 'value')": 2.867,
#   "('INTERNAL_PRESSURE', 'TEMP')": 350.0,
#   "('INTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('LOWER_THREAD', 'CONFIG')": 'PIN',
#   "('LOWER_THREAD', 'SIZE')": 3.5,
#   "('LOWER_THREAD', 'TYPE')": 'VAM TOP',
#   "('LOWER_THREAD', 'WT')": 9.2,
#   "('MATERIAL_ELEMENTS', 'value')": 'AFLAS',
#   "('MATERIAL_O_RING', 'value')": 'VITON',
#   "('OD_MAX', 'value')": 8.319,
#   "('QCG', 'value')": 'Q3',
#   "('QCP', 'value')": 'CLG QCP-102817386',
#   "('SERVICE_NACE', 'value')": True,
#   "('SETTING_PRESSURE', 'value')": 3000.0,
#   "('RELEASE_FORCE', 'value')": 103792.0,
#   "('TENSILE_STRENGTH', 'TEMP')": 350.0,
#   "('TENSILE_STRENGTH', 'STRENGTH')": 208000.0,
#   "('UPPER_THREAD', 'CONFIG')": 'BOX',
#   "('UPPER_THREAD', 'SIZE')": 3.5,
#   "('UPPER_THREAD', 'TYPE')": 'VAM TOP',
#   "('UPPER_THREAD', 'WT')": 9.2},
#  '103231276_AB': {"('WETTED_MATERIAL', 'MATERIAL')": '13CR',
#   "('WETTED_MATERIAL', 'STRENGTH')": 80.0,
#   "('CASING_SIZE', 'value')": 9.625,
#   "('WEIGHT_RANGE', 'MAX')": 47.0,
#   "('WEIGHT_RANGE', 'MIN')": 40.0,
#   "('CERTIFICATION', 'value')": 'ISO-V3[150-350F]',
#   "('PRESSURE_RATING', 'value')": 5000.0,
#   "('EXTERNAL_PRESSURE', 'TEMP')": 350.0,
#   "('EXTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('ID_DRIFT', 'value')": 3.833,
#   "('INTERNAL_PRESSURE', 'TEMP')": 350.0,
#   "('INTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('LOWER_THREAD', 'CONFIG')": 'PIN',
#   "('LOWER_THREAD', 'SIZE')": 4.5,
#   "('LOWER_THREAD', 'TYPE')": 'VAM TOP',
#   "('LOWER_THREAD', 'WT')": 12.6,
#   "('MATERIAL_ELEMENTS', 'value')": 'AFLAS',
#   "('MATERIAL_O_RING', 'value')": 'VITON',
#   "('OD_MAX', 'value')": 8.465,
#   "('QCG', 'value')": 'Q3',
#   "('QCP', 'value')": 'CLG QCP-102817386',
#   "('SERVICE_NACE', 'value')": True,
#   "('SETTING_PRESSURE', 'value')": 3000.0,
#   "('RELEASE_FORCE', 'value')": 116766.0,
#   "('TENSILE_STRENGTH', 'TEMP')": 350.0,
#   "('TENSILE_STRENGTH', 'STRENGTH')": 265075.0,
#   "('UPPER_THREAD', 'CONFIG')": 'PIN',
#   "('UPPER_THREAD', 'SIZE')": 4.5,
#   "('UPPER_THREAD', 'TYPE')": 'VAM TOP',
#   "('UPPER_THREAD', 'WT')": 12.6},
#  '103007709_AB': {"('WETTED_MATERIAL', 'MATERIAL')": '13CR',
#   "('WETTED_MATERIAL', 'STRENGTH')": 80.0,
#   "('CASING_SIZE', 'value')": 9.625,
#   "('WEIGHT_RANGE', 'MAX')": 47.0,
#   "('WEIGHT_RANGE', 'MIN')": 40.0,
#   "('CERTIFICATION', 'value')": 'ISO-V3[40-235F, 150-325F]',
#   "('PRESSURE_RATING', 'value')": 5000.0,
#   "('EXTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('EXTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('ID_DRIFT', 'value')": 2.867,
#   "('INTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('INTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('LOWER_THREAD', 'CONFIG')": 'PIN',
#   "('LOWER_THREAD', 'SIZE')": 3.5,
#   "('LOWER_THREAD', 'TYPE')": 'EUE',
#   "('LOWER_THREAD', 'WT')": 9.3,
#   "('MATERIAL_ELEMENTS', 'value')": 'HNBR',
#   "('MATERIAL_O_RING', 'value')": 'VITON',
#   "('OD_MAX', 'value')": 8.465,
#   "('QCG', 'value')": 'Q3',
#   "('QCP', 'value')": 'CLG QCP-102817386',
#   "('SERVICE_NACE', 'value')": True,
#   "('SETTING_PRESSURE', 'value')": 3000.0,
#   "('RELEASE_FORCE', 'value')": 103792.0,
#   "('TENSILE_STRENGTH', 'TEMP')": 325.0,
#   "('TENSILE_STRENGTH', 'STRENGTH')": 208000.0,
#   "('UPPER_THREAD', 'CONFIG')": 'BOX',
#   "('UPPER_THREAD', 'SIZE')": 3.5,
#   "('UPPER_THREAD', 'TYPE')": 'EUE',
#   "('UPPER_THREAD', 'WT')": 9.3},
#  '103129811_AB': {"('WETTED_MATERIAL', 'MATERIAL')": '13CR',
#   "('WETTED_MATERIAL', 'STRENGTH')": 80.0,
#   "('CASING_SIZE', 'value')": 9.625,
#   "('WEIGHT_RANGE', 'MAX')": 53.5,
#   "('WEIGHT_RANGE', 'MIN')": 47.0,
#   "('CERTIFICATION', 'value')": 'ISO-V3[150-325F]',
#   "('PRESSURE_RATING', 'value')": 5000.0,
#   "('EXTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('EXTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('ID_DRIFT', 'value')": 2.867,
#   "('INTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('INTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('LOWER_THREAD', 'CONFIG')": 'PIN',
#   "('LOWER_THREAD', 'SIZE')": 3.5,
#   "('LOWER_THREAD', 'TYPE')": 'VAM TOP',
#   "('LOWER_THREAD', 'WT')": 9.2,
#   "('MATERIAL_ELEMENTS', 'value')": 'HNBR',
#   "('MATERIAL_O_RING', 'value')": 'VITON',
#   "('OD_MAX', 'value')": 8.319,
#   "('QCG', 'value')": 'Q3',
#   "('QCP', 'value')": 'CLG QCP-102817386',
#   "('SERVICE_NACE', 'value')": True,
#   "('SETTING_PRESSURE', 'value')": 3000.0,
#   "('RELEASE_FORCE', 'value')": 103792.0,
#   "('TENSILE_STRENGTH', 'TEMP')": 325.0,
#   "('TENSILE_STRENGTH', 'STRENGTH')": 208000.0,
#   "('UPPER_THREAD', 'CONFIG')": 'BOX',
#   "('UPPER_THREAD', 'SIZE')": 3.5,
#   "('UPPER_THREAD', 'TYPE')": 'VAM TOP',
#   "('UPPER_THREAD', 'WT')": 9.2},
#  '103231271_AC': {"('WETTED_MATERIAL', 'MATERIAL')": '13CR',
#   "('WETTED_MATERIAL', 'STRENGTH')": 80.0,
#   "('CASING_SIZE', 'value')": 9.625,
#   "('WEIGHT_RANGE', 'MAX')": 47.0,
#   "('WEIGHT_RANGE', 'MIN')": 40.0,
#   "('CERTIFICATION', 'value')": 'ISO-V3[150-350F]',
#   "('PRESSURE_RATING', 'value')": 5000.0,
#   "('EXTERNAL_PRESSURE', 'TEMP')": 350.0,
#   "('EXTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('ID_DRIFT', 'value')": 4.653,
#   "('INTERNAL_PRESSURE', 'TEMP')": 350.0,
#   "('INTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('LOWER_THREAD', 'CONFIG')": 'PIN',
#   "('LOWER_THREAD', 'SIZE')": 5.5,
#   "('LOWER_THREAD', 'TYPE')": 'VAM 21',
#   "('LOWER_THREAD', 'WT')": 20.0,
#   "('MATERIAL_ELEMENTS', 'value')": 'AFLAS',
#   "('MATERIAL_O_RING', 'value')": 'VITON',
#   "('OD_MAX', 'value')": 8.465,
#   "('QCG', 'value')": 'Q3',
#   "('QCP', 'value')": 'CLG QCP-102817386',
#   "('SERVICE_NACE', 'value')": True,
#   "('SETTING_PRESSURE', 'value')": 3000.0,
#   "('RELEASE_FORCE', 'value')": 116766.0,
#   "('TENSILE_STRENGTH', 'TEMP')": 350.0,
#   "('TENSILE_STRENGTH', 'STRENGTH')": 217387.0,
#   "('UPPER_THREAD', 'CONFIG')": 'PIN',
#   "('UPPER_THREAD', 'SIZE')": 5.5,
#   "('UPPER_THREAD', 'TYPE')": 'VAM 21',
#   "('UPPER_THREAD', 'WT')": 20.0},
#  '102894287_AD': {"('WETTED_MATERIAL', 'MATERIAL')": '13CR',
#   "('WETTED_MATERIAL', 'STRENGTH')": 80.0,
#   "('CASING_SIZE', 'value')": 9.625,
#   "('WEIGHT_RANGE', 'MAX')": 47.0,
#   "('WEIGHT_RANGE', 'MIN')": 40.0,
#   "('CERTIFICATION', 'value')": 'ISO-V3[150-350F]',
#   "('PRESSURE_RATING', 'value')": 5000.0,
#   "('EXTERNAL_PRESSURE', 'TEMP')": 350.0,
#   "('EXTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('ID_DRIFT', 'value')": 2.867,
#   "('INTERNAL_PRESSURE', 'TEMP')": 350.0,
#   "('INTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('LOWER_THREAD', 'CONFIG')": 'PIN',
#   "('LOWER_THREAD', 'SIZE')": 3.5,
#   "('LOWER_THREAD', 'TYPE')": 'FOX',
#   "('LOWER_THREAD', 'WT')": 9.2,
#   "('MATERIAL_ELEMENTS', 'value')": 'AFLAS',
#   "('MATERIAL_O_RING', 'value')": 'VITON',
#   "('OD_MAX', 'value')": 8.465,
#   "('QCG', 'value')": 'Q3',
#   "('QCP', 'value')": 'CLG QCP-102817386',
#   "('SERVICE_NACE', 'value')": True,
#   "('SETTING_PRESSURE', 'value')": 3000.0,
#   "('RELEASE_FORCE', 'value')": 103792.0,
#   "('TENSILE_STRENGTH', 'TEMP')": 325.0,
#   "('TENSILE_STRENGTH', 'STRENGTH')": 208000.0,
#   "('UPPER_THREAD', 'CONFIG')": 'PIN',
#   "('UPPER_THREAD', 'SIZE')": 3.5,
#   "('UPPER_THREAD', 'TYPE')": 'FOX',
#   "('UPPER_THREAD', 'WT')": 9.2},
#  '102891301_AD': {"('WETTED_MATERIAL', 'MATERIAL')": '13CR',
#   "('WETTED_MATERIAL', 'STRENGTH')": 80.0,
#   "('CASING_SIZE', 'value')": 9.625,
#   "('WEIGHT_RANGE', 'MAX')": 40.0,
#   "('WEIGHT_RANGE', 'MIN')": 36.0,
#   "('CERTIFICATION', 'value')": 'ISO-V3[150-325F]',
#   "('PRESSURE_RATING', 'value')": 5000.0,
#   "('EXTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('EXTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('ID_DRIFT', 'value')": 2.867,
#   "('INTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('INTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('LOWER_THREAD', 'CONFIG')": 'PIN',
#   "('LOWER_THREAD', 'SIZE')": 3.5,
#   "('LOWER_THREAD', 'TYPE')": 'VAM TOP',
#   "('LOWER_THREAD', 'WT')": 9.2,
#   "('MATERIAL_ELEMENTS', 'value')": 'HNBR',
#   "('MATERIAL_O_RING', 'value')": 'VITON',
#   "('OD_MAX', 'value')": 8.619,
#   "('QCG', 'value')": 'Q3',
#   "('QCP', 'value')": 'CLG QCP-102817386',
#   "('SERVICE_NACE', 'value')": True,
#   "('SETTING_PRESSURE', 'value')": 3000.0,
#   "('RELEASE_FORCE', 'value')": 103792.0,
#   "('TENSILE_STRENGTH', 'TEMP')": 325.0,
#   "('TENSILE_STRENGTH', 'STRENGTH')": 208000.0,
#   "('UPPER_THREAD', 'CONFIG')": 'BOX',
#   "('UPPER_THREAD', 'SIZE')": 3.5,
#   "('UPPER_THREAD', 'TYPE')": 'VAM TOP',
#   "('UPPER_THREAD', 'WT')": 9.2},
#  '102832791_AD': {"('WETTED_MATERIAL', 'MATERIAL')": '13CR',
#   "('WETTED_MATERIAL', 'STRENGTH')": 80.0,
#   "('CASING_SIZE', 'value')": 9.625,
#   "('WEIGHT_RANGE', 'MAX')": 47.0,
#   "('WEIGHT_RANGE', 'MIN')": 40.0,
#   "('CERTIFICATION', 'value')": 'ISO-V3[40-235F, 150-325F]',
#   "('PRESSURE_RATING', 'value')": 5000.0,
#   "('EXTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('EXTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('ID_DRIFT', 'value')": 2.347,
#   "('INTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('INTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('LOWER_THREAD', 'CONFIG')": 'PIN',
#   "('LOWER_THREAD', 'SIZE')": 2.875,
#   "('LOWER_THREAD', 'TYPE')": 'VAM TOP',
#   "('LOWER_THREAD', 'WT')": 6.4,
#   "('MATERIAL_ELEMENTS', 'value')": 'HNBR',
#   "('MATERIAL_O_RING', 'value')": 'VITON',
#   "('OD_MAX', 'value')": 8.465,
#   "('QCG', 'value')": 'Q3',
#   "('QCP', 'value')": 'CLG QCP-102817386',
#   "('SERVICE_NACE', 'value')": True,
#   "('SETTING_PRESSURE', 'value')": 3000.0,
#   "('RELEASE_FORCE', 'value')": 103792.0,
#   "('TENSILE_STRENGTH', 'TEMP')": 325.0,
#   "('TENSILE_STRENGTH', 'STRENGTH')": 144000.0,
#   "('UPPER_THREAD', 'CONFIG')": 'BOX',
#   "('UPPER_THREAD', 'SIZE')": 2.875,
#   "('UPPER_THREAD', 'TYPE')": 'VAM TOP',
#   "('UPPER_THREAD', 'WT')": 6.4},
#  '102888683_AD': {"('WETTED_MATERIAL', 'MATERIAL')": '13CR',
#   "('WETTED_MATERIAL', 'STRENGTH')": 80.0,
#   "('CASING_SIZE', 'value')": 9.625,
#   "('WEIGHT_RANGE', 'MAX')": 47.0,
#   "('WEIGHT_RANGE', 'MIN')": 40.0,
#   "('CERTIFICATION', 'value')": 'ISO-V3[40-235F, 150-325F]',
#   "('PRESSURE_RATING', 'value')": 5000.0,
#   "('EXTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('EXTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('ID_DRIFT', 'value')": 2.867,
#   "('INTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('INTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('LOWER_THREAD', 'CONFIG')": 'PIN',
#   "('LOWER_THREAD', 'SIZE')": 3.5,
#   "('LOWER_THREAD', 'TYPE')": 'VAM TOP',
#   "('LOWER_THREAD', 'WT')": 9.2,
#   "('MATERIAL_ELEMENTS', 'value')": 'HNBR',
#   "('MATERIAL_O_RING', 'value')": 'VITON',
#   "('OD_MAX', 'value')": 8.465,
#   "('QCG', 'value')": 'Q3',
#   "('QCP', 'value')": 'CLG QCP-102817386',
#   "('SERVICE_NACE', 'value')": True,
#   "('SETTING_PRESSURE', 'value')": 3000.0,
#   "('RELEASE_FORCE', 'value')": 103792.0,
#   "('TENSILE_STRENGTH', 'TEMP')": 325.0,
#   "('TENSILE_STRENGTH', 'STRENGTH')": 208000.0,
#   "('UPPER_THREAD', 'CONFIG')": 'BOX',
#   "('UPPER_THREAD', 'SIZE')": 3.5,
#   "('UPPER_THREAD', 'TYPE')": 'VAM TOP',
#   "('UPPER_THREAD', 'WT')": 9.2},
#  '103120205_AB': {"('WETTED_MATERIAL', 'MATERIAL')": '13CR',
#   "('WETTED_MATERIAL', 'STRENGTH')": 80.0,
#   "('CASING_SIZE', 'value')": 9.625,
#   "('WEIGHT_RANGE', 'MAX')": 47.0,
#   "('WEIGHT_RANGE', 'MIN')": 40.0,
#   "('CERTIFICATION', 'value')": 'ISO-V3[40-235F, 150-325F]',
#   "('PRESSURE_RATING', 'value')": 5000.0,
#   "('EXTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('EXTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('ID_DRIFT', 'value')": 2.867,
#   "('INTERNAL_PRESSURE', 'TEMP')": 325.0,
#   "('INTERNAL_PRESSURE', 'PRESSURE')": 5000.0,
#   "('LOWER_THREAD', 'CONFIG')": 'PIN',
#   "('LOWER_THREAD', 'SIZE')": 3.5,
#   "('LOWER_THREAD', 'TYPE')": 'JFE BEAR',
#   "('LOWER_THREAD', 'WT')": 9.2,
#   "('MATERIAL_ELEMENTS', 'value')": 'HNBR',
#   "('MATERIAL_O_RING', 'value')": 'HNBR',
#   "('OD_MAX', 'value')": 8.465,
#   "('QCG', 'value')": 'Q3',
#   "('QCP', 'value')": 'CLG QCP-102817386',
#   "('SERVICE_NACE', 'value')": True,
#   "('SETTING_PRESSURE', 'value')": 3000.0,
#   "('RELEASE_FORCE', 'value')": 103792.0,
#   "('TENSILE_STRENGTH', 'TEMP')": 325.0,
#   "('TENSILE_STRENGTH', 'STRENGTH')": 208000.0,
#   "('UPPER_THREAD', 'CONFIG')": 'BOX',
#   "('UPPER_THREAD', 'SIZE')": 3.5,
#   "('UPPER_THREAD', 'TYPE')": 'JFE BEAR',
#   "('UPPER_THREAD', 'WT')": 9.2}}

# %%
# Dict for json for other match flag for those columns that pass the filter

ia_df_filter_result[ia_criteries].loc[s_filter_result_sum[s_filter_result_sum < len(ia_criteries)].sort_values(ascending = False).index].head()
# Out:
# attributes   CASING_SIZE WETTED_MATERIAL WEIGHT_RANGE
# values             value        MATERIAL          MAX    MIN
# 103232093_AA        True            True         True  False
# 103000049_AA        True           False         True   True
# 102055050_AC        True            True         True  False
# 102103987_AG        True            True        False   True
# 102727939_AC        True            True         True  False

# %%
data_structure = {}

for col in ia_df_basic_cols.columns:
    main_col = col[0] 
    sub_col = col[1]
    if main_col not in data_structure:
        data_structure[main_col] = {}
        
    
    data_structure[main_col]['name'] = reverse_rename[main_col]
    data_structure[main_col]['description'] = independent_attributes[independent_attributes['Attribute'] == 
                                                                     reverse_rename[main_col]]['Definition'].iloc[0]
    data_structure[main_col][sub_col] = {}
    data_structure[main_col][sub_col]['rule'] = ia_rules[col]

    if (ia_df_basic_cols[col].dtype == 'object'):
        data_structure[main_col][sub_col]['type'] = 'string' 
    else:
        data_structure[main_col][sub_col]['type'] = str(ia_df_basic_cols[col].dtype)
    
    if (ia_df_basic_cols[col].dtype == 'float64'):
        data_structure[main_col][sub_col]['min'] = float(np.min(ia_df_basic_cols[col]))
        data_structure[main_col][sub_col]['max'] = float(np.max(ia_df_basic_cols[col]))
    else:
        data_structure[main_col][sub_col]['values'] = list([str(val) for 
                                                    val in 
                                                    ia_df_basic_cols[col].unique()])
pp = pprint.PrettyPrinter(indent = 4)
pp.pprint(data_structure)
data_structure
# Out:
# {   'CASING_SIZE': {   'description': 'Nominal completion casing size',
#                        'name': 'CASING SIZE (IN)',
#                        'value': {   'max': 10.75,
#                                     'min': 4.5,
#                                     'rule': 'ia_df.CASING_SIZE.value<=x',
#                                     'type': 'float64'}},
#     'CERTIFICATION': {   'description': 'ISO 14310 V6~V0 design validation '
#                                         'grade for packers',
#                          'name': 'CERTIFICATION STATUS',
#                          'value': {   'rule': 'ia_df.CERTIFICATION.value==x',
#                                       'type': 'string',
#                                       'values': [   'ISO-V3[150-325F]',
#                                                     'ISO-V3[150-325F, 40-235F]',
#                                                     'ISO-V3[40-235F, 150-325F]',
#                                                     'ISO-V6[AMBIENT]',
#                                                     'ISO-V1[150-325F]',
#                                                     'ISO-V3[40-195F]',
#                                                     'ISO-V3[150-350F]',
#                                                     'nan']}},
#     'EXTERNAL_PRESSURE': {   'PRESSURE': {   'max': 6000.0,
#                                              'min': 5000.0,
#                                              'rule': 'ia_df.EXTERNAL_PRESSURE.PRESSURE>=x',
#                                              'type': 'float64'},
#                              'TEMP': {   'max': 350.0,
#                                          'min': 0.0,
#                                          'rule': 'ia_df.EXTERNAL_PRESSURE.TEMP>=x',
#                                          'type': 'float64'},
#                              'description': 'Max. allowable external pressure '
#                                             'of the product at a specified '
#                                             'temp. and excluding threaded end '
#                                             'connections',
#                              'name': 'EXTERNAL WORKING PRESSURE (PSI) - EOEC '
#                                      'AT SPECIFIED TEMP (F)'},
#     'ID_DRIFT': {   'description': 'Drift ID using standard API tubing drift',
#                     'name': 'I.D. - DRIFT (IN)',
#                     'value': {   'max': 4.767,
#                                  'min': 1.901,
#                                  'rule': 'ia_df.ID_DRIFT.value<=x',
#                                  'type': 'float64'}},
#     'INTERNAL_PRESSURE': {   'PRESSURE': {   'max': 7500.0,
#                                              'min': 5000.0,
#                                              'rule': 'ia_df.INTERNAL_PRESSURE.PRESSURE>=x',
#                                              'type': 'float64'},
#                              'TEMP': {   'max': 350.0,
#                                          'min': 0.0,
#                                          'rule': 'ia_df.INTERNAL_PRESSURE.TEMP>=x',
#                                          'type': 'float64'},
#                              'description': 'Max. allowable internal pressure '
#                                             'of the product at a specified '
#                                             'temp. and excluding threaded end '
#                                             'connections',
#                              'name': 'INTERNAL WORKING PRESSURE (PSI) - EOEC '
#                                      'AT SPECIFIED TEMP (F)'},
#     'LOWER_THREAD': {   'CONFIG': {   'rule': 'ia_df.LOWER_THREAD.CONFIG==x',
#                                       'type': 'string',
#                                       'values': ['PIN']},
#                         'SIZE': {   'max': 5.5,
#                                     'min': 2.375,
#                                     'rule': 'ia_df.LOWER_THREAD.SIZE<=x',
#                                     'type': 'float64'},
#                         'TYPE': {   'rule': 'ia_df.LOWER_THREAD.TYPE==x',
#                                     'type': 'string',
#                                     'values': [   'STUB ACME',
#                                                   'EUE',
#                                                   'LTC',
#                                                   'VAM TOP',
#                                                   'FOX',
#                                                   'NEW VAM',
#                                                   'JFE BEAR',
#                                                   'VAM 21',
#                                                   'TENARIS HYDRIL BLUE']},
#                         'WT': {   'max': 20.0,
#                                   'min': 4.6,
#                                   'rule': 'ia_df.LOWER_THREAD.WT<=x',
#                                   'type': 'float64'},
#                         'description': 'Thread connecion at the bottom of '
#                                        'packer',
#                         'name': 'LOWER THREAD CONNECTING - SIZE (IN), WT '
#                                 '(PPF), TYPE, CONFIG'},
#     'MATERIAL_ELEMENTS': {   'description': 'Element compound',
#                              'name': 'MATERIAL/ELEMENTS',
#                              'value': {   'rule': 'ia_df.MATERIAL_ELEMENTS.value==x',
#                                           'type': 'string',
#                                           'values': ['HNBR', 'AFLAS', 'nan']}},
#     'MATERIAL_O_RING': {   'description': 'O-ring compound',
#                            'name': 'MATERIAL/O-RING(S)',
#                            'value': {   'rule': 'ia_df.MATERIAL_O_RING.value==x',
#                                         'type': 'string',
#                                         'values': ['VITON', 'HNBR']}},
#     'OD_MAX': {   'description': 'OD of the largest metal component of a '
#                                  'packer',
#                   'name': 'O.D. - MAX. (IN)',
#                   'value': {   'max': 9.344,
#                                'min': 3.75,
#                                'rule': 'ia_df.OD_MAX.value<=x',
#                                'type': 'float64'}},
#     'PRESSURE_RATING': {   'description': 'The maxium differential pressure '
#                                           'across the element',
#                            'name': 'DIFFERENTIAL PRESSURE RATING (PSI)',
#                            'value': {   'max': 6000.0,
#                                         'min': 5000.0,
#                                         'rule': 'ia_df.PRESSURE_RATING.value>=x',
#                                         'type': 'float64'}},
#     'QCG': {   'description': '3 different grade defined per API 11D1',
#                'name': 'QUALITY CONTROL GRADE',
#                'value': {   'rule': 'ia_df.QCG.value==x',
#                             'type': 'string',
#                             'values': ['Q3', 'nan']}},
#     'QCP': {   'description': 'Customer quality control plan',
#                'name': 'QUALITY CONTROL PLAN - QCP',
#                'value': {   'rule': 'ia_df.QCP.value==x',
#                             'type': 'string',
#                             'values': [   'QCP-101792794',
#                                           'CLG QCP-102817386',
#                                           'CLQ QCP-102817386']}},
#     'RELEASE_FORCE': {   'description': 'Nominal shear force required to '
#                                         'activiate release mechanism on a '
#                                         'packer',
#                          'name': 'SHEAR RELEASE FORCE (LB)',
#                          'value': {   'max': 129740.0,
#                                       'min': 77844.0,
#                                       'rule': 'ia_df.RELEASE_FORCE.value<=x',
#                                       'type': 'float64'}},
#     'SERVICE_NACE': {   'description': 'If a packer type 1 components are '
#                                        'manufactured from material that '
#                                        'complying NACE MR0175 requirement',
#                         'name': 'SERVICE NACE (YES/NO)',
#                         'value': {   'rule': 'ia_df.SERVICE_NACE.value==x',
#                                      'type': 'bool',
#                                      'values': ['True', 'False']}},
#     'SETTING_PRESSURE': {   'description': 'Mini. differential pressure to set '
#                                            'a packer',
#                             'name': 'SETTING DIFFERENTIAL PRESSURE - '
#                                     'RECOMMENDED (MIN)(PSI)',
#                             'value': {   'max': 3000.0,
#                                          'min': 2400.0,
#                                          'rule': 'ia_df.SETTING_PRESSURE.value>=x',
#                                          'type': 'float64'}},
#     'TENSILE_STRENGTH': {   'STRENGTH': {   'max': 408300.0,
#                                             'min': 101000.0,
#                                             'rule': 'ia_df.TENSILE_STRENGTH.STRENGTH>=x',
#                                             'type': 'float64'},
#                             'TEMP': {   'max': 350.0,
#                                         'min': 0.0,
#                                         'rule': 'ia_df.TENSILE_STRENGTH.TEMP>=x',
#                                         'type': 'float64'},
#                             'description': 'The Max. tension that can be '
#                                            'pulled into a packer',
#                             'name': 'TENSILE STRENGTH (LBS) - EOEC AT '
#                                     'SPECIFIED TEMP (F)'},
#     'UPPER_THREAD': {   'CONFIG': {   'rule': 'ia_df.UPPER_THREAD.CONFIG==x',
#                                       'type': 'string',
#                                       'values': ['PIN', 'BOX']},
#                         'SIZE': {   'max': 5.5,
#                                     'min': 2.375,
#                                     'rule': 'ia_df.UPPER_THREAD.SIZE<=x',
#                                     'type': 'float64'},
#                         'TYPE': {   'rule': 'ia_df.UPPER_THREAD.TYPE==x',
#                                     'type': 'string',
#                                     'values': [   'STUB ACME',
#                                                   'EUE',
#                                                   'LTC',
#                                                   'MODIFIED EUE',
#                                                   'VAM TOP',
#                                                   'FOX',
#                                                   'NEW VAM',
#                                                   'JFE BEAR',
#                                                   'VAM 21',
#                                                   'TENARIS HYDRIL BLUE']},
#                         'WT': {   'max': 20.0,
#                                   'min': 4.6,
#                                   'rule': 'ia_df.UPPER_THREAD.WT<=x',
#                                   'type': 'float64'},
#                         'description': 'Thread connecion at the top of packer',
#                         'name': 'UPPER THREAD CONNECTING - SIZE (IN), WT '
#                                 '(PPF), TYPE, CONFIG'},
#     'WEIGHT_RANGE': {   'MAX': {   'max': 65.7,
#                                    'min': 13.5,
#                                    'rule': 'ia_df.WEIGHT_RANGE.MAX<=x',
#                                    'type': 'float64'},
#                         'MIN': {   'max': 47.0,
#                                    'min': 9.5,
#                                    'rule': 'ia_df.WEIGHT_RANGE.MIN>=x',
#                                    'type': 'float64'},
#                         'description': 'Nominal completion casing weights',
#                         'name': 'CASING WEIGHT RANGE (PPF)'},
#     'WETTED_MATERIAL': {   'MATERIAL': {   'rule': 'ia_df.WETTED_MATERIAL.MATERIAL==x',
#                                            'type': 'string',
#                                            'values': [   '9CR',
#                                                          '41XX',
#                                                          '13CR',
#                                                          '9CR-1MO',
#                                                          '25CR']},
#                            'STRENGTH': {   'max': 110.0,
#                                            'min': 80.0,
#                                            'rule': 'ia_df.WETTED_MATERIAL.STRENGTH>=x',
#                                            'type': 'float64'},
#                            'description': 'Component comes in direct contact '
#                                           'with the dynamic movement of well '
#                                           'fluids',
#                            'name': 'ACTIVE FLOW WETTED MATERIAL - YIELD '
#                                    'STRENGTH (KSI)'}}
# {'WETTED_MATERIAL': {'name': 'ACTIVE FLOW WETTED MATERIAL - YIELD STRENGTH (KSI)',
#   'description': 'Component comes in direct contact with the dynamic movement of well fluids',
#   'MATERIAL': {'rule': 'ia_df.WETTED_MATERIAL.MATERIAL==x',
#    'type': 'string',
#    'values': ['9CR', '41XX', '13CR', '9CR-1MO', '25CR']},
#   'STRENGTH': {'rule': 'ia_df.WETTED_MATERIAL.STRENGTH>=x',
#    'type': 'float64',
#    'min': 80.0,
#    'max': 110.0}},
#  'CASING_SIZE': {'name': 'CASING SIZE (IN)',
#   'description': 'Nominal completion casing size',
#   'value': {'rule': 'ia_df.CASING_SIZE.value<=x',
#    'type': 'float64',
#    'min': 4.5,
#    'max': 10.75}},
#  'WEIGHT_RANGE': {'name': 'CASING WEIGHT RANGE (PPF)',
#   'description': 'Nominal completion casing weights',
#   'MAX': {'rule': 'ia_df.WEIGHT_RANGE.MAX<=x',
#    'type': 'float64',
#    'min': 13.5,
#    'max': 65.7},
#   'MIN': {'rule': 'ia_df.WEIGHT_RANGE.MIN>=x',
#    'type': 'float64',
#    'min': 9.5,
#    'max': 47.0}},
#  'CERTIFICATION': {'name': 'CERTIFICATION STATUS',
#   'description': 'ISO 14310 V6~V0 design validation grade for packers',
#   'value': {'rule': 'ia_df.CERTIFICATION.value==x',
#    'type': 'string',
#    'values': ['ISO-V3[150-325F]',
#     'ISO-V3[150-325F, 40-235F]',
#     'ISO-V3[40-235F, 150-325F]',
#     'ISO-V6[AMBIENT]',
#     'ISO-V1[150-325F]',
#     'ISO-V3[40-195F]',
#     'ISO-V3[150-350F]',
#     'nan']}},
#  'PRESSURE_RATING': {'name': 'DIFFERENTIAL PRESSURE RATING (PSI)',
#   'description': 'The maxium differential pressure across the element',
#   'value': {'rule': 'ia_df.PRESSURE_RATING.value>=x',
#    'type': 'float64',
#    'min': 5000.0,
#    'max': 6000.0}},
#  'EXTERNAL_PRESSURE': {'name': 'EXTERNAL WORKING PRESSURE (PSI) - EOEC AT SPECIFIED TEMP (F)',
#   'description': 'Max. allowable external pressure of the product at a specified temp. and excluding threaded end connections',
#   'TEMP': {'rule': 'ia_df.EXTERNAL_PRESSURE.TEMP>=x',
#    'type': 'float64',
#    'min': 0.0,
#    'max': 350.0},
#   'PRESSURE': {'rule': 'ia_df.EXTERNAL_PRESSURE.PRESSURE>=x',
#    'type': 'float64',
#    'min': 5000.0,
#    'max': 6000.0}},
#  'ID_DRIFT': {'name': 'I.D. - DRIFT (IN)',
#   'description': 'Drift ID using standard API tubing drift',
#   'value': {'rule': 'ia_df.ID_DRIFT.value<=x',
#    'type': 'float64',
#    'min': 1.901,
#    'max': 4.767}},
#  'INTERNAL_PRESSURE': {'name': 'INTERNAL WORKING PRESSURE (PSI) - EOEC AT SPECIFIED TEMP (F)',
#   'description': 'Max. allowable internal pressure of the product at a specified temp. and excluding threaded end connections',
#   'TEMP': {'rule': 'ia_df.INTERNAL_PRESSURE.TEMP>=x',
#    'type': 'float64',
#    'min': 0.0,
#    'max': 350.0},
#   'PRESSURE': {'rule': 'ia_df.INTERNAL_PRESSURE.PRESSURE>=x',
#    'type': 'float64',
#    'min': 5000.0,
#    'max': 7500.0}},
#  'LOWER_THREAD': {'name': 'LOWER THREAD CONNECTING - SIZE (IN), WT (PPF), TYPE, CONFIG',
#   'description': 'Thread connecion at the bottom of packer',
#   'CONFIG': {'rule': 'ia_df.LOWER_THREAD.CONFIG==x',
#    'type': 'string',
#    'values': ['PIN']},
#   'SIZE': {'rule': 'ia_df.LOWER_THREAD.SIZE<=x',
#    'type': 'float64',
#    'min': 2.375,
#    'max': 5.5},
#   'TYPE': {'rule': 'ia_df.LOWER_THREAD.TYPE==x',
#    'type': 'string',
#    'values': ['STUB ACME',
#     'EUE',
#     'LTC',
#     'VAM TOP',
#     'FOX',
#     'NEW VAM',
#     'JFE BEAR',
#     'VAM 21',
#     'TENARIS HYDRIL BLUE']},
#   'WT': {'rule': 'ia_df.LOWER_THREAD.WT<=x',
#    'type': 'float64',
#    'min': 4.6,
#    'max': 20.0}},
#  'MATERIAL_ELEMENTS': {'name': 'MATERIAL/ELEMENTS',
#   'description': 'Element compound',
#   'value': {'rule': 'ia_df.MATERIAL_ELEMENTS.value==x',
#    'type': 'string',
#    'values': ['HNBR', 'AFLAS', 'nan']}},
#  'MATERIAL_O_RING': {'name': 'MATERIAL/O-RING(S)',
#   'description': 'O-ring compound',
#   'value': {'rule': 'ia_df.MATERIAL_O_RING.value==x',
#    'type': 'string',
#    'values': ['VITON', 'HNBR']}},
#  'OD_MAX': {'name': 'O.D. - MAX. (IN)',
#   'description': 'OD of the largest metal component of a packer',
#   'value': {'rule': 'ia_df.OD_MAX.value<=x',
#    'type': 'float64',
#    'min': 3.75,
#    'max': 9.344}},
#  'QCG': {'name': 'QUALITY CONTROL GRADE',
#   'description': '3 different grade defined per API 11D1',
#   'value': {'rule': 'ia_df.QCG.value==x',
#    'type': 'string',
#    'values': ['Q3', 'nan']}},
#  'QCP': {'name': 'QUALITY CONTROL PLAN - QCP',
#   'description': 'Customer quality control plan',
#   'value': {'rule': 'ia_df.QCP.value==x',
#    'type': 'string',
#    'values': ['QCP-101792794', 'CLG QCP-102817386', 'CLQ QCP-102817386']}},
#  'SERVICE_NACE': {'name': 'SERVICE NACE (YES/NO)',
#   'description': 'If a packer type 1 components are manufactured from material that complying NACE MR0175 requirement',
#   'value': {'rule': 'ia_df.SERVICE_NACE.value==x',
#    'type': 'bool',
#    'values': ['True', 'False']}},
#  'SETTING_PRESSURE': {'name': 'SETTING DIFFERENTIAL PRESSURE - RECOMMENDED (MIN)(PSI)',
#   'description': 'Mini. differential pressure to set a packer',
#   'value': {'rule': 'ia_df.SETTING_PRESSURE.value>=x',
#    'type': 'float64',
#    'min': 2400.0,
#    'max': 3000.0}},
#  'RELEASE_FORCE': {'name': 'SHEAR RELEASE FORCE (LB)',
#   'description': 'Nominal shear force required to activiate release mechanism on a packer',
#   'value': {'rule': 'ia_df.RELEASE_FORCE.value<=x',
#    'type': 'float64',
#    'min': 77844.0,
#    'max': 129740.0}},
#  'TENSILE_STRENGTH': {'name': 'TENSILE STRENGTH (LBS) - EOEC AT SPECIFIED TEMP (F)',
#   'description': 'The Max. tension that can be pulled into a packer',
#   'TEMP': {'rule': 'ia_df.TENSILE_STRENGTH.TEMP>=x',
#    'type': 'float64',
#    'min': 0.0,
#    'max': 350.0},
#   'STRENGTH': {'rule': 'ia_df.TENSILE_STRENGTH.STRENGTH>=x',
#    'type': 'float64',
#    'min': 101000.0,
#    'max': 408300.0}},
#  'UPPER_THREAD': {'name': 'UPPER THREAD CONNECTING - SIZE (IN), WT (PPF), TYPE, CONFIG',
#   'description': 'Thread connecion at the top of packer',
#   'CONFIG': {'rule': 'ia_df.UPPER_THREAD.CONFIG==x',
#    'type': 'string',
#    'values': ['PIN', 'BOX']},
#   'SIZE': {'rule': 'ia_df.UPPER_THREAD.SIZE<=x',
#    'type': 'float64',
#    'min': 2.375,
#    'max': 5.5},
#   'TYPE': {'rule': 'ia_df.UPPER_THREAD.TYPE==x',
#    'type': 'string',
#    'values': ['STUB ACME',
#     'EUE',
#     'LTC',
#     'MODIFIED EUE',
#     'VAM TOP',
#     'FOX',
#     'NEW VAM',
#     'JFE BEAR',
#     'VAM 21',
#     'TENARIS HYDRIL BLUE']},
#   'WT': {'rule': 'ia_df.UPPER_THREAD.WT<=x',
#    'type': 'float64',
#    'min': 4.6,
#    'max': 20.0}}}

# %%
config_dict = {}

config_dict['app_name'] = 'SLB_task2'
config_dict['attributes'] = data_structure

f = open("backend/slb_task2/config.yaml", "w")
yaml.dump(config_dict, f)
f.close()

# %%
ia_df_basic_cols.to_excel("ia_df_basic_cols.xlsx")
ia_df_basic_cols.describe().to_excel("ia_df_basic_cols_describe.xlsx")
ia_df_basic_cols.to_pickle("backend/slb_data/ia_df.pkl")
